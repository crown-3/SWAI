# %% [markdown]
# # Mac OS를 위한 setting

# %%
# webdriver setting
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager

driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())

# beautifulSoup, pandas setting
from bs4 import BeautifulSoup
import pandas as pd

# os, time setting
import os
import time
import copy
import re
import threading

# %% [markdown]
# ### 크롤링하고자 하는 데이터
# 1. name: 글꼴 이름
# 2. author: 제작자
# 3. downloads: 다운로드 수
# 4. link: 폰트의 dafont 페이지 링크
# 5. theme: 폰트의 하위 테마
# 6. license: 폰트의 라이센스
# 7. supported_glyphs: 지원되는 문체 (accent, euro)
# 8. uploaded_year: dafont에 업로드된 년도
#
# ### 크롤링할 웹사이트
# https://www.dafont.com/mtheme.php?id=1
# dafont에서 'Fancy'라는 테마를 가진 글꼴들을 대상으로 크롤링한다.

# %%
font_data = {
    'name': None,
    'author': None,
    'downloads': None,
    'link': None,
    'theme': None,
    'license': None,
    'supported_glyphs': None,
    'uploaded_year': None
}

base_url = "https://www.dafont.com"
theme_url = f"{base_url}/mtheme.php?id=1"

fonts_info = []

page = 1
objective = 100

# %% [markdown]
# # 크롤링 시작
# ### 크롤링하는 순서와 방법론은 다음과 같다.
# 1. url 파라미터로 페이지를 결정한다. (f"{base_url}&page=n"에서 n을 조작함으로써 페이지를 옮길 수 있다.)
# 2. 이 페이지의 폰트 리스트는 하나의 html element로 묶여 있지 않다. "lv1left dfbg" class값을 가진 div태그들을 모아 그 안에 있는 a태그의 href값을 추출하고 합쳐 임시 폰트 url 배열을 만든다.
# 3. 임시 폰트 url 배열에 대해 순회하며 폰트 상세 페이지를 방문한다.
# 4. 데이터 수집을 끝마쳤으면 bs4 객체를 초기화하고 다음 페이지로 넘어간다.
# 5. 추출된 url이 없으면 끝낸다.

# %%
# 정보 추출을 위한 함수 정의
def extract_element(soup, selector, default="unknown", post_process=None):
    try:
        element = soup.select_one(selector)
        text = element.text.strip() if element else default
        return post_process(text) if post_process else text
    except Exception as e:
        print(f"An error occurred: {e}")
        return default

# %%
def extract_font_info(soup):
    font_info = copy.deepcopy(font_data)
    
    font_info['name'] = extract_element(soup, 'div.lv1left > strong')
    font_info['author'] = extract_element(soup, 'div.lv1left > a')
    font_info['downloads'] = extract_element(soup, 'div.lv2right > span', post_process=lambda x: int(re.search(r'(\d+)', x).group(1)) if re.search(r'(\d+)', x) else 0)
    font_info['link'] = soup.current_url if hasattr(soup, 'current_url') else "unknown"
    font_info['theme'] = extract_element(soup, 'div.lv1right > a:nth-of-type(2)')
    font_info['license'] = extract_element(soup, 'a.tdn.help.black')
    font_info['supported_glyphs'] = extract_element(soup, 'div.lv1left > span.contain', post_process=lambda x: ', '.join([elem.text.strip() for elem in soup.select('div.lv1left > span.contain')]) if soup.select('div.lv1left > span.contain') else "unknown")
    font_info['uploaded_year'] = extract_element(soup, 'div.dfsmall', post_process=lambda x: int(re.search(r'(\d{4})', x).group(1)) if re.search(r'(\d{4})', x) else "unknown")
    
    return font_info

# %%
while True:
    # 페이지 세팅 후 접속
    url = f"{theme_url}&page={page}"
    driver.get(url)
    
    time.sleep(0.5)
    
    # soup 받아오기
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    # soup의 특정 class를 가진 요소들을 모조리 찾음
    elements_lv1left_dfbg = soup.find_all('div', class_="lv1left dfbg")
    
    # 없으면 크롤링 종료
    if not elements_lv1left_dfbg:
        break
    
    # 폰트 상세 페이지로 이동하는 url을 배열로 묶어냄 
    font_urls = [element.select_one('div.lv1left > a')['href'] for element in elements_lv1left_dfbg]
    

    for font_url in font_urls:
        # 추출한 url에 따라 페이지 방문
        driver.get(f"{base_url}/{font_url}")
        
        time.sleep(0.5)
        
        font_detail_soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        # 폰트 정보 수집 후 저장
        font_info = extract_font_info(font_detail_soup)
        fonts_info.append(font_info)
        
        # 목표 데이터 수에 도달했다면 탈출
        if len(fonts_info) >= objective:
            break
    
    # 목표 데이터 수에 도달했다면 탈출
    if len(fonts_info) >= objective:
        break
        
    # 다음 페이지로 넘어감
    page += 1

# %%
# Out:
# #1 Saved font info: Starborn
# #2 Saved font info: Varsity
# #3 Saved font info: Melted Monster
# #4 Saved font info: Cheese Burger
# #5 Saved font info: Harry P
# #6 Saved font info: Another Danger
# #7 Saved font info: Super Milk
# #8 Saved font info: Super Mario 256
# #9 Saved font info: Super Plants
# #10 Saved font info: Ghastly Panic
# #11 Saved font info: Ruzack Mojok
# #12 Saved font info: Krifon
# #13 Saved font info: Doctor Glitch
# #14 Saved font info: KG Red Hands
# #15 Saved font info: Happy Dance
# #16 Saved font info: Cheri
# #17 Saved font info: Muloka Kerash
# #18 Saved font info: American Captain
# #19 Saved font info: Komika Axis
# #20 Saved font info: Next Sunday
# #21 Saved font info: Valoon
# #22 Saved font info: Sunday Mango
# #23 Saved font info: Horror Korpus
# #24 Saved font info: BubbleGum
# #25 Saved font info: Freshman
# #26 Saved font info: Pokémon
# #27 Saved font info: Badaboom BB
# #28 Saved font info: Marola
# #29 Saved font info: Adelia
# #30 Saved font info: Who asks Satan
# #31 Saved font info: Urban Jungle
# #32 Saved font info: JMH Typewriter
# #33 Saved font info: Lostar
# #34 Saved font info: Misologist
# #35 Saved font info: Varsity Team
# #36 Saved font info: Grobold
# #37 Saved font info: Keep on Truckin' FW
# #38 Saved font info: Brogte
# #39 Saved font info: Rhuma Sinera
# #40 Saved font info: Hey Comic
# #41 Saved font info: Super Dessert
# #42 Saved font info: Storm Gust
# #43 Saved font info: The Amazing Spider-Man
# #44 Saved font info: Chicken Pie
# #45 Saved font info: Toony Line
# #46 Saved font info: Blastimo Sans
# #47 Saved font info: Porky's
# #48 Saved font info: Magic Retro
# #49 Saved font info: Hip Horay
# #50 Saved font info: Bouncy
# #51 Saved font info: Super Sedan
# #52 Saved font info: Break
# #53 Saved font info: New Romantics
# #54 Saved font info: Super Cool
# #55 Saved font info: Aurora Pro
# #56 Saved font info: Planet Joy
# #57 Saved font info: Texas Tango
# #58 Saved font info: Jumbo Sale
# #59 Saved font info: Shlop
# #60 Saved font info: Evil Empire
# #61 Saved font info: New Machiato
# #62 Saved font info: Darling
# #63 Saved font info: Friday 13
# #64 Saved font info: Heartless
# #65 Saved font info: Jersey M54
# #66 Saved font info: Rushen
# #67 Saved font info: College
# #68 Saved font info: Super Magic
# #69 Saved font info: Super Snack
# #70 Saved font info: Curse of the Zombie
# #71 Saved font info: Monday Banana
# #72 Saved font info: Next Bro
# #73 Saved font info: Hyper Super Fast
# #74 Saved font info: Glossy Sheen
# #75 Saved font info: Organical
# #76 Saved font info: Bakso Sapi
# #77 Saved font info: Panic
# #78 Saved font info: Help Me
# #79 Saved font info: Vintage King
# #80 Saved font info: Super Squad
# #81 Saved font info: Gods Must
# #82 Saved font info: Rock Wastro
# #83 Saved font info: Blazed
# #84 Saved font info: Mantana
# #85 Saved font info: Saint Carell
# #86 Saved font info: Blue Ocean
# #87 Saved font info: KG Happy
# #88 Saved font info: Giver Made
# #89 Saved font info: Carnivalee Freakshow
# #90 Saved font info: Bright
# #91 Saved font info: Mom's Typewriter
# #92 Saved font info: Cute Notes
# #93 Saved font info: University
# #94 Saved font info: Campus
# #95 Saved font info: Anime Ace BB
# #96 Saved font info: Collegiate FLF
# #97 Saved font info: Magazine Letter
# #98 Saved font info: Magic Sound
# #99 Saved font info: Get Now
# #100 Saved font info: a Abstract Groovy
# #101 Saved font info: The Macabre
# #102 Saved font info: Bonello
# #103 Saved font info: Grinched
# #104 Saved font info: Nightcore
# #105 Saved font info: Blacklisted
# #106 Saved font info: Capture it
# #107 Saved font info: Ka Blam
# #108 Saved font info: Unfair Shares
# #109 Saved font info: Shadow Of The Deads
# #110 Saved font info: Metropolitan
# #111 Saved font info: PaybAck
# #112 Saved font info: Genty
# #113 Saved font info: Permola Display
# #114 Saved font info: Soccer League
# #115 Saved font info: Blantick Script
# #116 Saved font info: Academy
# #117 Saved font info: Another Typewriter
# #118 Saved font info: The Death Dog
# #119 Saved font info: Candy Beans
# #120 Saved font info: Bloody
# #121 Saved font info: Last Episode
# #122 Saved font info: Super Organic
# #123 Saved font info: Riffic
# #124 Saved font info: Retro Cool
# #125 Saved font info: Manga Temple
# #126 Saved font info: Rio Grande
# #127 Saved font info: Kaoly
# #128 Saved font info: Franchise
# #129 Saved font info: Mainstay
# #130 Saved font info: Mercy Christole
# #131 Saved font info: Brodies
# #132 Saved font info: CoffeCake
# #133 Saved font info: Spongeboy Me Bob
# #134 Saved font info: Squashy Flow
# #135 Saved font info: Plante
# #136 Saved font info: Creepsville
# #137 Saved font info: Stranger back in the Night
# #138 Saved font info: Bigdex
# #139 Saved font info: Royal Acidbath
# #140 Saved font info: Jackpot
# #141 Saved font info: Plane Crash
# #142 Saved font info: Flowers Kingdom
# #143 Saved font info: Hanging Letters
# #144 Saved font info: Adventure
# #145 Saved font info: Hellbone
# #146 Saved font info: Circus
# #147 Saved font info: Soopafresh
# #148 Saved font info: Revamped
# #149 Saved font info: Sticky Sans
# #150 Saved font info: Super Dream
# #151 Saved font info: Sports World
# #152 Saved font info: Bad Grunge
# #153 Saved font info: Basketball
# #154 Saved font info: Cutie Molly
# #155 Saved font info: Fighting Spirit
# #156 Saved font info: Old Newspaper Types
# #157 Saved font info: Annabel
# #158 Saved font info: Gunplay
# #159 Saved font info: More than 50.000
# #160 Saved font info: Potato Sans
# #161 Saved font info: Western Bang Bang
# #162 Saved font info: Rumble Brave
# #163 Saved font info: Mickey
# #164 Saved font info: Aurora
# #165 Saved font info: Nightside
# #166 Saved font info: Insomnia
# #167 Saved font info: Swamp Witch
# #168 Saved font info: Neon Led Light
# #169 Saved font info: Cakecafe
# #170 Saved font info: Psycho
# #171 Saved font info: Heavy Heap
# #172 Saved font info: Championship
# #173 Saved font info: Letter Magic
# #174 Saved font info: Rolner
# #175 Saved font info: Sectar
# #176 Saved font info: Snacko
# #177 Saved font info: Janda Manatee
# #178 Saved font info: Athletic
# #179 Saved font info: Super Comic
# #180 Saved font info: Milestone
# #181 Saved font info: White On Black
# #182 Saved font info: Tenar Black
# #183 Saved font info: Bleeding Cowboys
# #184 Saved font info: Patchwork Stitchlings
# #185 Saved font info: Odisean One
# #186 Saved font info: Action Comics
# #187 Saved font info: Powerpuff Girls
# #188 Saved font info: KG Chasing Cars
# #189 Saved font info: Martyric
# #190 Saved font info: 28 Days Later
# #191 Saved font info: Tropical Love
# #192 Saved font info: Docktrin
# #193 Saved font info: Wigglye
# #194 Saved font info: Huglove
# #195 Saved font info: Ghoulish Fright AOE
# #196 Saved font info: Army Rust
# #197 Saved font info: Soul Billani
# #198 Saved font info: Supersonic Rocketship
# #199 Saved font info: Happy School
# #200 Saved font info: Chaleum
# #201 Saved font info: Cheeky Rabbit
# #202 Saved font info: Pervitina Dex
# #203 Saved font info: Dezire Stacked
# #204 Saved font info: Calinastiya
# #205 Saved font info: Elegant Typewriter
# #206 Saved font info: 1942 Report
# #207 Saved font info: Margarethy
# #208 Saved font info: Bones
# #209 Saved font info: Albertson
# #210 Saved font info: ExtraBlur
# #211 Saved font info: Brandier
# #212 Saved font info: Retrolight
# #213 Saved font info: Positions
# #214 Saved font info: Sport
# #215 Saved font info: Superstar M54
# #216 Saved font info: Sirukota
# #217 Saved font info: Margin
# #218 Saved font info: Sweety Rasty
# #219 Saved font info: Retro Mario
# #220 Saved font info: Blue Custard
# #221 Saved font info: Type Machine
# #222 Saved font info: Fridge
# #223 Saved font info: Nexa Rust Slab
# #224 Saved font info: Drunk & Proud
# #225 Saved font info: Earwig Factory
# #226 Saved font info: Arco
# #227 Saved font info: DCC Ash
# #228 Saved font info: Blueberry
# #229 Saved font info: Stencilia
# #230 Saved font info: Buka Bird
# #231 Saved font info: Wicked Mouse
# #232 Saved font info: New Athletic M54
# #233 Saved font info: Charley
# #234 Saved font info: Retro Team
# #235 Saved font info: Dark College
# #236 Saved font info: Dacherry
# #237 Saved font info: Pulang
# #238 Saved font info: Bloom
# #239 Saved font info: Fragment Core
# #240 Saved font info: Bates Shower
# #241 Saved font info: Kawaii Stitch
# #242 Saved font info: Doodle Gum
# #243 Saved font info: Vtks Caminhos
# #244 Saved font info: Saiyan Sans
# #245 Saved font info: Infected
# #246 Saved font info: Bad Coma
# #247 Saved font info: Retro Groovy
# #248 Saved font info: Moon Star
# #249 Saved font info: Snowtop Caps
# #250 Saved font info: Bratsy Script
# #251 Saved font info: Cowboys
# #252 Saved font info: Neon 80s
# #253 Saved font info: Abandon
# #254 Saved font info: Halloween Too
# #255 Saved font info: Overwave
# #256 Saved font info: Space Time
# #257 Saved font info: Flower Girl
# #258 Saved font info: Silvers
# #259 Saved font info: February
# #260 Saved font info: African
# #261 Saved font info: All Rights Reserved
# #262 Saved font info: A Love of Thunder
# #263 Saved font info: Top Secret
# #264 Saved font info: Starshines
# #265 Saved font info: Agent Orange
# #266 Saved font info: Speedway
# #267 Saved font info: Bowzer
# #268 Saved font info: Vanilla Whale
# #269 Saved font info: Be True To Your School
# #270 Saved font info: Tommy
# #271 Saved font info: Bad Signal
# #272 Saved font info: Ghost Factory
# #273 Saved font info: Nightmare in Bolloland
# #274 Saved font info: Verve
# #275 Saved font info: The Last Comic On Earth
# #276 Saved font info: Palm Beach
# #277 Saved font info: Roadstore
# #278 Saved font info: Matanza Española
# #279 Saved font info: Impossible
# #280 Saved font info: Crunchy Time
# #281 Saved font info: Allstar
# #282 Saved font info: Turtles
# #283 Saved font info: Colleged
# #284 Saved font info: Nirmala
# #285 Saved font info: Academic M54
# #286 Saved font info: Fires
# #287 Saved font info: Angels
# #288 Saved font info: Minnie
# #289 Saved font info: Lemon Days
# #290 Saved font info: Red Screen Eye
# #291 Saved font info: Brightness
# #292 Saved font info: Cotton Cloud
# #293 Saved font info: Danger Zone Warning
# #294 Saved font info: Bing Bam Boum
# #295 Saved font info: Market Deco
# #296 Saved font info: Doctor Punk
# #297 Saved font info: Scare Taker
# #298 Saved font info: Eastwood
# #299 Saved font info: Alphakind
# #300 Saved font info: Wrong Delivery
# #301 Saved font info: Team 401
# #302 Saved font info: Chicago
# #303 Saved font info: Vamos por la parejita
# #304 Saved font info: Gimme Danger
# #305 Saved font info: Nightmare 5
# #306 Saved font info: McKloud
# #307 Saved font info: Stereofidelic
# #308 Saved font info: Sunday Lemon
# #309 Saved font info: Kids Magazine
# #310 Saved font info: Gruno
# #311 Saved font info: Legend M54
# #312 Saved font info: Punk Typewriter
# #313 Saved font info: Little Dog of Hell
# #314 Saved font info: Toxic Cemetery
# #315 Saved font info: Storybook
# #316 Saved font info: Manolete
# #317 Saved font info: Tales of Scare FX
# #318 Saved font info: Krabby Patty
# #319 Saved font info: Ancient Ad
# #320 Saved font info: Good Dog
# #321 Saved font info: Richu Mast
# #322 Saved font info: Broken Detroit
# #323 Saved font info: KG A Little Swag
# #324 Saved font info: Agreloy
# #325 Saved font info: DK Jambo
# #326 Saved font info: KG Blank Space
# #327 Saved font info: Sun Flower
# #328 Saved font info: Super Funky
# #329 Saved font info: Avengeance Mightiest Avenger
# #330 Saved font info: Merrycle
# #331 Saved font info: Impacted
# #332 Saved font info: Deadly Killers
# #333 Saved font info: Bubble Bobble
# #334 Saved font info: Seventies Sunrise
# #335 Saved font info: Chinese Rocks
# #336 Saved font info: Headliner No. 45
# #337 Saved font info: Dinosaur
# #338 Saved font info: Bingo
# #339 Saved font info: Finger Printed
# #340 Saved font info: Retroking
# #341 Saved font info: Vanilla Caramel
# #342 Saved font info: Shadowed Serif
# #343 Saved font info: Western
# #344 Saved font info: Stora
# #345 Saved font info: Blood Crow
# #346 Saved font info: Super Mario Bros.
# #347 Saved font info: Punkbabe
# #348 Saved font info: Glimmer Of Light
# #349 Saved font info: They Are Not
# #350 Saved font info: Lazer Game Zone
# #351 Saved font info: KG Second Chances
# #352 Saved font info: Typo Slab Irregular
# #353 Saved font info: Sweet Gentle
# #354 Saved font info: Spotyfied Me
# #355 Saved font info: Zombie Land
# #356 Saved font info: Titania
# #357 Saved font info: Riesling
# #358 Saved font info: The Modern Chaos
# #359 Saved font info: Crackvetica
# #360 Saved font info: Bobaland
# #361 Saved font info: Wildflower
# #362 Saved font info: Dulce Boy
# #363 Saved font info: M Ponderosa
# #364 Saved font info: Blood Lust
# #365 Saved font info: Air Americana
# #366 Saved font info: Super Pop Summer Fest
# #367 Saved font info: Needleteeth
# #368 Saved font info: Stella
# #369 Saved font info: Old Car
# #370 Saved font info: King
# #371 Saved font info: S&S Nickson One
# #372 Saved font info: Grinched 2.0
# #373 Saved font info: Mega Surprise
# #374 Saved font info: Meriposa
# #375 Saved font info: Paper Banner
# #376 Saved font info: War is Over
# #377 Saved font info: Mabook
# #378 Saved font info: Personal Services
# #379 Saved font info: Loud and Clear
# #380 Saved font info: Artisual Deco
# #381 Saved font info: Veteran Typewriter
# #382 Saved font info: The Devil Net
# #383 Saved font info: Alstoria
# #384 Saved font info: Sunday Sport
# #385 Saved font info: Cronos Kid
# #386 Saved font info: Run!
# #387 Saved font info: Deadwax
# #388 Saved font info: KG What the Teacher Wants
# #389 Saved font info: Marline
# #390 Saved font info: Milky Nice
# #391 Saved font info: Chubby Relief
# #392 Saved font info: Rosalia
# #393 Saved font info: Pink Chicken
# #394 Saved font info: Friday
# #395 Saved font info: Handwriting Draft
# #396 Saved font info: Nixie One
# #397 Saved font info: Monogramos
# #398 Saved font info: Quick Fox
# #399 Saved font info: Sports Jersey
# #400 Saved font info: Portentous Distorted
# #401 Saved font info: Candy Pop!
# #402 Saved font info: Zombies Reborn
# #403 Saved font info: Super Boys
# #404 Saved font info: Base 02
# #405 Saved font info: Super Bubble
# #406 Saved font info: Love Craft
# #407 Saved font info: Vintage
# #408 Saved font info: Hit me, punk!
# #409 Saved font info: Capuche
# #410 Saved font info: Tox Typewriter
# #411 Saved font info: Pencilized
# #412 Saved font info: Trash Talk
# #413 Saved font info: Arista Pro
# #414 Saved font info: LT Glockenspiel
# #415 Saved font info: Bellerose
# #416 Saved font info: Saddlebag
# #417 Saved font info: Play With Fire
# #418 Saved font info: Friday Terror
# #419 Saved font info: Polar Snow
# #420 Saved font info: Wild Trails
# #421 Saved font info: Cowboy Movie
# #422 Saved font info: The Bad & The Bunny
# #423 Saved font info: Good Summer
# #424 Saved font info: Bebalon Blue
# #425 Saved font info: Typewriter Condensed
# #426 Saved font info: A Aha Wow
# #427 Saved font info: Snowboarding
# #428 Saved font info: Budmo
# #429 Saved font info: Beautiful Friends
# #430 Saved font info: Sweet Creamy
# #431 Saved font info: Quick Love
# #432 Saved font info: Komika Title
# #433 Saved font info: Angry Birds
# #434 Saved font info: Top Secret Stamp
# #435 Saved font info: Vehicle Breaks Down
# #436 Saved font info: Butler Stencil
# #437 Saved font info: Mount Hills
# #438 Saved font info: North Korea Airlines
# #439 Saved font info: Comix Loud
# #440 Saved font info: Checkpoint Charlie
# #441 Saved font info: Splatch
# #442 Saved font info: Comic Kings
# #443 Saved font info: Simplisicky
# #444 Saved font info: Hulkbusters
# #445 Saved font info: Xilosa
# #446 Saved font info: Juniory
# #447 Saved font info: Masque
# #448 Saved font info: Ginchiest
# #449 Saved font info: Bazinga!
# #450 Saved font info: Kraash
# #451 Saved font info: Art Dystopia II
# #452 Saved font info: Awakenning
# #453 Saved font info: Hipotesis
# #454 Saved font info: Nightscary
# #455 Saved font info: Falling For Autumn
# #456 Saved font info: Corleone
# #457 Saved font info: Flame on!
# #458 Saved font info: Old School United Stencil
# #459 Saved font info: Sketch 3D
# #460 Saved font info: JMH Hallowen 2017
# #461 Saved font info: Wanted M54
# #462 Saved font info: Prisma
# #463 Saved font info: Dimbo
# #464 Saved font info: Playgram
# #465 Saved font info: Dilo World
# #466 Saved font info: Bodo Amat
# #467 Saved font info: Billo
# #468 Saved font info: Hammer Keys
# #469 Saved font info: Amperzand
# #470 Saved font info: College Block
# #471 Saved font info: Sweet Peas
# #472 Saved font info: Godzilla
# #473 Saved font info: Marons
# #474 Saved font info: Legionary
# #475 Saved font info: Writing Book
# #476 Saved font info: Hatolie
# #477 Saved font info: Varsity
# #478 Saved font info: Pincoya Black
# #479 Saved font info: Old Stamper
# #480 Saved font info: IFC Insane Rodeo
# #481 Saved font info: Bloodlust
# #482 Saved font info: Super Corn
# #483 Saved font info: f Framboz
# #484 Saved font info: Trajanus Bricks
# #485 Saved font info: BD Cartoon Shout
# #486 Saved font info: Electrical
# #487 Saved font info: Romanum Est
# #488 Saved font info: Outrun future
# #489 Saved font info: Hello Morgan
# #490 Saved font info: Unfinished Scream
# #491 Saved font info: Bulletproof
# #492 Saved font info: Sunday Grapes
# #493 Saved font info: Zombie
# #494 Saved font info: Brady Bunch Remastered
# #495 Saved font info: Aka Posse
# #496 Saved font info: Water Galon
# #497 Saved font info: Cattie
# #498 Saved font info: Yikes
# #499 Saved font info: Stencilla
# #500 Saved font info: Dotimpact
# #501 Saved font info: Fifties Movies
# #502 Saved font info: Fluo Gums
# #503 Saved font info: CF Night of Terror
# #504 Saved font info: Londrina
# #505 Saved font info: Super Comic
# #506 Saved font info: Love You
# #507 Saved font info: College Block 2.0
# #508 Saved font info: Cafe Matcha
# #509 Saved font info: Backfired
# #510 Saved font info: Green Fuz
# #511 Saved font info: 1 Punk
# #512 Saved font info: Pain Circus
# #513 Saved font info: Comic Neue Sans ID
# #514 Saved font info: Omegle
# #515 Saved font info: Dirty Brush
# #516 Saved font info: Bigfat Script
# #517 Saved font info: Kids Are The Future
# #518 Saved font info: Creepy Crawlers
# #519 Saved font info: Beachfly
# #520 Saved font info: Super Foods
# #521 Saved font info: Bubbleboddy
# #522 Saved font info: Chuck Noon
# #523 Saved font info: Young Frankenstein
# #524 Saved font info: Burn
# #525 Saved font info: Static
# #526 Saved font info: Super Woobly
# #527 Saved font info: Cheesecake
# #528 Saved font info: El Fatso
# #529 Saved font info: Nandaka Western
# #530 Saved font info: Naughty Monster
# #531 Saved font info: Rained
# #532 Saved font info: Citylist
# #533 Saved font info: Kill all Hipsters
# #534 Saved font info: Alba
# #535 Saved font info: Organic Relief
# #536 Saved font info: Nice Sugar
# #537 Saved font info: Hippie Groovy
# #538 Saved font info: Sunset Boulevard
# #539 Saved font info: Rakoon
# #540 Saved font info: Vlump
# #541 Saved font info: Elegant
# #542 Saved font info: Lemon Tea
# #543 Saved font info: SF Slapstick Comic
# #544 Saved font info: Lemon Juice
# #545 Saved font info: Darkmode
# #546 Saved font info: Guyon Gazebo
# #547 Saved font info: LT Funk
# #548 Saved font info: h Hulleah
# #549 Saved font info: SF Hollywood Hills
# #550 Saved font info: Take Cover
# #551 Saved font info: Skrapbook
# #552 Saved font info: Unthinkers
# #553 Saved font info: Bold Fashion
# #554 Saved font info: Futura Handwritten
# #555 Saved font info: Nighty
# #556 Saved font info: Baristo
# #557 Saved font info: IFC Rail Road
# #558 Saved font info: Ropest
# #559 Saved font info: Far From Homecoming
# #560 Saved font info: Vignettic
# #561 Saved font info: Pop Art
# #562 Saved font info: Comic Book
# #563 Saved font info: Mexcellent
# #564 Saved font info: Serif of Nottingham
# #565 Saved font info: Vintage Warehouse
# #566 Saved font info: Think Smart
# #567 Saved font info: Orange Milk
# #568 Saved font info: South Park
# #569 Saved font info: Tattoo Ink
# #570 Saved font info: Lost Saloon
# #571 Saved font info: Quiska
# #572 Saved font info: Avocado Creamy
# #573 Saved font info: Lovely
# #574 Saved font info: Old Typewriter
# #575 Saved font info: Tequilla Sunrise
# #576 Saved font info: Dollar Bill
# #577 Saved font info: Dynamix
# #578 Saved font info: Casino
# #579 Saved font info: High Jersey
# #580 Saved font info: True Lies
# #581 Saved font info: Pretty Girls Script
# #582 Saved font info: Young Heart
# #583 Saved font info: Starlight
# #584 Saved font info: Reglisse
# #585 Saved font info: Oceanside Typewriter
# #586 Saved font info: Mindset
# #587 Saved font info: Beckan
# #588 Saved font info: Breamcatcher
# #589 Saved font info: Athena
# #590 Saved font info: Penguin
# #591 Saved font info: Marbella Army
# #592 Saved font info: Nectarine
# #593 Saved font info: Misfits
# #594 Saved font info: Feast of Flesh BB
# #595 Saved font info: Cookies
# #596 Saved font info: XXII Ultimate Black Metal
# #597 Saved font info: Vintages
# #598 Saved font info: Crush N Burn!
# #599 Saved font info: Mothercode
# #600 Saved font info: Kingslaw
# #601 Saved font info: Youngster
# #602 Saved font info: Guevara
# #603 Saved font info: Rock's Death
# #604 Saved font info: Hand TypeWriter
# #605 Saved font info: Backcountry
# #606 Saved font info: Fright Night
# #607 Saved font info: SF Collegiate
# #608 Saved font info: Ghostbusters
# #609 Saved font info: Double Feature
# #610 Saved font info: Flux Architect
# #611 Saved font info: Indiana Jonas
# #612 Saved font info: Brighly Crush
# #613 Saved font info: Black Forest
# #614 Saved font info: Boston Traffic
# #615 Saved font info: HVD Comic Serif
# #616 Saved font info: Mystery
# #617 Saved font info: Sacred Bridge
# #618 Saved font info: Chistoso
# #619 Saved font info: A Alloy Ink
# #620 Saved font info: Evil Highway
# #621 Saved font info: A Angkatan Bersenjata
# #622 Saved font info: Happy Food
# #623 Saved font info: X Typewriter
# #624 Saved font info: Firestor
# #625 Saved font info: Flores
# #626 Saved font info: Impact Label
# #627 Saved font info: Shut'Em Down
# #628 Saved font info: Just Bubble
# #629 Saved font info: Giants
# #630 Saved font info: Bleeding Freaks
# #631 Saved font info: Janda Curlygirl
# #632 Saved font info: Kids Zone
# #633 Saved font info: Cat Paw
# #634 Saved font info: Nougat
# #635 Saved font info: College Boy
# #636 Saved font info: Break It
# #637 Saved font info: R&C
# #638 Saved font info: Jack in the Box
# #639 Saved font info: African Style
# #640 Saved font info: Neonblitz
# #641 Saved font info: Mostera
# #642 Saved font info: Planet Comic
# #643 Saved font info: Mistaken
# #644 Saved font info: Aardvark Cafe
# #645 Saved font info: Chlorinap
# #646 Saved font info: Scooby Doo
# #647 Saved font info: Collegerion
# #648 Saved font info: Wrestlemania
# #649 Saved font info: East Border
# #650 Saved font info: Paint Drops
# #651 Saved font info: Satine
# #652 Saved font info: Last Dream
# #653 Saved font info: Happy Chicken
# #654 Saved font info: Fake Identity
# #655 Saved font info: Loud Beats
# #656 Saved font info: Comicy
# #657 Saved font info: Milky Coffee
# #658 Saved font info: Ranked Sports
# #659 Saved font info: Cute Bubble
# #660 Saved font info: Bubblegums
# #661 Saved font info: Hominis
# #662 Saved font info: Malvie
# #663 Saved font info: Quacker
# #664 Saved font info: Bloodsoul
# #665 Saved font info: Trelink
# #666 Saved font info: f Foresthome
# #667 Saved font info: Char BB
# #668 Saved font info: Super Retro M54
# #669 Saved font info: Nowharehouse
# #670 Saved font info: Monogram KK
# #671 Saved font info: Old School United
# #672 Saved font info: Scream Again
# #673 Saved font info: CF Punk is not Dead
# #674 Saved font info: I Am A Player
# #675 Saved font info: Wash Your Hand
# #676 Saved font info: The Bambank Script
# #677 Saved font info: Charming Sixties
# #678 Saved font info: Magic Unicorn
# #679 Saved font info: Citylines
# #680 Saved font info: Bou College
# #681 Saved font info: KG Summer Sunshine
# #682 Saved font info: High Voltage Rough
# #683 Saved font info: Chickens Lovers
# #684 Saved font info: Wigenda Typewrite
# #685 Saved font info: Almond Nougat
# #686 Saved font info: Smile Candy
# #687 Saved font info: Bloody Terror
# #688 Saved font info: Boba Cups
# #689 Saved font info: Cursive Sans
# #690 Saved font info: Cake Bake
# #691 Saved font info: Punk Kid
# #692 Saved font info: Adam Gorry
# #693 Saved font info: Smallville
# #694 Saved font info: Excalibur Nouveau
# #695 Saved font info: Black Bubble
# #696 Saved font info: Organic Brand
# #697 Saved font info: f Foden
# #698 Saved font info: Terror Farm
# #699 Saved font info: Broken 15
# #700 Saved font info: MB Think Twice
# #701 Saved font info: New Super Mario Font U
# #702 Saved font info: Heroes Legend
# #703 Saved font info: Versa Versa
# #704 Saved font info: Beachday
# #705 Saved font info: Garden Sans
# #706 Saved font info: Corrupted File
# #707 Saved font info: Backhome
# #708 Saved font info: Pac-Font
# #709 Saved font info: Firestarter
# #710 Saved font info: Defused
# #711 Saved font info: Traveling Typewriter
# #712 Saved font info: Hatch
# #713 Saved font info: Black Santa
# #714 Saved font info: Fast Forward
# #715 Saved font info: Barcade
# #716 Saved font info: Karma
# #717 Saved font info: Big Dazzle
# #718 Saved font info: KG Lego House
# #719 Saved font info: Matrix
# #720 Saved font info: Plump
# #721 Saved font info: Ghost Shadow
# #722 Saved font info: Niñato Dreams
# #723 Saved font info: Copasetic
# #724 Saved font info: Campanile
# #725 Saved font info: Dutch & Harley
# #726 Saved font info: College Slab
# #727 Saved font info: Stanberry
# #728 Saved font info: Water Park
# #729 Saved font info: JMH Horror
# #730 Saved font info: Split On
# #731 Saved font info: Hermona
# #732 Saved font info: Spicy Pumpkin
# #733 Saved font info: La Machine Company
# #734 Saved font info: Train Letters
# #735 Saved font info: Jersey Letters
# #736 Saved font info: Extra Sales
# #737 Saved font info: Grandstander Clean
# #738 Saved font info: Cocogoose Letterpress
# #739 Saved font info: Kid Games
# #740 Saved font info: Sketchzone
# #741 Saved font info: Chalkboy
# #742 Saved font info: Bluetea
# #743 Saved font info: Socake
# #744 Saved font info: Final Fantasy
# #745 Saved font info: Les Mysteres de Paris
# #746 Saved font info: Fun Sized
# #747 Saved font info: Space Comics
# #748 Saved font info: Gecko Lunch
# #749 Saved font info: Zamruds
# #750 Saved font info: Dream to Berich
# #751 Saved font info: Super Mario 64
# #752 Saved font info: h Hidan
# #753 Saved font info: i Ighty Mighty
# #754 Saved font info: Aleator Tattoo Parlour
# #755 Saved font info: Glass
# #756 Saved font info: Nü*Creactivo 2008
# #757 Saved font info: Revista
# #758 Saved font info: Black Widow
# #759 Saved font info: Anyk
# #760 Saved font info: Art Dystopia
# #761 Saved font info: Browser
# #762 Saved font info: Avocado
# #763 Saved font info: Crushed
# #764 Saved font info: Chubby Rounded
# #765 Saved font info: Snomelt
# #766 Saved font info: Horseshoes
# #767 Saved font info: Wizards Magic
# #768 Saved font info: MetalShow
# #769 Saved font info: Powerful
# #770 Saved font info: Createland
# #771 Saved font info: Jersey 716
# #772 Saved font info: Death in Buenos Aires
# #773 Saved font info: Flamer
# #774 Saved font info: The Roots
# #775 Saved font info: Kelvinized
# #776 Saved font info: Gun Metal
# #777 Saved font info: Threed
# #778 Saved font info: Comica BD
# #779 Saved font info: Funny Kid
# #780 Saved font info: Jelly Crazies
# #781 Saved font info: JMH Typewriter Dry
# #782 Saved font info: Demode
# #783 Saved font info: Magical Night
# #784 Saved font info: Textalk
# #785 Saved font info: Sex Pistols
# #786 Saved font info: A Bite
# #787 Saved font info: Helv Children
# #788 Saved font info: Sunny Spells
# #789 Saved font info: Stay Vibes
# #790 Saved font info: Rhune Explorer
# #791 Saved font info: Got heroin?
# #792 Saved font info: Tiza
# #793 Saved font info: Doctor Soos
# #794 Saved font info: Cartonsix NC
# #795 Saved font info: DCC Cloud
# #796 Saved font info: Bubbleboddy Neue
# #797 Saved font info: Folk Festival
# #798 Saved font info: KG Do You Love Me
# #799 Saved font info: Anime Kids
# #800 Saved font info: Retropulse
# #801 Saved font info: Airstream
# #802 Saved font info: Cartoonist Kooky
# #803 Saved font info: Max Initiale
# #804 Saved font info: Face Off M54
# #805 Saved font info: Face Your Fears
# #806 Saved font info: Minecraft Evenings
# #807 Saved font info: KG Defying Gravity
# #808 Saved font info: Green Nature
# #809 Saved font info: The Barista
# #810 Saved font info: Among Us
# #811 Saved font info: Tiktok
# #812 Saved font info: Trailer Park Girl
# #813 Saved font info: Best School
# #814 Saved font info: On Fire
# #815 Saved font info: Peckham Press
# #816 Saved font info: Milk Kids
# #817 Saved font info: Millionaire
# #818 Saved font info: Ransom Note
# #819 Saved font info: Sablon Up
# #820 Saved font info: Broadway
# #821 Saved font info: Lethal Slime
# #822 Saved font info: Crack Wall
# #823 Saved font info: Oswald
# #824 Saved font info: Cakar Monyet
# #825 Saved font info: Munstar
# #826 Saved font info: f Ferent
# #827 Saved font info: Chemy Retro
# #828 Saved font info: CF National Stitches
# #829 Saved font info: MB Thin Worms
# #830 Saved font info: Dalmation
# #831 Saved font info: Haarlem Deco
# #832 Saved font info: Baby School
# #833 Saved font info: Comics Tricks
# #834 Saved font info: Sengatz
# #835 Saved font info: Devils Crew
# #836 Saved font info: Kooltura
# #837 Saved font info: TT Ramillas Initials
# #838 Saved font info: Codigra
# #839 Saved font info: Comedo
# #840 Saved font info: Inlander
# #841 Saved font info: Funtime
# #842 Saved font info: The Lithium Shop
# #843 Saved font info: Mrs. Monster
# #844 Saved font info: Ohio Collegiate
# #845 Saved font info: 212 Sports
# #846 Saved font info: Honey And Raspberries
# #847 Saved font info: Christmas Day
# #848 Saved font info: Panton Rust
# #849 Saved font info: Park Lane NF
# #850 Saved font info: Abandon
# #851 Saved font info: Ed Wood Movies
# #852 Saved font info: Vraoum
# #853 Saved font info: Bronzier
# #854 Saved font info: Stay And Shine
# #855 Saved font info: Cavalier
# #856 Saved font info: Big Bad Bugs
# #857 Saved font info: Michelia
# #858 Saved font info: Vintage Waves
# #859 Saved font info: Flintstone
# #860 Saved font info: Dirty Headline
# #861 Saved font info: Alpha Clouds
# #862 Saved font info: Ice Caps
# #863 Saved font info: Bohemian Typewriter
# #864 Saved font info: Cracked Code
# #865 Saved font info: Vintage Display
# #866 Saved font info: Stanley
# #867 Saved font info: Glasberg
# #868 Saved font info: Stars
# #869 Saved font info: Neon Sans
# #870 Saved font info: Hamston
# #871 Saved font info: Super Funtime
# #872 Saved font info: Breaker Rockin Display
# #873 Saved font info: Disko
# #874 Saved font info: Old Press
# #875 Saved font info: Just Like That
# #876 Saved font info: Broken Glass
# #877 Saved font info: D Day Stencil
# #878 Saved font info: Fiendish
# #879 Saved font info: Arastin Pro
# #880 Saved font info: Coffee Extra
# #881 Saved font info: Jumping Flash
# #882 Saved font info: Vintage College Dept
# #883 Saved font info: Cursive Serif
# #884 Saved font info: Freedom45
# #885 Saved font info: Snickers
# #886 Saved font info: Happy Cow
# #887 Saved font info: Capture Smallz
# #888 Saved font info: Snake in the Boot
# #889 Saved font info: Westmeath
# #890 Saved font info: Queen
# #891 Saved font info: Retrotype
# #892 Saved font info: Universal Ignorance
# #893 Saved font info: Water Resistant
# #894 Saved font info: Kawaii Bubble
# #895 Saved font info: Horror
# #896 Saved font info: Milky Honey
# #897 Saved font info: Boleh
# #898 Saved font info: Weird Words
# #899 Saved font info: Silent Phobia
# #900 Saved font info: Skull Bones
# #901 Saved font info: Another Brick
# #902 Saved font info: Progress
# #903 Saved font info: Sugar Bomb
# #904 Saved font info: Pesta Tahun Baru
# #905 Saved font info: Arcane Nine
# #906 Saved font info: New Blackbuster
# #907 Saved font info: Split Letras
# #908 Saved font info: Black Rat Punk Band
# #909 Saved font info: Ketchum
# #910 Saved font info: Roman New Times
# #911 Saved font info: Cinema ST
# #912 Saved font info: Horroroid
# #913 Saved font info: Chateau de Garage
# #914 Saved font info: K26 Toy Blocks 123
# #915 Saved font info: High School
# #916 Saved font info: Very Popular
# #917 Saved font info: JMH Psychedelic CAPS
# #918 Saved font info: Hackney
# #919 Saved font info: Chicken Quiche
# #920 Saved font info: Modern Prestige
# #921 Saved font info: Bromawo
# #922 Saved font info: Crayon Kids
# #923 Saved font info: Cheap Fire
# #924 Saved font info: Brutal Tooth
# #925 Saved font info: Ransom
# #926 Saved font info: Chocolate Dealer
# #927 Saved font info: Warpaint
# #928 Saved font info: Hippie Movement
# #929 Saved font info: Jackport NCV
# #930 Saved font info: Death to Metal
# #931 Saved font info: Royal King
# #932 Saved font info: Cookie
# #933 Saved font info: Water Splash
# #934 Saved font info: Spanish Circus
# #935 Saved font info: Aubergine
# #936 Saved font info: Parade Groovy
# #937 Saved font info: Super Candy
# #938 Saved font info: Coaster
# #939 Saved font info: Sketch Block
# #940 Saved font info: Dead Font Walking
# #941 Saved font info: Dark Net Warrior
# #942 Saved font info: Coiny
# #943 Saved font info: Typo Draft
# #944 Saved font info: Hooman Stitch
# #945 Saved font info: Bigilla
# #946 Saved font info: Goovy Modice
# #947 Saved font info: Circusia
# #948 Saved font info: Amina Reska
# #949 Saved font info: Happy Lucky
# #950 Saved font info: Gready
# #951 Saved font info: Bubble Shine
# #952 Saved font info: Sticky Memos
# #953 Saved font info: Catastrophic Consequences
# #954 Saved font info: IFC Los Banditos
# #955 Saved font info: Wicked Grit
# #956 Saved font info: Mikado
# #957 Saved font info: Linowrite
# #958 Saved font info: Cheap Potatoes Black
# #959 Saved font info: Candy Shop
# #960 Saved font info: Captain Redemption
# #961 Saved font info: The Rustic
# #962 Saved font info: Holyfat
# #963 Saved font info: Springwood Display
# #964 Saved font info: BoldenVan
# #965 Saved font info: Slayer movie
# #966 Saved font info: Rockwill
# #967 Saved font info: Hyperpolar Brush
# #968 Saved font info: Disco Diva
# #969 Saved font info: Splash
# #970 Saved font info: Heart Breaking Bad
# #971 Saved font info: Cloud Candy
# #972 Saved font info: Minnie
# #973 Saved font info: Comical Cartoon
# #974 Saved font info: Dragon Ball
# #975 Saved font info: Bubble 3D
# #976 Saved font info: Shiny Signature
# #977 Saved font info: Cartoon Fun
# #978 Saved font info: Cosmic Blaster
# #979 Saved font info: Watcher
# #980 Saved font info: Second Hand Campus
# #981 Saved font info: Taco Crispy
# #982 Saved font info: Snackid
# #983 Saved font info: Schluber
# #984 Saved font info: Papel Picado
# #985 Saved font info: KG Corner of the Sky
# #986 Saved font info: Punktype
# #987 Saved font info: DK Frozen Memory
# #988 Saved font info: Buffalo
# #989 Saved font info: Oaklash
# #990 Saved font info: Baby Bunny Script
# #991 Saved font info: Panic Room
# #992 Saved font info: Cute Decor
# #993 Saved font info: h Hutaner
# #994 Saved font info: Samdan
# #995 Saved font info: Roman Antique
# #996 Saved font info: Unquiet Spirits
# #997 Saved font info: Fool For Love
# #998 Saved font info: Campus A
# #999 Saved font info: Atlantic Cruise
# #1000 Saved font info: No Safety Zone
# #1001 Saved font info: Blood'n Guts
# #1002 Saved font info: Handwriting Black Draft
# #1003 Saved font info: Sporter
# #1004 Saved font info: Victorian Decade
# #1005 Saved font info: Fidalga
# #1006 Saved font info: Baby Monsta
# #1007 Saved font info: Empirez
# #1008 Saved font info: Batik Worldwide
# #1009 Saved font info: Kids Monday
# #1010 Saved font info: Kamryn
# #1011 Saved font info: Scramble Storm
# #1012 Saved font info: Glitching
# #1013 Saved font info: Hanging Lights
# #1014 Saved font info: Realitas
# #1015 Saved font info: Dead Kansas
# #1016 Saved font info: Emilio 20
# #1017 Saved font info: PatchFun
# #1018 Saved font info: High Jakarta
# #1019 Saved font info: Crazy Sixties
# #1020 Saved font info: Balloons!
# #1021 Saved font info: Comic Shark
# #1022 Saved font info: Snorter
# #1023 Saved font info: Mat Saleh
# #1024 Saved font info: Happy Shop
# #1025 Saved font info: Kidsco
# #1026 Saved font info: 3D Sports Bar
# #1027 Saved font info: Gloomy Things
# #1028 Saved font info: Pretty Garden Serif
# #1029 Saved font info: f Foundas
# #1030 Saved font info: Helsinki
# #1031 Saved font info: Mulan
# #1032 Saved font info: Fontdinerdotcom Sparkly
# #1033 Saved font info: Rockin Record G
# #1034 Saved font info: The Minion
# #1035 Saved font info: Shaka Pow
# #1036 Saved font info: Prequel
# #1037 Saved font info: Bykars
# #1038 Saved font info: Best Kids
# #1039 Saved font info: Fiesta Rumba
# #1040 Saved font info: Patched
# #1041 Saved font info: Circus World
# #1042 Saved font info: Pio Serif
# #1043 Saved font info: Neon Lights
# #1044 Saved font info: Zallman Caps
# #1045 Saved font info: Carnival
# #1046 Saved font info: Zou
# #1047 Saved font info: Come With Us
# #1048 Saved font info: Fanzine Title
# #1049 Saved font info: Vanished
# #1050 Saved font info: Astounding news
# #1051 Saved font info: Round Monogram
# #1052 Saved font info: Xbones
# #1053 Saved font info: Bittermilk
# #1054 Saved font info: Candy Cake
# #1055 Saved font info: Castlefire
# #1056 Saved font info: Magic Sparkle
# #1057 Saved font info: Leorio
# #1058 Saved font info: Amnestia Distressed
# #1059 Saved font info: Youtube Star
# #1060 Saved font info: Quicksilver
# #1061 Saved font info: Urzeit
# #1062 Saved font info: Meglona
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[37], line 22
#      17 font_urls = [element.select_one('div.lv1left > a')['href'] for element in elements_lv1left_dfbg]
#      20 for font_url in font_urls:
#      21     # 추출한 url에 따라 페이지 방문
# ---> 22     driver.get(f"{base_url}/{font_url}")
#      24     font_detail_soup = BeautifulSoup(driver.page_source, 'html.parser')
#      26     # 폰트 정보 수집 후 저장
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:333, in WebDriver.get(self, url)
#     329 def get(self, url):
#     330     """
#     331     Loads a web page in the current browser session.
#     332     """
# --> 333     self.execute(Command.GET, {'url': url})
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: Navigation timed out after 300000 ms
