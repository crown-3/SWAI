# %% [markdown]
# # NLP(Natural Language Processing)

# %% [markdown]
# # 크롤링한 데이터 파일을 이용한 한국어 분석

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 1. 한국어 분석에 필요한 모듈 임포트하기
# </span>

# %%
from konlpy.tag import *      
import pandas as pd

#konlpy.tag 에서 제공되는 함수 Okt(), Kkma( ) 호출 
okt = Okt() 
kkma = Kkma( )

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 2. 한국어 데이터셋에서 문장 추출하기
# </span>

# %% [markdown]
# <span style="color:blue; font-size: 14pt">
# 데이터셋 파일을 pandas를 활용하여 읽기  <b>(return type - DataFrame)
# </span>

# %% [markdown]
# <span style="color:#0000ff">
# ● pandas에서 제공하는 read_csv()함수, read_excel()함수는 데이터를 읽어서 DataFrame타입으로 리턴한다.
# </span>

# %%
file_path = "자연어처리.csv"
data_read = pd.read_csv(file_path, encoding='utf-8')  

#file_path = "자연어처리.xlsx"
#data_read = pd.read_excel(file_path)  

print(type(data_read))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_read
# Out:
#      번호                                        제목  \
# 0     1                        트링크AI는 지역관광 솔루션입니다
# 1     2                      패스트캠퍼스 챌린지 10일차(수요일)
# 2     3        다급한 기업, IT인재 직접 키워…컴공·전산 서울 대졸자 추월
# 3     4  2021년 11월 9일 상한가(갤럭시아에스엠, 셀바스AI, 하이트론...
# 4     5                     인공지능을 넘어 인공자아의 시대로 도약
# ..  ...                                       ...
# 95   96                  딥러닝, 머신러닝, 인공지능 차이점 알아보기
# 96   97                  과기정통부, ‘인공지능 그랜드 챌린지’ 진행
# 97   98                   콴다라는 별이 뜨고 메가스터디는 지고 있네
# 98   99    수지군청 전화안내시스템에 음성합성기 ReadSpeaker™ 혜련...
# 99  100          AI그랜드 챌린지, 원자력연-젠티연합팀 1위로 3단계 진출
#
#                                                    내용  \
# 0   텍스트 마이닝, 대화형 자연어 처리 기술로 강화된 인공지능이 해답을 제시합니다. 3...
# 1   ly/3FVdhDa #패스트캠퍼스 #패캠챌린지 #직장인인강 #직장인자기계발 #패스트...
# 2   이 프로그램은 자연어 처리 기법을 활용해 법률 문서의 내용이 잘 요약된 문장을......
# 3   음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제...
# 4   일각에서는 2032년이면 GPT-3보다 1000배의 학습처리능력을 가진 인공지능이 ...
# ..                                                ...
# 95  자연어 처리 4. 추천시스템 이렇게 4가지 분야에서 다양하게 사용되고 있더라고요. ...
# 96  5차 대회는 AI 기술을 활용한 수학 문제 해결을 주제로, 자연어 이해와 수리적.....
# 97  요새는 자연어처리 AI를 통해 문자로 하는 질문에 대해서도 답변할 수 있도록 하는 ...
# 98  성우, #자연어처리, #TTS프로그램, #콜센터, #아나운서, #영어 교육, #DN...
# 99  5차 대회는 자연어의 이해와 수리적 사고 추론에 기반한 복합지능 기술 확보를... ...
#
#                                      작성자     작성일
# 0                                 t-link  21시간 전
# 1                           HELLO WORLD!  22시간 전
# 2                                 긍정적 변수  23시간 전
# 3                      흔하디 흔한 아카시아꿀의 이야기      어제
# 4                         IITP 정보통신기획평가원      어제
# ..                                   ...     ...
# 95                                   티오더    6일 전
# 96                                  뉴스앤잡    6일 전
# 97                       거인의 어깨에 올라 부자되기    6일 전
# 98  A Global leader of voice technology.    6일 전
# 99                             국가과학기술연구회    6일 전
#
# [100 rows x 5 columns]

# %%
data_title = data_read['제목'].values  #제목 부분만 추출 

print('●  데이터 타입 : ', type(data_title))  #데이터 타입 numpy.ndarray
print('●  제목 개수 : ', len(data_title)) 
print('● ', data_title)
# Out:
# ●  데이터 타입 :  <class 'numpy.ndarray'>
# ●  제목 개수 :  100
# ●  ['트링크AI는 지역관광 솔루션입니다' '패스트캠퍼스 챌린지 10일차(수요일)'
#  '다급한 기업, IT인재 직접 키워…컴공·전산 서울 대졸자 추월'
#  '2021년 11월 9일 상한가(갤럭시아에스엠, 셀바스AI, 하이트론...' '인공지능을 넘어 인공자아의 시대로 도약'
#  '[디지털 시대의 전공들] 중앙대학교 소프트웨어 학부' '셀바스AI-우리가 모르는 메타버스 수혜주, 절대적 저평가...'
#  'NVIDIA, 신규 Jetson AGX Orin 공개' '메타버스 관련주로 떠오르는 셀바스AI +78% 성공'
#  '[GIP 뉴스레터_11월 2주] 넷플릭스가 게임 만든다고?' '[자바공부] 자바알고리즘이란 무엇인가?'
#  '파이썬의 강력함을 느낄 수 있는 「한 권으로 다지는 머신...' '11/10 주린이의 받아쓰는 시황정리(feat. 삼프로 tv)'
#  '[월230/수원] 삼성전기 AI인공지능 챗봇 트레이너'
#  "[영상] 전상호 코어에이아이(kore.ai,) 상무, '대화형 AI..." '빅 데이터란? 특징과 의미를 알아봅니다.'
#  '[개발 2유닛] 무하유의 서비스를 만들어가는 “서비스...' '[에임리치] 비트코인 시총 3조 달러 근접… ‘ETH’ 급등...'
#  '11월 10일 삼프로 티비 - 월가모닝라이브, 오늘아침라이브' '"공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼...'
#  'Meta의 AI 전략 (AI 시리즈 1)' '21,11,10 검색조회수가장많은 단어키워드 상위노출유입분석'
#  '멀티캠퍼스 인공지능 자연어처리(NLP) 기반 기업 데이터 분석...'
#  '(211109) 셀바스AI - 우리가 모르는 메타버스 수혜주, 절대적...'
#  '셀바스AI 주가 전망 : 인공지능, 메타버스, 음성인식 관련주' '2021/11/09'
#  '마이크로소프트(MSFT)도 메타버스에 합류! 그에 대한 완벽 분석!' '셀바스AI 주가 숨겨진 메타버스 수혜주 기대감에 상한가'
#  'AI 최강의 수업' '[경북대학교 데이터융합연구원] 2021년 고용노동부 K...' '21년 11월 9일 화 주식시황'
#  '아진산업,하이트론,제일테크노스,셀바스AI' '프로그래밍 언어의 간추린 역사'
#  '[Kore.ai XO Platform Release v9.1] 100개 이상 언어로...'
#  '상한가(11월9일),갤럭시아에스이엠/하이트론...' '[2021 금융산업 전문인력 AI 역량강화] #온라인으로_배우는...'
#  '셀바스AI 메타버스 가상 캐릭터와 소통하는 AI음성인식기술로...'
#  '[가까운 책] 트렌드코리아 2022 - 김난도, 전미영, 최지혜 외' '셀바스AI 주가 상한가 메타버스 음성인식'
#  '[재벌투자연구소 투자정보]-장중에 78%로 수익매도#셀바스AI' '가을의 기록'
#  '기술평가 A, AA 등급을 받고 기술특례상장 초읽기에 들어간...'
#  '품절주 관련주, 하이트론 주가,이재명 후보 수술실 관련 발언...'
#  '경북대학교, K-Digital Training 빅데이터 분석가 양성과정'
#  '<그냥 하지 말라> | 빅데이터 전문가 송길영 부사장이 말하는...' '콘텐츠 홍수 속, 플랫폼이 필요해'
#  '기 들릴(Guy Delisle) - 평양(Pyongyang) (2003)'
#  '엔비디아 GTC 컨퍼런스 개최 (feat. 무료 등록방법)' '중국 빅테크, 반도체 자체 개발에 나서는 이유'
#  '키플홀딩스 장외주식매도매수문의' '매일매일 경제노트(2021년11월3일)'
#  '치매 예방부터 돌봄까지…AI로 어르신 건강·안전 지키는 광주...'
#  '"전문가 수준의 영어 문제, AI가 5초 만에 제작"...이형종...'
#  '초거대 AI 개발에 한창인 LG, 계열사별 AI 연구 상황은?' '[사주임의 전략소개 #11] Ai주식자동매매프로그램의...'
#  '마이크로소프트 3D 아바타 회의/매타버스, 인공지능AI GPT-3...' '딥 러닝 - fastai 를 이용한 예제'
#  '2021. 11. 8' '마이크로소프트의 또 다른 전략'
#  '[SBA 새싹(SeSAC) X 솔트룩스] 취업연계 인공지능 SW교육...'
#  'AI 스타트업, 브랜드 포지셔닝부터 제대로 <#솔트룩스>' '기계번역 솔루션 랭귀지 위버 CASE STUDY :: 한화 디펜스'
#  'nlp ALBERT 논문 정리(논문 리뷰) - A Lite BERT for...' '인간보다 우월한 AI, 축복인가 재앙인가'
#  '마인즈랩공모주 분석 : 상담도 AI로' "Tech Trends_VR 비즈니스 동향 ('211112)_MS도 메타버스 진격..."
#  '211108 2022년 전망~ 어떤 섹터, 종목들이 괜찮을지? 한번...'
#  '[기업분석] 셀바스AI - 절대적 저평가 상태인 메타버스...' 'GPT-1, BERT, GPT-2 모델 이해'
#  '11월 8일~11월12일(11월2주차)주요 증시일정-엔비디아...' '자료구조 총정리' 'Transformer 이론 및 구성요소'
#  '[셀바스AI] 메타버스의 잠재력을 가진 AI기업' '메타버스 영향력, 기대, 평가, 취약점, 필요요소, 전망 등...'
#  '[Book]AI 101, 인공지능 비즈니스의 모든 것' '[3줄 독후감] 네이버 vs 카카오'
#  'IONQ(아이온큐) - 투자설명서 2편 (사업편)' '인공지능개발 에이아이글로벌 !'
#  '[에이블런] 소셜 빅데이터 분석캠프_에이블캠프 체험활동단 1주차' '빅데이터 분석과 R 10편, 빅데이터 관련 용어 이해'
#  'GM 크루즈 인베스터데이Under the Hood 2021: 자율주행...'
#  '뤼이드, 교육 AI 학습 효과 입증에서 신뢰기반 구축까지 다각적...' '패스트캠퍼스 챌린지 6일차(토요일)'
#  '[자연어처리] 자연어처리를 위한 KoNLPy 설치' '자연어 처리 논문 분석 주제 - Opinion Mining and...'
#  '다음주 정부부처 일정 및 주식/증시 일정 소개(11/8~11/12)'
#  '[2022 대선 후보 분석 15화] 민주당 이재명 VS 국민의힘 윤석열...'
#  '11월 공모주 일정 ( 트윔, 마인즈랩, 알비더블유, 바이옵트로...'
#  '쏘나타 장기렌트_비교견적을 통해 착한 가격으로 스마트하게...' '패스트캠퍼스 챌린지 5일차'
#  "[IT 소식] 젠슨 황 엔비디아 CEO, 'GTC' 기조연설 나선다…AI..."
#  '마이크로소프트(MSFT) 주가: 마소도 메타버스, 인공지능(AI)...'
#  '인공지능 대규모(그랜드) 도전잇기(챌린지) 5차대회 2단계...'
#  '[ESG/투자] 팬데믹 시대가 일깨워준 지속가능한 투자의 중요성'
#  '[물류매거진] CJ대한통운 / 택배기사 돕는 ‘AI 비서’ 도입' '딥러닝, 머신러닝, 인공지능 차이점 알아보기'
#  '과기정통부, ‘인공지능 그랜드 챌린지’ 진행' '콴다라는 별이 뜨고 메가스터디는 지고 있네'
#  '수지군청 전화안내시스템에 음성합성기 ReadSpeaker™ 혜련...'
#  'AI그랜드 챌린지, 원자력연-젠티연합팀 1위로 3단계 진출']

# %%
num = 1
for i in data_title  :
    print('제목', num, ')', i)
    num += 1
# Out:
# 제목 1 ) 트링크AI는 지역관광 솔루션입니다
# 제목 2 ) 패스트캠퍼스 챌린지 10일차(수요일)
# 제목 3 ) 다급한 기업, IT인재 직접 키워…컴공·전산 서울 대졸자 추월
# 제목 4 ) 2021년 11월 9일 상한가(갤럭시아에스엠, 셀바스AI, 하이트론...
# 제목 5 ) 인공지능을 넘어 인공자아의 시대로 도약
# 제목 6 ) [디지털 시대의 전공들] 중앙대학교 소프트웨어 학부
# 제목 7 ) 셀바스AI-우리가 모르는 메타버스 수혜주, 절대적 저평가...
# 제목 8 ) NVIDIA, 신규 Jetson AGX Orin 공개
# 제목 9 ) 메타버스 관련주로 떠오르는 셀바스AI +78% 성공
# 제목 10 ) [GIP 뉴스레터_11월 2주] 넷플릭스가 게임 만든다고?
# 제목 11 ) [자바공부] 자바알고리즘이란 무엇인가?
# 제목 12 ) 파이썬의 강력함을 느낄 수 있는 「한 권으로 다지는 머신...
# 제목 13 ) 11/10 주린이의 받아쓰는 시황정리(feat. 삼프로 tv)
# 제목 14 ) [월230/수원] 삼성전기 AI인공지능 챗봇 트레이너
# 제목 15 ) [영상] 전상호 코어에이아이(kore.ai,) 상무, '대화형 AI...
# 제목 16 ) 빅 데이터란? 특징과 의미를 알아봅니다.
# 제목 17 ) [개발 2유닛] 무하유의 서비스를 만들어가는 “서비스...
# 제목 18 ) [에임리치] 비트코인 시총 3조 달러 근접… ‘ETH’ 급등...
# 제목 19 ) 11월 10일 삼프로 티비 - 월가모닝라이브, 오늘아침라이브
# 제목 20 ) "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼...
# 제목 21 ) Meta의 AI 전략 (AI 시리즈 1)
# 제목 22 ) 21,11,10 검색조회수가장많은 단어키워드 상위노출유입분석
# 제목 23 ) 멀티캠퍼스 인공지능 자연어처리(NLP) 기반 기업 데이터 분석...
# 제목 24 ) (211109) 셀바스AI - 우리가 모르는 메타버스 수혜주, 절대적...
# 제목 25 ) 셀바스AI 주가 전망 : 인공지능, 메타버스, 음성인식 관련주
# 제목 26 ) 2021/11/09
# 제목 27 ) 마이크로소프트(MSFT)도 메타버스에 합류! 그에 대한 완벽 분석!
# 제목 28 ) 셀바스AI 주가 숨겨진 메타버스 수혜주 기대감에 상한가
# 제목 29 ) AI 최강의 수업
# 제목 30 ) [경북대학교 데이터융합연구원] 2021년 고용노동부 K...
# 제목 31 ) 21년 11월 9일 화 주식시황
# 제목 32 ) 아진산업,하이트론,제일테크노스,셀바스AI
# 제목 33 ) 프로그래밍 언어의 간추린 역사
# 제목 34 ) [Kore.ai XO Platform Release v9.1] 100개 이상 언어로...
# 제목 35 ) 상한가(11월9일),갤럭시아에스이엠/하이트론...
# 제목 36 ) [2021 금융산업 전문인력 AI 역량강화] #온라인으로_배우는...
# 제목 37 ) 셀바스AI 메타버스 가상 캐릭터와 소통하는 AI음성인식기술로...
# 제목 38 ) [가까운 책] 트렌드코리아 2022 - 김난도, 전미영, 최지혜 외
# 제목 39 ) 셀바스AI 주가 상한가 메타버스 음성인식
# 제목 40 ) [재벌투자연구소 투자정보]-장중에 78%로 수익매도#셀바스AI
# 제목 41 ) 가을의 기록
# 제목 42 ) 기술평가 A, AA 등급을 받고 기술특례상장 초읽기에 들어간...
# 제목 43 ) 품절주 관련주, 하이트론 주가,이재명 후보 수술실 관련 발언...
# 제목 44 ) 경북대학교, K-Digital Training 빅데이터 분석가 양성과정
# 제목 45 ) <그냥 하지 말라> | 빅데이터 전문가 송길영 부사장이 말하는...
# 제목 46 ) 콘텐츠 홍수 속, 플랫폼이 필요해
# 제목 47 ) 기 들릴(Guy Delisle) - 평양(Pyongyang) (2003)
# 제목 48 ) 엔비디아 GTC 컨퍼런스 개최 (feat. 무료 등록방법)
# 제목 49 ) 중국 빅테크, 반도체 자체 개발에 나서는 이유
# 제목 50 ) 키플홀딩스 장외주식매도매수문의
# 제목 51 ) 매일매일 경제노트(2021년11월3일)
# 제목 52 ) 치매 예방부터 돌봄까지…AI로 어르신 건강·안전 지키는 광주...
# 제목 53 ) "전문가 수준의 영어 문제, AI가 5초 만에 제작"...이형종...
# 제목 54 ) 초거대 AI 개발에 한창인 LG, 계열사별 AI 연구 상황은?
# 제목 55 ) [사주임의 전략소개 #11] Ai주식자동매매프로그램의...
# 제목 56 ) 마이크로소프트 3D 아바타 회의/매타버스, 인공지능AI GPT-3...
# 제목 57 ) 딥 러닝 - fastai 를 이용한 예제
# 제목 58 ) 2021. 11. 8
# 제목 59 ) 마이크로소프트의 또 다른 전략
# 제목 60 ) [SBA 새싹(SeSAC) X 솔트룩스] 취업연계 인공지능 SW교육...
# 제목 61 ) AI 스타트업, 브랜드 포지셔닝부터 제대로 <#솔트룩스>
# 제목 62 ) 기계번역 솔루션 랭귀지 위버 CASE STUDY :: 한화 디펜스
# 제목 63 ) nlp ALBERT 논문 정리(논문 리뷰) - A Lite BERT for...
# 제목 64 ) 인간보다 우월한 AI, 축복인가 재앙인가
# 제목 65 ) 마인즈랩공모주 분석 : 상담도 AI로
# 제목 66 ) Tech Trends_VR 비즈니스 동향 ('211112)_MS도 메타버스 진격...
# 제목 67 ) 211108 2022년 전망~ 어떤 섹터, 종목들이 괜찮을지? 한번...
# 제목 68 ) [기업분석] 셀바스AI - 절대적 저평가 상태인 메타버스...
# 제목 69 ) GPT-1, BERT, GPT-2 모델 이해
# 제목 70 ) 11월 8일~11월12일(11월2주차)주요 증시일정-엔비디아...
# 제목 71 ) 자료구조 총정리
# 제목 72 ) Transformer 이론 및 구성요소
# 제목 73 ) [셀바스AI] 메타버스의 잠재력을 가진 AI기업
# 제목 74 ) 메타버스 영향력, 기대, 평가, 취약점, 필요요소, 전망 등...
# 제목 75 ) [Book]AI 101, 인공지능 비즈니스의 모든 것
# 제목 76 ) [3줄 독후감] 네이버 vs 카카오
# 제목 77 ) IONQ(아이온큐) - 투자설명서 2편 (사업편)
# 제목 78 ) 인공지능개발 에이아이글로벌 !
# 제목 79 ) [에이블런] 소셜 빅데이터 분석캠프_에이블캠프 체험활동단 1주차
# 제목 80 ) 빅데이터 분석과 R 10편, 빅데이터 관련 용어 이해
# 제목 81 ) GM 크루즈 인베스터데이Under the Hood 2021: 자율주행...
# 제목 82 ) 뤼이드, 교육 AI 학습 효과 입증에서 신뢰기반 구축까지 다각적...
# 제목 83 ) 패스트캠퍼스 챌린지 6일차(토요일)
# 제목 84 ) [자연어처리] 자연어처리를 위한 KoNLPy 설치
# 제목 85 ) 자연어 처리 논문 분석 주제 - Opinion Mining and...
# 제목 86 ) 다음주 정부부처 일정 및 주식/증시 일정 소개(11/8~11/12)
# 제목 87 ) [2022 대선 후보 분석 15화] 민주당 이재명 VS 국민의힘 윤석열...
# 제목 88 ) 11월 공모주 일정 ( 트윔, 마인즈랩, 알비더블유, 바이옵트로...
# 제목 89 ) 쏘나타 장기렌트_비교견적을 통해 착한 가격으로 스마트하게...
# 제목 90 ) 패스트캠퍼스 챌린지 5일차
# 제목 91 ) [IT 소식] 젠슨 황 엔비디아 CEO, 'GTC' 기조연설 나선다…AI...
# 제목 92 ) 마이크로소프트(MSFT) 주가: 마소도 메타버스, 인공지능(AI)...
# 제목 93 ) 인공지능 대규모(그랜드) 도전잇기(챌린지) 5차대회 2단계...
# 제목 94 ) [ESG/투자] 팬데믹 시대가 일깨워준 지속가능한 투자의 중요성
# 제목 95 ) [물류매거진] CJ대한통운 / 택배기사 돕는 ‘AI 비서’ 도입
# 제목 96 ) 딥러닝, 머신러닝, 인공지능 차이점 알아보기
# 제목 97 ) 과기정통부, ‘인공지능 그랜드 챌린지’ 진행
# 제목 98 ) 콴다라는 별이 뜨고 메가스터디는 지고 있네
# 제목 99 ) 수지군청 전화안내시스템에 음성합성기 ReadSpeaker™ 혜련...
# 제목 100 ) AI그랜드 챌린지, 원자력연-젠티연합팀 1위로 3단계 진출

# %%
data_contents = data_read['내용'].values  #내용 부분만 추출 

print('●  데이터 타입 : ', type(data_contents))  #데이터 타입 numpy.ndarray
print('●  내용 개수 : ', len(data_contents))  
print('● ', data_contents )
# Out:
# ●  데이터 타입 :  <class 'numpy.ndarray'>
# ●  내용 개수 :  100
# ●  ['텍스트 마이닝, 대화형 자연어 처리 기술로 강화된 인공지능이 해답을 제시합니다. 3. 모든 담당자가 쉽게 인사이트를 활용할 수 있도록 시각화 자료를 제공합니다....'
#  'ly/3FVdhDa #패스트캠퍼스 #패캠챌린지 #직장인인강 #직장인자기계발 #패스트캠퍼스후기 #김기현의딥러닝을활용한자연어처리입문올인원패키지Online'
#  '이 프로그램은 자연어 처리 기법을 활용해 법률 문서의 내용이 잘 요약된 문장을... 신경망처리장치(NPU) 개발을 위 해선 컴퓨터공학을 비롯한 소프트웨어에 대한...'
#  '음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공하고... 이 회사는 건축용 자재를 제조하는 데크 플레이트 부문, 조선용 철판을 표면처리...'
#  '일각에서는 2032년이면 GPT-3보다 1000배의 학습처리능력을 가진 인공지능이 탄생할... 또한, 일반 상식에 대한 이미지나 자연어 처리가 가능하도록, 상식을 객관적으로...'
#  '영상처리 4학년 캡스톤디자인(2), 멀티코어컴퓨팅, 무선이동통신, 네트워크응용설계, 정보보호이론, 생체인식및응용, 자연어처리및정보검색, 패턴인식, 컴퓨터비전...'
#  '음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고 있다. 셀바스AI의 음성기술을 주목해야한다. 각 도메 인별 데이터 학습을 통해 98...'
#  '향상된 처리능력, 이전 세대인 Jetson AGX Xavier의 폼팩터 및 핀에 대한... 이는 개발자가 자연어 이해, 3D 인식, 멀티센서 퓨전 등과 관련된 엣지(edge)...'
#  '영상지능, 자연어처리 등 HCI 기술 경쟁력을 강화하고 있다고 재벌투자연구소 전문가분께서 알려주셨습니다 주식 후기에서 가장 중요한 수익 이야기를 해볼까...'
#  '대표적으로 신약개발, 배터리 성능 개선, 날씨 예측, 주식 선별, 양자 자연어처리, 이동경로 최적화, 교통 관리, 데이터 보호 등 생활과 밀접한 기술에 양자 컴퓨터가...'
#  '컴퓨터는 정확하게 무엇을 해야 할지 처리 내용과 처리 순서를 모두 구체적으로... 알고리즘은 자연어, 의사코드, 순서도, 프로그래밍 언어 등으로 표현이 가능합니다....'
#  '▶ 심층 신경망(DNN) 처리 ▶ 자연어 처리 ▶ 편미분 방정식 ▶ 추상화 ▶ 이미지... 주요 역할: 데이터 조작 및 분석 NLTK NLTK는 Natural Language Toolkit(자연어 툴킷)의...'
#  'AI, 자연어 처리 기술 - 로보틱스, 헬스케어, 자율주행 관련 AI 기술 - 메타버스를 위한 새로운 애플리케이션 - 공장도시 및 지역 디지털 트윈 구축 =>딥러닝...'
#  '20년간 자체 개발한 자연어처리기술과 머신러닝, 텍스트마이닝, 의미분석 및 검색 등이 복합적으로 융합된 인공지능 기반 하이브리드 챗봇 솔루션입니다....'
#  'kr) #데모 #코어에이아이 #원격지원 #챗봇 #IVR #컨택센터 #자연어처리... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...'
#  '학습, 자연어 처리, 패턴 인식 등이 분석 기법에 해당한다. 복잡성(Complexity) 데이터의 구조나 데이터의 획득과 처리에 드는 속도, 도메인 규칙이나, 저장 타입 등...'
#  '민프로 저는 ‘자연어를 이해하는 AI 기술 기업, 무하유’라는 회사 슬로건을 보고... 서비스에 문장 처리 기술과 AI 기술을 적용시키는 좋은 경험을 할 수 있고요....'
#  "예산법안을 처리한 것이 증시에 호재로 작용하면서 소폭 상승 마감했다.... 추출하여 자연어 처리방식으로 실시한 '비트코인'(bitcoin)라는 단어에 대한..."
#  '대화형AI, 자연어 처리기술, 로보틱스, 헬스케어, 자율주행 관련기술 메타버스를 위한 새로운 어플리케이션 공장도시 및 지역 디지털 트윈 구축 -딥 러닝...'
#  '제목: "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼 절대 공식 저자: 양자학파 출판: 미디어숲 발매: 2021. 11. 10 저자 : 양자학파 양자학파는 자연 과학(수학...'
#  'Natural Language Processing Natural Language, 즉 인간이 사용하는 자연어를 처리하는 기술입니다. 언어 장벽을 허물고 어떤 언어를 사용하든 누구와 대화하든 쉽게...'
#  '16% 자연어 처리 국어 0.16% 전자순찰 tcr-200 0.16% 토카막 네트워크 0.16% 폐기물이 에너지로 변환 미분방정식 0.16% 홍합 접착 단백질 0.16...'
#  "단순히 '인공지능 자연어처리'라는 키워드만 보고 바로 지원했고, NLP가 무엇인지도 모르는 상태였다. 개념적인 내용은 블로그, 유튜브를 통해 공부하고 있었지만..."
#  '(TTS), 자연어처리, 필기인식 등 AI솔루션 제공 └ 국내 최고 음성인식률 보유, 음성합성 기술 M/S 60%로 국내 1위 └ 쌍방향커뮤니케이션 핵심기술인 음성기술을...'
#  '영상지능, 자연어처리 등 HCI 기술 경쟁력을 가오하하고 있음 - 음성합성... 마우스, 키보드 등 전통적인 컴퓨터 입력장치가 음성인식, 음성합성, 자여어처리...'
#  '흘러흘러 자연어처리 딥러닝을 하는중이다. 문제는 단기간에 계속 효율이 안나와서 열심히 자신과의 싸움중 나무만보고 숲은 못본다는게 이런 경우인거같다 내년쯤 이...'
#  '☆ Azure Open AI Service 현존 최대 자연어 처리 프로그램인 GPT-3 API를 클라우드 기반으로 제공합니다. 즉, 애저를 사용하면 고객 서비스 로그 상의 공통된 불만사항을...'
#  '음성합성, 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을 주목해야 한다고 합니다 각 도메인별 데이터 학습을 통해 98% 이상의 국내 최고 음성...'
#  '전처리 방법이라고 볼 수 있다. 차원 감소를 위 해서는 주성분 분석... - 자연어는 애매하다. 상황에 따라 단어의 역할, 의미가 달라진다. 의미만 전달하는 것이 아니라...'
#  '데이터 처리 라이브러리 Pandas ▶ 데이터 크롤링정제 등 총 256시간 진행된다. 심화과정은 47일 동안 ▶ 빅데이터 통계기본 ▶ 자연어 처리 ▶ 데이터 분석...'
#  '#코스피#코스닥#상한가 21년 11월 9일 화요일 주식시황입니다. 양대 지수 모두 소폭 상승하면서 강보합입니다. 코스피는 여전히 하락하는 중이고 코스닥은 옆으로...'
#  '표면처리(Shot Blast) 및 절단가공(Steel Cutting)하는 조선부문으로 사업을 영위하고... (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을...'
#  '상당부분 자연어에 의존하며, 포트란에 비해 많은 양의 데이터를 처리하도록 설계됐다. 코볼은 처음 등장한 후 가장 널리 사용되는 프로그램 언어 중 하나로...'
#  '컨택센터 #자연어처리 #챗봇솔루션 #자동응답서비스 #AI비서 #KOREAI #코어AI... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...'
#  '셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을... 표면처리·절단가공하는 조선부문 등을 영위하고 있습니다. 이 회사의 박정식...'
#  'OCR, 자연어 처리 등 딥러닝을 통해 해결한 문제 소개 코스 2 소개 페이지 ♂? 수강하러 가기 ♀? 코스 3. 간편결제 및 자산관리 사례 ? 디지털 전환을 통한...'
#  '셀바스AI는 AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을 제공하는 업체다. 최근 증권가에서 셀바스AI가 주목받는 건 메타버스 내에서 셀바스AI...'
#  '빅데이터 자연어 처리NLP 등 데이터를 다양한 관점에서 분석하고 있다. 코오롱-카이스트 라이프스타일 이노베이션 최우수상을 수상했다. 저자 : 권정윤...'
#  '영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음.... 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을...'
#  '동사는 22년간의 지속적인 연구개발 투자를 통해 음성지능, 필기지능, 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음....'
#  '회사에서 자연어처리 특강을 하는데 나는 1도 모르겠다.. 꼭 배워야할 것 같은데 과외를 해야나아 ㅋㅋㅋㅋ.. 유투브 열심히보면 알 수 있지않나여? 하핳,, 어렵네여 진짜...'
#  '음성인식과 자연어처리(NLP) 등의 기술을 이전 받아 다양한 분야의 첨단 AI 서비스 플랫폼을 개발하며 대표적인 AI 기업으로 성장중인 비상장회사 "마인즈랩"를...'
#  '오늘의급등주 하이트론 셀바스AI 갤럭시아에스엠 일정실업 갤럭시아머니트리 셀바스AI AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을...'
#  '한국어 처리 패키지 8 자연어 처리 미니프로젝트 16 데이터 분석 데이터 기초통계분석 8 데이터 심화 분석 8 데이터 분석 미니프로젝트 16 데이터 시각화와...'
#  '바이브컴퍼니는 텍스트 마이닝, 대규모 정보탐색과 자연어 처리 등 수십억 개의 소셜미디어 글들이 담고 있는 소비자의 의견을 인공지능 기술을 이용하여 자동으로...'
#  '구글 번역 아닌가 했는데, 헤이버니를 만든 트위그팜 은 딥러닝 기반의 자연어처리 전문기업으로 번역쪽에 특화되어 있었다. 오, 멋진데. 헤이버니 웹사이트 캡쳐...'
#  '만화영화 제작이나 해킹 같은 거야 나랑 관련이 별로 없는 분야라지만, 자연어처리에서마저... 나는 대체 뭐란 말인가. 사실 직원들은 별도로 봉급을 받긴 하지만, 쌀...'
#  '<메타버스에서의 연결 : 엔비디아 GTC 키노트 제작 과정> 젠슨 황 CEO는 기조연설에서 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 기술, 로보틱스, 헬스케어...'
#  '그중에서도 텐센트가 주력하는 것은 AI반도체가 될 것이며, 추후 이미지·동영상 처리, 자연어 처리, 검색 추천 등의 기능을 개발할 예정으로 알려졌다. 텐센트 본사...'
#  '#키플홀딩스 #키플홀딩스주식 #키플홀딩스장외주식 #음성인식#기계번역#자연어처리 #오픈API #AI기반언어처리 #언어솔루션 #AI어시스턴트시스템공동개발...'
#  '자동화해 처리하는 기술이다. 네이버클라우드는 RPA 서비스의 경쟁력 확보를... MS는 또 현재 가장 강력한 자연어 처리 인공지능 모델인 GPT-3를 자신의 클라우드...'
#  '인공지능 자연어 처리기술을 접목해 120만건의 회화 전개가 가능하고 보호자, 관리자 애플리케이션을 통해 돌봄 인형의 목소리로 어르신과 대화도 할 수 있다. AI...'
#  "영어 문제 자동생성 서비스 'ATM(AI Test Maker)' 개발 자연어처리(NLP) 기반으로 지문... 그만큼 지문을 분석하는 자연어처리(NLP) 기술이 높아야 하고, 이를 응용할 수..."
#  '활용 중인 AI 기술 종류는 음성인식·합성, 자연어처리, 영상처리·추천·예측 등 다양하다. LG유플러스가 가장 많은 AI 기술을 적용하는 서비스 주제는 IPTV다. IPTV...'
#  '딥러닝과 자연어 처리에 크게 의존하고 있고, 이런 기술들을 통해 엄청 많은 데이터의 패턴을 인식하고 처리하며 실생활에도 많이 활용되고 있어요 이러한 인공지능의...'
#  '만든 자연어 처리 모델인 GPT-3은 인류 역사상 가장 뛰어난 언어 인공지능 모델이라고 평가를 받고 있다 GPT-3 이 기존 AI보다 뛰어난 점은 1) 특정 주제만이 아닌...'
#  '현재 사용되는 분야 ● 컴퓨터 영상 처리 · 물체 인식: object... ( 자연어 처리 ) · 게시글의 답글 달기 · 모방한 글 쓰기...'
#  '(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공 - 이에 셀바스AI는 쌍방향커뮤니케이션 핵심기술인 음성기술을 메타버스 세계관 속 버추얼 휴먼에 접목시킬...'
#  "대규모 자연어처리(NLP) 모델인 GPT-3의 라이선스 독점 사용권을 사들였다고 발표 = GPT-3는 인류 역사상 가장 뛰어난 '언어 인공지능'이라고 평가 받아온 모델..."
#  '[인공지능 자연어처리 및 음성인식/합성기술을 활용한 응용SW 개발자 양성과정] ● 모집개요 - 자연어처리와 음성인식/합성 기술을 활용하여 현업에서 사용하는...'
#  '기계학습과 자연어 처리 스타트업 ㈜시스메타가 이들의 시초라고 합니다. 창업... 대화 처리 딥러닝 기반의 지식 학습, 음성인식/합성 등에 많은 투자를 진행하기도...'
#  '안녕하세요, 유니포인트 입니다. 여러 기업, 기관들도 물론이지만, 특히나 국방관련의 사업에서의 글로벌 의사소통 역량은 보다 더욱 빠르고 정확해야합니다....'
#  '포스팅 개요 이번 포스팅은 자연어처리(NLP) 논문 중 A Lite BERT... 데이터 처리량 (number of training steps) 을 제어하는 대신 ? Actual...'
#  '자연어 처리기술(Natural language processing)이 있다. 컴퓨터가 인간의 언어를 알아들을 수 있게 해 사람처럼 인식하고 말하고 소통할 수 있게 하는 기술이다. 자연어...'
#  '12 마인즈랩은 어떤 회사인가 마인즈랩은 자연어라고 불리는 사람들의 일상적인... 물론 아직까지는 자연어 처리 기술이 좀 더 발전되어야 하겠지만 향후 매우...'
#  'MS는 자연어 처리 인공지능 모델인 GPT-3를 활용해 대량의 텍스트를 자동 요약해주는 소프트웨어, MS 오피스 제품과 결합해 표나 메모를 자유롭게 캔버스에 그리듯...'
#  '제가 매일 듣는 하나금융투자의 하나모닝브리핑 방송에 언급된 것을 요약 위주로 기술하였고 기억하고 싶은 요점만 뽑아봤습니다. 상세한 내용은 Daily Report를....'
#  '분야에서 #자연어처리 기술의 중요성이 증가하고 있습니다. 셀바스AI는 음성... 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고...'
#  'next sentence prediction(NSP) 문장 두 개를 처리하는 자연어 처리의 예로는 질의 및 응답을 하는 경우가 있고, 문장 간의 상관관계를 예측하는...'
#  '및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에 이르기까지 모든 분야를 아우르는 엔비디아의 최신 AI를 공개할 예정) →메타버스...'
#  'docx 파일 다운로드 1장 자료구조와 알고리즘 문제 처리를 위한 프로그램 작성... 알고리즘을 자연어로 구체적으로 적고 > 흐름도를 그리고 > 의사 코드(유사코드)를...'
#  '트랜스포머는 비전 테스크에 좋은 Batch Normalization이 아닌 자연어 처리에 강한 Layer Normalization을 사용하고 있습니다. 이미지는 사이즈가 고정되어...'
#  '영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고... 음성합성, 자연어처리, 필기인식 등으로 진화시키는 기술을 의미합니다. 제품에 대한...'
#  '자연어처리, 음성처리, 시각처리 등 AI 기술이 사람이 못하는 부분을 감시자로서 역할을 하여 이용자들로 하여금 충분히 경각심을 고취시킬 수 있으리라 생각합니다....'
#  '그러던 중 2010년 세번째 붐이 일어나게되는데 그 원동력은 강력한 그래픽처리장... 6-3 자연어처리 기술 6-4 엘모와 버트 6-5 자연어처리를 넘어 7장 AI 공정성 7-1 AI...'
#  '선순환 구조가 완성된 것으로 보이나, 카카오는 아직 중구 난방의 느낌. (개인 의견) * 양사 모두 AI / 로봇 / IOT / TTS / OCR / 자연어 처리 등등에 대한 연구를 진행 중.'
#  '정보 처리, 통신, 에너지, 운송, 생명 공학, 생명을 포함한 과학, 농업 및 산업... 발전했으며 처리 능력은 몇 년마다 약 2배씩 증가합니다(무어의 법칙)...'
#  '자연어 처리 기반으로 최적의 답변을 제공는 챗봇을 개발 텍스트 정보를... 영상콘텐츠 속의 내용까지 검색하는 AI 기술 이 있어요 자연어 이해 기술로 구축된 AI 챗봇...'
#  '소셜 빅데이터를 통해 유의미한 정보 추출 및 인사이트를 얻는게 중요해짐 : 소셜 빅데이터 분석 프로세스 데이터 수집 -> 텍스트 마이닝(자연어처리, 키워드 및...'
#  '빅데이터를 처리하기 위해 개발한 소프트웨어 프레임워크 3) 아파치 하둡... 5) 자연어 처리 인간이 말하는, 발화하는 언어 현상을 기계적으로 분석해서...'
#  'AI를 이용한 자연어 처리 기술이나 집을 구매하고 판매하는 ibuying도 그렇지만 구글의 웨이모가 특히 그런 생각을 강하게 만들었다. 몇년전부터 웨이모와 월마트가...'
#  '특히, EDM에 채택된 점수 예측 알고리즘 연구는 최신 자연어 처리 기술을 교육 AI에 최초로 접목해 현재 최고 정확도 모델 대비 오차를 4% 감소시키며, 베스트...'
#  '좋아 자연어처리가 왜 어려운지에 대한 저번 강의에 이어 이번에는 한국어... 많아지고 처리할 것도 많아짐 따라서 형태소 분석기를 통해 하나로 줄여야 함 ex. 잡 / 다...'
#  '- 한국어 정보 처리를 위한 파이썬 패키지 한국어 자연어처리를 위해선 반드시 필요한 패키지라고 할 수 있습니다. 먼저 KoNLPy를 설치하기 위해선...'
#  '728x90 반응형 Opinion_mining_and_sentiment_analysis로 정함 https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=7724305 21.11.06 정함 1 해당 논문을 왜 선정하였는지 2...'
#  '엔비디아 CEO 제슨황, GTC 기조연설 진행 엔터프라이즈 및 데이터센터 AI, 대화형 AI 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에...'
#  '데이터를 분석하여 제공하는 매니지드 웹크롤링(Crawling) 서비스입니다. 자연어처리(감정분석, 형태소분석) 뿐만 아니라 이미지 분석 기술도 사용할 수 있습니다.'
#  '사람이미지의 키오스크라는 건데, 마인즈랩의 M1은 아바타 기술, 음성인식·합성 기술, 자연어처리(NLP) 기술과 역량 등 AI기술을 총망라된 서비스입니다. 그냥 사람이...'
#  '기반의 자연어 음성 명령 기능과, 준자율주행급의 스마트 크루즈 컨트롤... 비용처리할 수 있으며, 추가로 차량 유류비로 사용되는 비용 중 매년 700만원까지 비용처리를...'
#  '자연어처리부트캠프에 합격한 나는 오늘밤이 지나가기전에 배송지를 입력해야한다. 이게 맞는 길이 맞을까 계속 고민되지만 꿈에다가 한표를 던지기로 했다. 자꾸...'
#  '젠슨 황 CEO는 기조연설에서 엔터프라이즈 및 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 최신 기술을 비롯해 로보틱스부터 헬스케어, 자율주행차량에...'
#  'Open AI란 일론머스크가 처음 투자했던 인공지능 개발 기구인데, 이 기구에 지분을 투자해 만든 대규모 자연어처리 모델이 GPT-3다. MS가 이 모델의 라이선스 독점...'
#  '5차대회는 자연어의 이해와 수리적 사고?추론에 기반 한 복합지능 기술... 대회에서 자연어 처리 규칙을 완화하고 문서(텍스트)로 묘사된 도형문제를 추가하는...'
#  '이 연구는 자연어 처리를 이용하여 노무 관리, 공급망 관리, 기업 운영 등에서 기업이 취한 이해관계자 친화적인 행동을 평가하였습니다. 이해관계자 친화적인 행동을...'
#  '음성인식(STT), 음성합성(TTS), 자연어처리(NLP) 등 다양한 AI 기술을 융·복합해 사용자 환경에 최적화했다. CJ대한통운은 체감도 높은 정교한 서비스를 구현하기 위해...'
#  '자연어 처리 4. 추천시스템 이렇게 4가지 분야에서 다양하게 사용되고 있더라고요. 지금까지 인공지능, 머신러닝, 딥러닝에 대하여 간단하게 알아보는 시간을 가졌는데...'
#  '5차 대회는 AI 기술을 활용한 수학 문제 해결을 주제로, 자연어 이해와 수리적... 대회에서 자연어 처리 규칙을 완화하고 텍스트로 묘사된 도형문제를 추가하는 등...'
#  '요새는 자연어처리 AI를 통해 문자로 하는 질문에 대해서도 답변할 수 있도록 하는 방안도 추진 중이라는데, 이뿐만 아니라 콴다 이용자들끼리 공부 잘하는 법, 입시...'
#  '성우, #자연어처리, #TTS프로그램, #콜센터, #아나운서, #영어 교육, #DNN, #NLP, #목소리프로그램 #e-book #마이토키 #STT #영어교육 #리드스피커...'
#  '5차 대회는 자연어의 이해와 수리적 사고 추론에 기반한 복합지능 기술 확보를... 성균관대 인공지능대학원 연구팀은 자연어 처리 연구 역량을 바탕으로 수학 문제...']

# %%
num = 1
for i in data_contents  :
    print('내용', num, ')', i)
    print('-'*50)
    num += 1
# Out:
# 내용 1 ) 텍스트 마이닝, 대화형 자연어 처리 기술로 강화된 인공지능이 해답을 제시합니다. 3. 모든 담당자가 쉽게 인사이트를 활용할 수 있도록 시각화 자료를 제공합니다....
# --------------------------------------------------
# 내용 2 ) ly/3FVdhDa #패스트캠퍼스 #패캠챌린지 #직장인인강 #직장인자기계발 #패스트캠퍼스후기 #김기현의딥러닝을활용한자연어처리입문올인원패키지Online
# --------------------------------------------------
# 내용 3 ) 이 프로그램은 자연어 처리 기법을 활용해 법률 문서의 내용이 잘 요약된 문장을... 신경망처리장치(NPU) 개발을 위 해선 컴퓨터공학을 비롯한 소프트웨어에 대한...
# --------------------------------------------------
# 내용 4 ) 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공하고... 이 회사는 건축용 자재를 제조하는 데크 플레이트 부문, 조선용 철판을 표면처리...
# --------------------------------------------------
# 내용 5 ) 일각에서는 2032년이면 GPT-3보다 1000배의 학습처리능력을 가진 인공지능이 탄생할... 또한, 일반 상식에 대한 이미지나 자연어 처리가 가능하도록, 상식을 객관적으로...
# --------------------------------------------------
# 내용 6 ) 영상처리 4학년 캡스톤디자인(2), 멀티코어컴퓨팅, 무선이동통신, 네트워크응용설계, 정보보호이론, 생체인식및응용, 자연어처리및정보검색, 패턴인식, 컴퓨터비전...
# --------------------------------------------------
# 내용 7 ) 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고 있다. 셀바스AI의 음성기술을 주목해야한다. 각 도메 인별 데이터 학습을 통해 98...
# --------------------------------------------------
# 내용 8 ) 향상된 처리능력, 이전 세대인 Jetson AGX Xavier의 폼팩터 및 핀에 대한... 이는 개발자가 자연어 이해, 3D 인식, 멀티센서 퓨전 등과 관련된 엣지(edge)...
# --------------------------------------------------
# 내용 9 ) 영상지능, 자연어처리 등 HCI 기술 경쟁력을 강화하고 있다고 재벌투자연구소 전문가분께서 알려주셨습니다 주식 후기에서 가장 중요한 수익 이야기를 해볼까...
# --------------------------------------------------
# 내용 10 ) 대표적으로 신약개발, 배터리 성능 개선, 날씨 예측, 주식 선별, 양자 자연어처리, 이동경로 최적화, 교통 관리, 데이터 보호 등 생활과 밀접한 기술에 양자 컴퓨터가...
# --------------------------------------------------
# 내용 11 ) 컴퓨터는 정확하게 무엇을 해야 할지 처리 내용과 처리 순서를 모두 구체적으로... 알고리즘은 자연어, 의사코드, 순서도, 프로그래밍 언어 등으로 표현이 가능합니다....
# --------------------------------------------------
# 내용 12 ) ▶ 심층 신경망(DNN) 처리 ▶ 자연어 처리 ▶ 편미분 방정식 ▶ 추상화 ▶ 이미지... 주요 역할: 데이터 조작 및 분석 NLTK NLTK는 Natural Language Toolkit(자연어 툴킷)의...
# --------------------------------------------------
# 내용 13 ) AI, 자연어 처리 기술 - 로보틱스, 헬스케어, 자율주행 관련 AI 기술 - 메타버스를 위한 새로운 애플리케이션 - 공장도시 및 지역 디지털 트윈 구축 =>딥러닝...
# --------------------------------------------------
# 내용 14 ) 20년간 자체 개발한 자연어처리기술과 머신러닝, 텍스트마이닝, 의미분석 및 검색 등이 복합적으로 융합된 인공지능 기반 하이브리드 챗봇 솔루션입니다....
# --------------------------------------------------
# 내용 15 ) kr) #데모 #코어에이아이 #원격지원 #챗봇 #IVR #컨택센터 #자연어처리... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...
# --------------------------------------------------
# 내용 16 ) 학습, 자연어 처리, 패턴 인식 등이 분석 기법에 해당한다. 복잡성(Complexity) 데이터의 구조나 데이터의 획득과 처리에 드는 속도, 도메인 규칙이나, 저장 타입 등...
# --------------------------------------------------
# 내용 17 ) 민프로 저는 ‘자연어를 이해하는 AI 기술 기업, 무하유’라는 회사 슬로건을 보고... 서비스에 문장 처리 기술과 AI 기술을 적용시키는 좋은 경험을 할 수 있고요....
# --------------------------------------------------
# 내용 18 ) 예산법안을 처리한 것이 증시에 호재로 작용하면서 소폭 상승 마감했다.... 추출하여 자연어 처리방식으로 실시한 '비트코인'(bitcoin)라는 단어에 대한...
# --------------------------------------------------
# 내용 19 ) 대화형AI, 자연어 처리기술, 로보틱스, 헬스케어, 자율주행 관련기술 메타버스를 위한 새로운 어플리케이션 공장도시 및 지역 디지털 트윈 구축 -딥 러닝...
# --------------------------------------------------
# 내용 20 ) 제목: "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼 절대 공식 저자: 양자학파 출판: 미디어숲 발매: 2021. 11. 10 저자 : 양자학파 양자학파는 자연 과학(수학...
# --------------------------------------------------
# 내용 21 ) Natural Language Processing Natural Language, 즉 인간이 사용하는 자연어를 처리하는 기술입니다. 언어 장벽을 허물고 어떤 언어를 사용하든 누구와 대화하든 쉽게...
# --------------------------------------------------
# 내용 22 ) 16% 자연어 처리 국어 0.16% 전자순찰 tcr-200 0.16% 토카막 네트워크 0.16% 폐기물이 에너지로 변환 미분방정식 0.16% 홍합 접착 단백질 0.16...
# --------------------------------------------------
# 내용 23 ) 단순히 '인공지능 자연어처리'라는 키워드만 보고 바로 지원했고, NLP가 무엇인지도 모르는 상태였다. 개념적인 내용은 블로그, 유튜브를 통해 공부하고 있었지만...
# --------------------------------------------------
# 내용 24 ) (TTS), 자연어처리, 필기인식 등 AI솔루션 제공 └ 국내 최고 음성인식률 보유, 음성합성 기술 M/S 60%로 국내 1위 └ 쌍방향커뮤니케이션 핵심기술인 음성기술을...
# --------------------------------------------------
# 내용 25 ) 영상지능, 자연어처리 등 HCI 기술 경쟁력을 가오하하고 있음 - 음성합성... 마우스, 키보드 등 전통적인 컴퓨터 입력장치가 음성인식, 음성합성, 자여어처리...
# --------------------------------------------------
# 내용 26 ) 흘러흘러 자연어처리 딥러닝을 하는중이다. 문제는 단기간에 계속 효율이 안나와서 열심히 자신과의 싸움중 나무만보고 숲은 못본다는게 이런 경우인거같다 내년쯤 이...
# --------------------------------------------------
# 내용 27 ) ☆ Azure Open AI Service 현존 최대 자연어 처리 프로그램인 GPT-3 API를 클라우드 기반으로 제공합니다. 즉, 애저를 사용하면 고객 서비스 로그 상의 공통된 불만사항을...
# --------------------------------------------------
# 내용 28 ) 음성합성, 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을 주목해야 한다고 합니다 각 도메인별 데이터 학습을 통해 98% 이상의 국내 최고 음성...
# --------------------------------------------------
# 내용 29 ) 전처리 방법이라고 볼 수 있다. 차원 감소를 위 해서는 주성분 분석... - 자연어는 애매하다. 상황에 따라 단어의 역할, 의미가 달라진다. 의미만 전달하는 것이 아니라...
# --------------------------------------------------
# 내용 30 ) 데이터 처리 라이브러리 Pandas ▶ 데이터 크롤링정제 등 총 256시간 진행된다. 심화과정은 47일 동안 ▶ 빅데이터 통계기본 ▶ 자연어 처리 ▶ 데이터 분석...
# --------------------------------------------------
# 내용 31 ) #코스피#코스닥#상한가 21년 11월 9일 화요일 주식시황입니다. 양대 지수 모두 소폭 상승하면서 강보합입니다. 코스피는 여전히 하락하는 중이고 코스닥은 옆으로...
# --------------------------------------------------
# 내용 32 ) 표면처리(Shot Blast) 및 절단가공(Steel Cutting)하는 조선부문으로 사업을 영위하고... (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을...
# --------------------------------------------------
# 내용 33 ) 상당부분 자연어에 의존하며, 포트란에 비해 많은 양의 데이터를 처리하도록 설계됐다. 코볼은 처음 등장한 후 가장 널리 사용되는 프로그램 언어 중 하나로...
# --------------------------------------------------
# 내용 34 ) 컨택센터 #자연어처리 #챗봇솔루션 #자동응답서비스 #AI비서 #KOREAI #코어AI... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...
# --------------------------------------------------
# 내용 35 ) 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을... 표면처리·절단가공하는 조선부문 등을 영위하고 있습니다. 이 회사의 박정식...
# --------------------------------------------------
# 내용 36 ) OCR, 자연어 처리 등 딥러닝을 통해 해결한 문제 소개 코스 2 소개 페이지 ♂? 수강하러 가기 ♀? 코스 3. 간편결제 및 자산관리 사례 ? 디지털 전환을 통한...
# --------------------------------------------------
# 내용 37 ) 셀바스AI는 AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을 제공하는 업체다. 최근 증권가에서 셀바스AI가 주목받는 건 메타버스 내에서 셀바스AI...
# --------------------------------------------------
# 내용 38 ) 빅데이터 자연어 처리NLP 등 데이터를 다양한 관점에서 분석하고 있다. 코오롱-카이스트 라이프스타일 이노베이션 최우수상을 수상했다. 저자 : 권정윤...
# --------------------------------------------------
# 내용 39 ) 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음.... 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을...
# --------------------------------------------------
# 내용 40 ) 동사는 22년간의 지속적인 연구개발 투자를 통해 음성지능, 필기지능, 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음....
# --------------------------------------------------
# 내용 41 ) 회사에서 자연어처리 특강을 하는데 나는 1도 모르겠다.. 꼭 배워야할 것 같은데 과외를 해야나아 ㅋㅋㅋㅋ.. 유투브 열심히보면 알 수 있지않나여? 하핳,, 어렵네여 진짜...
# --------------------------------------------------
# 내용 42 ) 음성인식과 자연어처리(NLP) 등의 기술을 이전 받아 다양한 분야의 첨단 AI 서비스 플랫폼을 개발하며 대표적인 AI 기업으로 성장중인 비상장회사 "마인즈랩"를...
# --------------------------------------------------
# 내용 43 ) 오늘의급등주 하이트론 셀바스AI 갤럭시아에스엠 일정실업 갤럭시아머니트리 셀바스AI AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을...
# --------------------------------------------------
# 내용 44 ) 한국어 처리 패키지 8 자연어 처리 미니프로젝트 16 데이터 분석 데이터 기초통계분석 8 데이터 심화 분석 8 데이터 분석 미니프로젝트 16 데이터 시각화와...
# --------------------------------------------------
# 내용 45 ) 바이브컴퍼니는 텍스트 마이닝, 대규모 정보탐색과 자연어 처리 등 수십억 개의 소셜미디어 글들이 담고 있는 소비자의 의견을 인공지능 기술을 이용하여 자동으로...
# --------------------------------------------------
# 내용 46 ) 구글 번역 아닌가 했는데, 헤이버니를 만든 트위그팜 은 딥러닝 기반의 자연어처리 전문기업으로 번역쪽에 특화되어 있었다. 오, 멋진데. 헤이버니 웹사이트 캡쳐...
# --------------------------------------------------
# 내용 47 ) 만화영화 제작이나 해킹 같은 거야 나랑 관련이 별로 없는 분야라지만, 자연어처리에서마저... 나는 대체 뭐란 말인가. 사실 직원들은 별도로 봉급을 받긴 하지만, 쌀...
# --------------------------------------------------
# 내용 48 ) <메타버스에서의 연결 : 엔비디아 GTC 키노트 제작 과정> 젠슨 황 CEO는 기조연설에서 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 기술, 로보틱스, 헬스케어...
# --------------------------------------------------
# 내용 49 ) 그중에서도 텐센트가 주력하는 것은 AI반도체가 될 것이며, 추후 이미지·동영상 처리, 자연어 처리, 검색 추천 등의 기능을 개발할 예정으로 알려졌다. 텐센트 본사...
# --------------------------------------------------
# 내용 50 ) #키플홀딩스 #키플홀딩스주식 #키플홀딩스장외주식 #음성인식#기계번역#자연어처리 #오픈API #AI기반언어처리 #언어솔루션 #AI어시스턴트시스템공동개발...
# --------------------------------------------------
# 내용 51 ) 자동화해 처리하는 기술이다. 네이버클라우드는 RPA 서비스의 경쟁력 확보를... MS는 또 현재 가장 강력한 자연어 처리 인공지능 모델인 GPT-3를 자신의 클라우드...
# --------------------------------------------------
# 내용 52 ) 인공지능 자연어 처리기술을 접목해 120만건의 회화 전개가 가능하고 보호자, 관리자 애플리케이션을 통해 돌봄 인형의 목소리로 어르신과 대화도 할 수 있다. AI...
# --------------------------------------------------
# 내용 53 ) 영어 문제 자동생성 서비스 'ATM(AI Test Maker)' 개발 자연어처리(NLP) 기반으로 지문... 그만큼 지문을 분석하는 자연어처리(NLP) 기술이 높아야 하고, 이를 응용할 수...
# --------------------------------------------------
# 내용 54 ) 활용 중인 AI 기술 종류는 음성인식·합성, 자연어처리, 영상처리·추천·예측 등 다양하다. LG유플러스가 가장 많은 AI 기술을 적용하는 서비스 주제는 IPTV다. IPTV...
# --------------------------------------------------
# 내용 55 ) 딥러닝과 자연어 처리에 크게 의존하고 있고, 이런 기술들을 통해 엄청 많은 데이터의 패턴을 인식하고 처리하며 실생활에도 많이 활용되고 있어요 이러한 인공지능의...
# --------------------------------------------------
# 내용 56 ) 만든 자연어 처리 모델인 GPT-3은 인류 역사상 가장 뛰어난 언어 인공지능 모델이라고 평가를 받고 있다 GPT-3 이 기존 AI보다 뛰어난 점은 1) 특정 주제만이 아닌...
# --------------------------------------------------
# 내용 57 ) 현재 사용되는 분야 ● 컴퓨터 영상 처리 · 물체 인식: object... ( 자연어 처리 ) · 게시글의 답글 달기 · 모방한 글 쓰기...
# --------------------------------------------------
# 내용 58 ) (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공 - 이에 셀바스AI는 쌍방향커뮤니케이션 핵심기술인 음성기술을 메타버스 세계관 속 버추얼 휴먼에 접목시킬...
# --------------------------------------------------
# 내용 59 ) 대규모 자연어처리(NLP) 모델인 GPT-3의 라이선스 독점 사용권을 사들였다고 발표 = GPT-3는 인류 역사상 가장 뛰어난 '언어 인공지능'이라고 평가 받아온 모델...
# --------------------------------------------------
# 내용 60 ) [인공지능 자연어처리 및 음성인식/합성기술을 활용한 응용SW 개발자 양성과정] ● 모집개요 - 자연어처리와 음성인식/합성 기술을 활용하여 현업에서 사용하는...
# --------------------------------------------------
# 내용 61 ) 기계학습과 자연어 처리 스타트업 ㈜시스메타가 이들의 시초라고 합니다. 창업... 대화 처리 딥러닝 기반의 지식 학습, 음성인식/합성 등에 많은 투자를 진행하기도...
# --------------------------------------------------
# 내용 62 ) 안녕하세요, 유니포인트 입니다. 여러 기업, 기관들도 물론이지만, 특히나 국방관련의 사업에서의 글로벌 의사소통 역량은 보다 더욱 빠르고 정확해야합니다....
# --------------------------------------------------
# 내용 63 ) 포스팅 개요 이번 포스팅은 자연어처리(NLP) 논문 중 A Lite BERT... 데이터 처리량 (number of training steps) 을 제어하는 대신 ? Actual...
# --------------------------------------------------
# 내용 64 ) 자연어 처리기술(Natural language processing)이 있다. 컴퓨터가 인간의 언어를 알아들을 수 있게 해 사람처럼 인식하고 말하고 소통할 수 있게 하는 기술이다. 자연어...
# --------------------------------------------------
# 내용 65 ) 12 마인즈랩은 어떤 회사인가 마인즈랩은 자연어라고 불리는 사람들의 일상적인... 물론 아직까지는 자연어 처리 기술이 좀 더 발전되어야 하겠지만 향후 매우...
# --------------------------------------------------
# 내용 66 ) MS는 자연어 처리 인공지능 모델인 GPT-3를 활용해 대량의 텍스트를 자동 요약해주는 소프트웨어, MS 오피스 제품과 결합해 표나 메모를 자유롭게 캔버스에 그리듯...
# --------------------------------------------------
# 내용 67 ) 제가 매일 듣는 하나금융투자의 하나모닝브리핑 방송에 언급된 것을 요약 위주로 기술하였고 기억하고 싶은 요점만 뽑아봤습니다. 상세한 내용은 Daily Report를....
# --------------------------------------------------
# 내용 68 ) 분야에서 #자연어처리 기술의 중요성이 증가하고 있습니다. 셀바스AI는 음성... 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고...
# --------------------------------------------------
# 내용 69 ) next sentence prediction(NSP) 문장 두 개를 처리하는 자연어 처리의 예로는 질의 및 응답을 하는 경우가 있고, 문장 간의 상관관계를 예측하는...
# --------------------------------------------------
# 내용 70 ) 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에 이르기까지 모든 분야를 아우르는 엔비디아의 최신 AI를 공개할 예정) →메타버스...
# --------------------------------------------------
# 내용 71 ) docx 파일 다운로드 1장 자료구조와 알고리즘 문제 처리를 위한 프로그램 작성... 알고리즘을 자연어로 구체적으로 적고 > 흐름도를 그리고 > 의사 코드(유사코드)를...
# --------------------------------------------------
# 내용 72 ) 트랜스포머는 비전 테스크에 좋은 Batch Normalization이 아닌 자연어 처리에 강한 Layer Normalization을 사용하고 있습니다. 이미지는 사이즈가 고정되어...
# --------------------------------------------------
# 내용 73 ) 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고... 음성합성, 자연어처리, 필기인식 등으로 진화시키는 기술을 의미합니다. 제품에 대한...
# --------------------------------------------------
# 내용 74 ) 자연어처리, 음성처리, 시각처리 등 AI 기술이 사람이 못하는 부분을 감시자로서 역할을 하여 이용자들로 하여금 충분히 경각심을 고취시킬 수 있으리라 생각합니다....
# --------------------------------------------------
# 내용 75 ) 그러던 중 2010년 세번째 붐이 일어나게되는데 그 원동력은 강력한 그래픽처리장... 6-3 자연어처리 기술 6-4 엘모와 버트 6-5 자연어처리를 넘어 7장 AI 공정성 7-1 AI...
# --------------------------------------------------
# 내용 76 ) 선순환 구조가 완성된 것으로 보이나, 카카오는 아직 중구 난방의 느낌. (개인 의견) * 양사 모두 AI / 로봇 / IOT / TTS / OCR / 자연어 처리 등등에 대한 연구를 진행 중.
# --------------------------------------------------
# 내용 77 ) 정보 처리, 통신, 에너지, 운송, 생명 공학, 생명을 포함한 과학, 농업 및 산업... 발전했으며 처리 능력은 몇 년마다 약 2배씩 증가합니다(무어의 법칙)...
# --------------------------------------------------
# 내용 78 ) 자연어 처리 기반으로 최적의 답변을 제공는 챗봇을 개발 텍스트 정보를... 영상콘텐츠 속의 내용까지 검색하는 AI 기술 이 있어요 자연어 이해 기술로 구축된 AI 챗봇...
# --------------------------------------------------
# 내용 79 ) 소셜 빅데이터를 통해 유의미한 정보 추출 및 인사이트를 얻는게 중요해짐 : 소셜 빅데이터 분석 프로세스 데이터 수집 -> 텍스트 마이닝(자연어처리, 키워드 및...
# --------------------------------------------------
# 내용 80 ) 빅데이터를 처리하기 위해 개발한 소프트웨어 프레임워크 3) 아파치 하둡... 5) 자연어 처리 인간이 말하는, 발화하는 언어 현상을 기계적으로 분석해서...
# --------------------------------------------------
# 내용 81 ) AI를 이용한 자연어 처리 기술이나 집을 구매하고 판매하는 ibuying도 그렇지만 구글의 웨이모가 특히 그런 생각을 강하게 만들었다. 몇년전부터 웨이모와 월마트가...
# --------------------------------------------------
# 내용 82 ) 특히, EDM에 채택된 점수 예측 알고리즘 연구는 최신 자연어 처리 기술을 교육 AI에 최초로 접목해 현재 최고 정확도 모델 대비 오차를 4% 감소시키며, 베스트...
# --------------------------------------------------
# 내용 83 ) 좋아 자연어처리가 왜 어려운지에 대한 저번 강의에 이어 이번에는 한국어... 많아지고 처리할 것도 많아짐 따라서 형태소 분석기를 통해 하나로 줄여야 함 ex. 잡 / 다...
# --------------------------------------------------
# 내용 84 ) - 한국어 정보 처리를 위한 파이썬 패키지 한국어 자연어처리를 위해선 반드시 필요한 패키지라고 할 수 있습니다. 먼저 KoNLPy를 설치하기 위해선...
# --------------------------------------------------
# 내용 85 ) 728x90 반응형 Opinion_mining_and_sentiment_analysis로 정함 https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=7724305 21.11.06 정함 1 해당 논문을 왜 선정하였는지 2...
# --------------------------------------------------
# 내용 86 ) 엔비디아 CEO 제슨황, GTC 기조연설 진행 엔터프라이즈 및 데이터센터 AI, 대화형 AI 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에...
# --------------------------------------------------
# 내용 87 ) 데이터를 분석하여 제공하는 매니지드 웹크롤링(Crawling) 서비스입니다. 자연어처리(감정분석, 형태소분석) 뿐만 아니라 이미지 분석 기술도 사용할 수 있습니다.
# --------------------------------------------------
# 내용 88 ) 사람이미지의 키오스크라는 건데, 마인즈랩의 M1은 아바타 기술, 음성인식·합성 기술, 자연어처리(NLP) 기술과 역량 등 AI기술을 총망라된 서비스입니다. 그냥 사람이...
# --------------------------------------------------
# 내용 89 ) 기반의 자연어 음성 명령 기능과, 준자율주행급의 스마트 크루즈 컨트롤... 비용처리할 수 있으며, 추가로 차량 유류비로 사용되는 비용 중 매년 700만원까지 비용처리를...
# --------------------------------------------------
# 내용 90 ) 자연어처리부트캠프에 합격한 나는 오늘밤이 지나가기전에 배송지를 입력해야한다. 이게 맞는 길이 맞을까 계속 고민되지만 꿈에다가 한표를 던지기로 했다. 자꾸...
# --------------------------------------------------
# 내용 91 ) 젠슨 황 CEO는 기조연설에서 엔터프라이즈 및 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 최신 기술을 비롯해 로보틱스부터 헬스케어, 자율주행차량에...
# --------------------------------------------------
# 내용 92 ) Open AI란 일론머스크가 처음 투자했던 인공지능 개발 기구인데, 이 기구에 지분을 투자해 만든 대규모 자연어처리 모델이 GPT-3다. MS가 이 모델의 라이선스 독점...
# --------------------------------------------------
# 내용 93 ) 5차대회는 자연어의 이해와 수리적 사고?추론에 기반 한 복합지능 기술... 대회에서 자연어 처리 규칙을 완화하고 문서(텍스트)로 묘사된 도형문제를 추가하는...
# --------------------------------------------------
# 내용 94 ) 이 연구는 자연어 처리를 이용하여 노무 관리, 공급망 관리, 기업 운영 등에서 기업이 취한 이해관계자 친화적인 행동을 평가하였습니다. 이해관계자 친화적인 행동을...
# --------------------------------------------------
# 내용 95 ) 음성인식(STT), 음성합성(TTS), 자연어처리(NLP) 등 다양한 AI 기술을 융·복합해 사용자 환경에 최적화했다. CJ대한통운은 체감도 높은 정교한 서비스를 구현하기 위해...
# --------------------------------------------------
# 내용 96 ) 자연어 처리 4. 추천시스템 이렇게 4가지 분야에서 다양하게 사용되고 있더라고요. 지금까지 인공지능, 머신러닝, 딥러닝에 대하여 간단하게 알아보는 시간을 가졌는데...
# --------------------------------------------------
# 내용 97 ) 5차 대회는 AI 기술을 활용한 수학 문제 해결을 주제로, 자연어 이해와 수리적... 대회에서 자연어 처리 규칙을 완화하고 텍스트로 묘사된 도형문제를 추가하는 등...
# --------------------------------------------------
# 내용 98 ) 요새는 자연어처리 AI를 통해 문자로 하는 질문에 대해서도 답변할 수 있도록 하는 방안도 추진 중이라는데, 이뿐만 아니라 콴다 이용자들끼리 공부 잘하는 법, 입시...
# --------------------------------------------------
# 내용 99 ) 성우, #자연어처리, #TTS프로그램, #콜센터, #아나운서, #영어 교육, #DNN, #NLP, #목소리프로그램 #e-book #마이토키 #STT #영어교육 #리드스피커...
# --------------------------------------------------
# 내용 100 ) 5차 대회는 자연어의 이해와 수리적 사고 추론에 기반한 복합지능 기술 확보를... 성균관대 인공지능대학원 연구팀은 자연어 처리 연구 역량을 바탕으로 수학 문제...
# --------------------------------------------------

# %%
data_tit_con = '■ 제목 : ' + data_title + ' ■ 내용 : ' + data_contents

# %%
data_tit_con
# Out:
# array(['■ 제목 : 트링크AI는 지역관광 솔루션입니다 ■ 내용 : 텍스트 마이닝, 대화형 자연어 처리 기술로 강화된 인공지능이 해답을 제시합니다. 3. 모든 담당자가 쉽게 인사이트를 활용할 수 있도록 시각화 자료를 제공합니다....',
#        '■ 제목 : 패스트캠퍼스 챌린지 10일차(수요일) ■ 내용 : ly/3FVdhDa #패스트캠퍼스 #패캠챌린지 #직장인인강 #직장인자기계발 #패스트캠퍼스후기 #김기현의딥러닝을활용한자연어처리입문올인원패키지Online',
#        '■ 제목 : 다급한 기업, IT인재 직접 키워…컴공·전산 서울 대졸자 추월 ■ 내용 : 이 프로그램은 자연어 처리 기법을 활용해 법률 문서의 내용이 잘 요약된 문장을... 신경망처리장치(NPU) 개발을 위 해선 컴퓨터공학을 비롯한 소프트웨어에 대한...',
#        '■ 제목 : 2021년 11월 9일 상한가(갤럭시아에스엠, 셀바스AI, 하이트론... ■ 내용 : 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공하고... 이 회사는 건축용 자재를 제조하는 데크 플레이트 부문, 조선용 철판을 표면처리...',
#        '■ 제목 : 인공지능을 넘어 인공자아의 시대로 도약 ■ 내용 : 일각에서는 2032년이면 GPT-3보다 1000배의 학습처리능력을 가진 인공지능이 탄생할... 또한, 일반 상식에 대한 이미지나 자연어 처리가 가능하도록, 상식을 객관적으로...',
#        '■ 제목 : [디지털 시대의 전공들] 중앙대학교 소프트웨어 학부 ■ 내용 : 영상처리 4학년 캡스톤디자인(2), 멀티코어컴퓨팅, 무선이동통신, 네트워크응용설계, 정보보호이론, 생체인식및응용, 자연어처리및정보검색, 패턴인식, 컴퓨터비전...',
#        '■ 제목 : 셀바스AI-우리가 모르는 메타버스 수혜주, 절대적 저평가... ■ 내용 : 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고 있다. 셀바스AI의 음성기술을 주목해야한다. 각 도메 인별 데이터 학습을 통해 98...',
#        '■ 제목 : NVIDIA, 신규 Jetson AGX Orin 공개 ■ 내용 : 향상된 처리능력, 이전 세대인 Jetson AGX Xavier의 폼팩터 및 핀에 대한... 이는 개발자가 자연어 이해, 3D 인식, 멀티센서 퓨전 등과 관련된 엣지(edge)...',
#        '■ 제목 : 메타버스 관련주로 떠오르는 셀바스AI +78% 성공 ■ 내용 : 영상지능, 자연어처리 등 HCI 기술 경쟁력을 강화하고 있다고 재벌투자연구소 전문가분께서 알려주셨습니다 주식 후기에서 가장 중요한 수익 이야기를 해볼까...',
#        '■ 제목 : [GIP 뉴스레터_11월 2주] 넷플릭스가 게임 만든다고? ■ 내용 : 대표적으로 신약개발, 배터리 성능 개선, 날씨 예측, 주식 선별, 양자 자연어처리, 이동경로 최적화, 교통 관리, 데이터 보호 등 생활과 밀접한 기술에 양자 컴퓨터가...',
#        '■ 제목 : [자바공부] 자바알고리즘이란 무엇인가? ■ 내용 : 컴퓨터는 정확하게 무엇을 해야 할지 처리 내용과 처리 순서를 모두 구체적으로... 알고리즘은 자연어, 의사코드, 순서도, 프로그래밍 언어 등으로 표현이 가능합니다....',
#        '■ 제목 : 파이썬의 강력함을 느낄 수 있는 「한 권으로 다지는 머신... ■ 내용 : ▶ 심층 신경망(DNN) 처리 ▶ 자연어 처리 ▶ 편미분 방정식 ▶ 추상화 ▶ 이미지... 주요 역할: 데이터 조작 및 분석 NLTK NLTK는 Natural Language Toolkit(자연어 툴킷)의...',
#        '■ 제목 : 11/10 주린이의 받아쓰는 시황정리(feat. 삼프로 tv) ■ 내용 : AI, 자연어 처리 기술 - 로보틱스, 헬스케어, 자율주행 관련 AI 기술 - 메타버스를 위한 새로운 애플리케이션 - 공장도시 및 지역 디지털 트윈 구축 =>딥러닝...',
#        '■ 제목 : [월230/수원] 삼성전기 AI인공지능 챗봇 트레이너 ■ 내용 : 20년간 자체 개발한 자연어처리기술과 머신러닝, 텍스트마이닝, 의미분석 및 검색 등이 복합적으로 융합된 인공지능 기반 하이브리드 챗봇 솔루션입니다....',
#        "■ 제목 : [영상] 전상호 코어에이아이(kore.ai,) 상무, '대화형 AI... ■ 내용 : kr) #데모 #코어에이아이 #원격지원 #챗봇 #IVR #컨택센터 #자연어처리... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...",
#        '■ 제목 : 빅 데이터란? 특징과 의미를 알아봅니다. ■ 내용 : 학습, 자연어 처리, 패턴 인식 등이 분석 기법에 해당한다. 복잡성(Complexity) 데이터의 구조나 데이터의 획득과 처리에 드는 속도, 도메인 규칙이나, 저장 타입 등...',
#        '■ 제목 : [개발 2유닛] 무하유의 서비스를 만들어가는 “서비스... ■ 내용 : 민프로 저는 ‘자연어를 이해하는 AI 기술 기업, 무하유’라는 회사 슬로건을 보고... 서비스에 문장 처리 기술과 AI 기술을 적용시키는 좋은 경험을 할 수 있고요....',
#        "■ 제목 : [에임리치] 비트코인 시총 3조 달러 근접… ‘ETH’ 급등... ■ 내용 : 예산법안을 처리한 것이 증시에 호재로 작용하면서 소폭 상승 마감했다.... 추출하여 자연어 처리방식으로 실시한 '비트코인'(bitcoin)라는 단어에 대한...",
#        '■ 제목 : 11월 10일 삼프로 티비 - 월가모닝라이브, 오늘아침라이브 ■ 내용 : 대화형AI, 자연어 처리기술, 로보틱스, 헬스케어, 자율주행 관련기술 메타버스를 위한 새로운 어플리케이션 공장도시 및 지역 디지털 트윈 구축 -딥 러닝...',
#        '■ 제목 : "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼... ■ 내용 : 제목: "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼 절대 공식 저자: 양자학파 출판: 미디어숲 발매: 2021. 11. 10 저자 : 양자학파 양자학파는 자연 과학(수학...',
#        '■ 제목 : Meta의 AI 전략 (AI 시리즈 1) ■ 내용 : Natural Language Processing Natural Language, 즉 인간이 사용하는 자연어를 처리하는 기술입니다. 언어 장벽을 허물고 어떤 언어를 사용하든 누구와 대화하든 쉽게...',
#        '■ 제목 : 21,11,10 검색조회수가장많은 단어키워드 상위노출유입분석 ■ 내용 : 16% 자연어 처리 국어 0.16% 전자순찰 tcr-200 0.16% 토카막 네트워크 0.16% 폐기물이 에너지로 변환 미분방정식 0.16% 홍합 접착 단백질 0.16...',
#        "■ 제목 : 멀티캠퍼스 인공지능 자연어처리(NLP) 기반 기업 데이터 분석... ■ 내용 : 단순히 '인공지능 자연어처리'라는 키워드만 보고 바로 지원했고, NLP가 무엇인지도 모르는 상태였다. 개념적인 내용은 블로그, 유튜브를 통해 공부하고 있었지만...",
#        '■ 제목 : (211109) 셀바스AI - 우리가 모르는 메타버스 수혜주, 절대적... ■ 내용 : (TTS), 자연어처리, 필기인식 등 AI솔루션 제공 └ 국내 최고 음성인식률 보유, 음성합성 기술 M/S 60%로 국내 1위 └ 쌍방향커뮤니케이션 핵심기술인 음성기술을...',
#        '■ 제목 : 셀바스AI 주가 전망 : 인공지능, 메타버스, 음성인식 관련주 ■ 내용 : 영상지능, 자연어처리 등 HCI 기술 경쟁력을 가오하하고 있음 - 음성합성... 마우스, 키보드 등 전통적인 컴퓨터 입력장치가 음성인식, 음성합성, 자여어처리...',
#        '■ 제목 : 2021/11/09 ■ 내용 : 흘러흘러 자연어처리 딥러닝을 하는중이다. 문제는 단기간에 계속 효율이 안나와서 열심히 자신과의 싸움중 나무만보고 숲은 못본다는게 이런 경우인거같다 내년쯤 이...',
#        '■ 제목 : 마이크로소프트(MSFT)도 메타버스에 합류! 그에 대한 완벽 분석! ■ 내용 : ☆ Azure Open AI Service 현존 최대 자연어 처리 프로그램인 GPT-3 API를 클라우드 기반으로 제공합니다. 즉, 애저를 사용하면 고객 서비스 로그 상의 공통된 불만사항을...',
#        '■ 제목 : 셀바스AI 주가 숨겨진 메타버스 수혜주 기대감에 상한가 ■ 내용 : 음성합성, 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을 주목해야 한다고 합니다 각 도메인별 데이터 학습을 통해 98% 이상의 국내 최고 음성...',
#        '■ 제목 : AI 최강의 수업 ■ 내용 : 전처리 방법이라고 볼 수 있다. 차원 감소를 위 해서는 주성분 분석... - 자연어는 애매하다. 상황에 따라 단어의 역할, 의미가 달라진다. 의미만 전달하는 것이 아니라...',
#        '■ 제목 : [경북대학교 데이터융합연구원] 2021년 고용노동부 K... ■ 내용 : 데이터 처리 라이브러리 Pandas ▶ 데이터 크롤링정제 등 총 256시간 진행된다. 심화과정은 47일 동안 ▶ 빅데이터 통계기본 ▶ 자연어 처리 ▶ 데이터 분석...',
#        '■ 제목 : 21년 11월 9일 화 주식시황 ■ 내용 : #코스피#코스닥#상한가 21년 11월 9일 화요일 주식시황입니다. 양대 지수 모두 소폭 상승하면서 강보합입니다. 코스피는 여전히 하락하는 중이고 코스닥은 옆으로...',
#        '■ 제목 : 아진산업,하이트론,제일테크노스,셀바스AI ■ 내용 : 표면처리(Shot Blast) 및 절단가공(Steel Cutting)하는 조선부문으로 사업을 영위하고... (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을...',
#        '■ 제목 : 프로그래밍 언어의 간추린 역사 ■ 내용 : 상당부분 자연어에 의존하며, 포트란에 비해 많은 양의 데이터를 처리하도록 설계됐다. 코볼은 처음 등장한 후 가장 널리 사용되는 프로그램 언어 중 하나로...',
#        '■ 제목 : [Kore.ai XO Platform Release v9.1] 100개 이상 언어로... ■ 내용 : 컨택센터 #자연어처리 #챗봇솔루션 #자동응답서비스 #AI비서 #KOREAI #코어AI... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...',
#        '■ 제목 : 상한가(11월9일),갤럭시아에스이엠/하이트론... ■ 내용 : 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을... 표면처리·절단가공하는 조선부문 등을 영위하고 있습니다. 이 회사의 박정식...',
#        '■ 제목 : [2021 금융산업 전문인력 AI 역량강화] #온라인으로_배우는... ■ 내용 : OCR, 자연어 처리 등 딥러닝을 통해 해결한 문제 소개 코스 2 소개 페이지 ♂? 수강하러 가기 ♀? 코스 3. 간편결제 및 자산관리 사례 ? 디지털 전환을 통한...',
#        '■ 제목 : 셀바스AI 메타버스 가상 캐릭터와 소통하는 AI음성인식기술로... ■ 내용 : 셀바스AI는 AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을 제공하는 업체다. 최근 증권가에서 셀바스AI가 주목받는 건 메타버스 내에서 셀바스AI...',
#        '■ 제목 : [가까운 책] 트렌드코리아 2022 - 김난도, 전미영, 최지혜 외 ■ 내용 : 빅데이터 자연어 처리NLP 등 데이터를 다양한 관점에서 분석하고 있다. 코오롱-카이스트 라이프스타일 이노베이션 최우수상을 수상했다. 저자 : 권정윤...',
#        '■ 제목 : 셀바스AI 주가 상한가 메타버스 음성인식 ■ 내용 : 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음.... 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을...',
#        '■ 제목 : [재벌투자연구소 투자정보]-장중에 78%로 수익매도#셀바스AI ■ 내용 : 동사는 22년간의 지속적인 연구개발 투자를 통해 음성지능, 필기지능, 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음....',
#        '■ 제목 : 가을의 기록 ■ 내용 : 회사에서 자연어처리 특강을 하는데 나는 1도 모르겠다.. 꼭 배워야할 것 같은데 과외를 해야나아 ㅋㅋㅋㅋ.. 유투브 열심히보면 알 수 있지않나여? 하핳,, 어렵네여 진짜...',
#        '■ 제목 : 기술평가 A, AA 등급을 받고 기술특례상장 초읽기에 들어간... ■ 내용 : 음성인식과 자연어처리(NLP) 등의 기술을 이전 받아 다양한 분야의 첨단 AI 서비스 플랫폼을 개발하며 대표적인 AI 기업으로 성장중인 비상장회사 "마인즈랩"를...',
#        '■ 제목 : 품절주 관련주, 하이트론 주가,이재명 후보 수술실 관련 발언... ■ 내용 : 오늘의급등주 하이트론 셀바스AI 갤럭시아에스엠 일정실업 갤럭시아머니트리 셀바스AI AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을...',
#        '■ 제목 : 경북대학교, K-Digital Training 빅데이터 분석가 양성과정 ■ 내용 : 한국어 처리 패키지 8 자연어 처리 미니프로젝트 16 데이터 분석 데이터 기초통계분석 8 데이터 심화 분석 8 데이터 분석 미니프로젝트 16 데이터 시각화와...',
#        '■ 제목 : <그냥 하지 말라> | 빅데이터 전문가 송길영 부사장이 말하는... ■ 내용 : 바이브컴퍼니는 텍스트 마이닝, 대규모 정보탐색과 자연어 처리 등 수십억 개의 소셜미디어 글들이 담고 있는 소비자의 의견을 인공지능 기술을 이용하여 자동으로...',
#        '■ 제목 : 콘텐츠 홍수 속, 플랫폼이 필요해 ■ 내용 : 구글 번역 아닌가 했는데, 헤이버니를 만든 트위그팜 은 딥러닝 기반의 자연어처리 전문기업으로 번역쪽에 특화되어 있었다. 오, 멋진데. 헤이버니 웹사이트 캡쳐...',
#        '■ 제목 : 기 들릴(Guy Delisle) - 평양(Pyongyang) (2003) ■ 내용 : 만화영화 제작이나 해킹 같은 거야 나랑 관련이 별로 없는 분야라지만, 자연어처리에서마저... 나는 대체 뭐란 말인가. 사실 직원들은 별도로 봉급을 받긴 하지만, 쌀...',
#        '■ 제목 : 엔비디아 GTC 컨퍼런스 개최 (feat. 무료 등록방법) ■ 내용 : <메타버스에서의 연결 : 엔비디아 GTC 키노트 제작 과정> 젠슨 황 CEO는 기조연설에서 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 기술, 로보틱스, 헬스케어...',
#        '■ 제목 : 중국 빅테크, 반도체 자체 개발에 나서는 이유 ■ 내용 : 그중에서도 텐센트가 주력하는 것은 AI반도체가 될 것이며, 추후 이미지·동영상 처리, 자연어 처리, 검색 추천 등의 기능을 개발할 예정으로 알려졌다. 텐센트 본사...',
#        '■ 제목 : 키플홀딩스 장외주식매도매수문의 ■ 내용 : #키플홀딩스 #키플홀딩스주식 #키플홀딩스장외주식 #음성인식#기계번역#자연어처리 #오픈API #AI기반언어처리 #언어솔루션 #AI어시스턴트시스템공동개발...',
#        '■ 제목 : 매일매일 경제노트(2021년11월3일) ■ 내용 : 자동화해 처리하는 기술이다. 네이버클라우드는 RPA 서비스의 경쟁력 확보를... MS는 또 현재 가장 강력한 자연어 처리 인공지능 모델인 GPT-3를 자신의 클라우드...',
#        '■ 제목 : 치매 예방부터 돌봄까지…AI로 어르신 건강·안전 지키는 광주... ■ 내용 : 인공지능 자연어 처리기술을 접목해 120만건의 회화 전개가 가능하고 보호자, 관리자 애플리케이션을 통해 돌봄 인형의 목소리로 어르신과 대화도 할 수 있다. AI...',
#        '■ 제목 : "전문가 수준의 영어 문제, AI가 5초 만에 제작"...이형종... ■ 내용 : 영어 문제 자동생성 서비스 \'ATM(AI Test Maker)\' 개발 자연어처리(NLP) 기반으로 지문... 그만큼 지문을 분석하는 자연어처리(NLP) 기술이 높아야 하고, 이를 응용할 수...',
#        '■ 제목 : 초거대 AI 개발에 한창인 LG, 계열사별 AI 연구 상황은? ■ 내용 : 활용 중인 AI 기술 종류는 음성인식·합성, 자연어처리, 영상처리·추천·예측 등 다양하다. LG유플러스가 가장 많은 AI 기술을 적용하는 서비스 주제는 IPTV다. IPTV...',
#        '■ 제목 : [사주임의 전략소개 #11] Ai주식자동매매프로그램의... ■ 내용 : 딥러닝과 자연어 처리에 크게 의존하고 있고, 이런 기술들을 통해 엄청 많은 데이터의 패턴을 인식하고 처리하며 실생활에도 많이 활용되고 있어요 이러한 인공지능의...',
#        '■ 제목 : 마이크로소프트 3D 아바타 회의/매타버스, 인공지능AI GPT-3... ■ 내용 : 만든 자연어 처리 모델인 GPT-3은 인류 역사상 가장 뛰어난 언어 인공지능 모델이라고 평가를 받고 있다 GPT-3 이 기존 AI보다 뛰어난 점은 1) 특정 주제만이 아닌...',
#        '■ 제목 : 딥 러닝 - fastai 를 이용한 예제 ■ 내용 : 현재 사용되는 분야 ● 컴퓨터 영상 처리 · 물체 인식: object... ( 자연어 처리 ) · 게시글의 답글 달기 · 모방한 글 쓰기...',
#        '■ 제목 : 2021. 11. 8 ■ 내용 : (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공 - 이에 셀바스AI는 쌍방향커뮤니케이션 핵심기술인 음성기술을 메타버스 세계관 속 버추얼 휴먼에 접목시킬...',
#        "■ 제목 : 마이크로소프트의 또 다른 전략 ■ 내용 : 대규모 자연어처리(NLP) 모델인 GPT-3의 라이선스 독점 사용권을 사들였다고 발표 = GPT-3는 인류 역사상 가장 뛰어난 '언어 인공지능'이라고 평가 받아온 모델...",
#        '■ 제목 : [SBA 새싹(SeSAC) X 솔트룩스] 취업연계 인공지능 SW교육... ■ 내용 : [인공지능 자연어처리 및 음성인식/합성기술을 활용한 응용SW 개발자 양성과정] ● 모집개요 - 자연어처리와 음성인식/합성 기술을 활용하여 현업에서 사용하는...',
#        '■ 제목 : AI 스타트업, 브랜드 포지셔닝부터 제대로 <#솔트룩스> ■ 내용 : 기계학습과 자연어 처리 스타트업 ㈜시스메타가 이들의 시초라고 합니다. 창업... 대화 처리 딥러닝 기반의 지식 학습, 음성인식/합성 등에 많은 투자를 진행하기도...',
#        '■ 제목 : 기계번역 솔루션 랭귀지 위버 CASE STUDY :: 한화 디펜스 ■ 내용 : 안녕하세요, 유니포인트 입니다. 여러 기업, 기관들도 물론이지만, 특히나 국방관련의 사업에서의 글로벌 의사소통 역량은 보다 더욱 빠르고 정확해야합니다....',
#        '■ 제목 : nlp ALBERT 논문 정리(논문 리뷰) - A Lite BERT for... ■ 내용 : 포스팅 개요 이번 포스팅은 자연어처리(NLP) 논문 중 A Lite BERT... 데이터 처리량 (number of training steps) 을 제어하는 대신 ? Actual...',
#        '■ 제목 : 인간보다 우월한 AI, 축복인가 재앙인가 ■ 내용 : 자연어 처리기술(Natural language processing)이 있다. 컴퓨터가 인간의 언어를 알아들을 수 있게 해 사람처럼 인식하고 말하고 소통할 수 있게 하는 기술이다. 자연어...',
#        '■ 제목 : 마인즈랩공모주 분석 : 상담도 AI로 ■ 내용 : 12 마인즈랩은 어떤 회사인가 마인즈랩은 자연어라고 불리는 사람들의 일상적인... 물론 아직까지는 자연어 처리 기술이 좀 더 발전되어야 하겠지만 향후 매우...',
#        "■ 제목 : Tech Trends_VR 비즈니스 동향 ('211112)_MS도 메타버스 진격... ■ 내용 : MS는 자연어 처리 인공지능 모델인 GPT-3를 활용해 대량의 텍스트를 자동 요약해주는 소프트웨어, MS 오피스 제품과 결합해 표나 메모를 자유롭게 캔버스에 그리듯...",
#        '■ 제목 : 211108 2022년 전망~ 어떤 섹터, 종목들이 괜찮을지? 한번... ■ 내용 : 제가 매일 듣는 하나금융투자의 하나모닝브리핑 방송에 언급된 것을 요약 위주로 기술하였고 기억하고 싶은 요점만 뽑아봤습니다. 상세한 내용은 Daily Report를....',
#        '■ 제목 : [기업분석] 셀바스AI - 절대적 저평가 상태인 메타버스... ■ 내용 : 분야에서 #자연어처리 기술의 중요성이 증가하고 있습니다. 셀바스AI는 음성... 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고...',
#        '■ 제목 : GPT-1, BERT, GPT-2 모델 이해 ■ 내용 : next sentence prediction(NSP) 문장 두 개를 처리하는 자연어 처리의 예로는 질의 및 응답을 하는 경우가 있고, 문장 간의 상관관계를 예측하는...',
#        '■ 제목 : 11월 8일~11월12일(11월2주차)주요 증시일정-엔비디아... ■ 내용 : 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에 이르기까지 모든 분야를 아우르는 엔비디아의 최신 AI를 공개할 예정) →메타버스...',
#        '■ 제목 : 자료구조 총정리 ■ 내용 : docx 파일 다운로드 1장 자료구조와 알고리즘 문제 처리를 위한 프로그램 작성... 알고리즘을 자연어로 구체적으로 적고 > 흐름도를 그리고 > 의사 코드(유사코드)를...',
#        '■ 제목 : Transformer 이론 및 구성요소 ■ 내용 : 트랜스포머는 비전 테스크에 좋은 Batch Normalization이 아닌 자연어 처리에 강한 Layer Normalization을 사용하고 있습니다. 이미지는 사이즈가 고정되어...',
#        '■ 제목 : [셀바스AI] 메타버스의 잠재력을 가진 AI기업 ■ 내용 : 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고... 음성합성, 자연어처리, 필기인식 등으로 진화시키는 기술을 의미합니다. 제품에 대한...',
#        '■ 제목 : 메타버스 영향력, 기대, 평가, 취약점, 필요요소, 전망 등... ■ 내용 : 자연어처리, 음성처리, 시각처리 등 AI 기술이 사람이 못하는 부분을 감시자로서 역할을 하여 이용자들로 하여금 충분히 경각심을 고취시킬 수 있으리라 생각합니다....',
#        '■ 제목 : [Book]AI 101, 인공지능 비즈니스의 모든 것 ■ 내용 : 그러던 중 2010년 세번째 붐이 일어나게되는데 그 원동력은 강력한 그래픽처리장... 6-3 자연어처리 기술 6-4 엘모와 버트 6-5 자연어처리를 넘어 7장 AI 공정성 7-1 AI...',
#        '■ 제목 : [3줄 독후감] 네이버 vs 카카오 ■ 내용 : 선순환 구조가 완성된 것으로 보이나, 카카오는 아직 중구 난방의 느낌. (개인 의견) * 양사 모두 AI / 로봇 / IOT / TTS / OCR / 자연어 처리 등등에 대한 연구를 진행 중.',
#        '■ 제목 : IONQ(아이온큐) - 투자설명서 2편 (사업편) ■ 내용 : 정보 처리, 통신, 에너지, 운송, 생명 공학, 생명을 포함한 과학, 농업 및 산업... 발전했으며 처리 능력은 몇 년마다 약 2배씩 증가합니다(무어의 법칙)...',
#        '■ 제목 : 인공지능개발 에이아이글로벌 ! ■ 내용 : 자연어 처리 기반으로 최적의 답변을 제공는 챗봇을 개발 텍스트 정보를... 영상콘텐츠 속의 내용까지 검색하는 AI 기술 이 있어요 자연어 이해 기술로 구축된 AI 챗봇...',
#        '■ 제목 : [에이블런] 소셜 빅데이터 분석캠프_에이블캠프 체험활동단 1주차 ■ 내용 : 소셜 빅데이터를 통해 유의미한 정보 추출 및 인사이트를 얻는게 중요해짐 : 소셜 빅데이터 분석 프로세스 데이터 수집 -> 텍스트 마이닝(자연어처리, 키워드 및...',
#        '■ 제목 : 빅데이터 분석과 R 10편, 빅데이터 관련 용어 이해 ■ 내용 : 빅데이터를 처리하기 위해 개발한 소프트웨어 프레임워크 3) 아파치 하둡... 5) 자연어 처리 인간이 말하는, 발화하는 언어 현상을 기계적으로 분석해서...',
#        '■ 제목 : GM 크루즈 인베스터데이Under the Hood 2021: 자율주행... ■ 내용 : AI를 이용한 자연어 처리 기술이나 집을 구매하고 판매하는 ibuying도 그렇지만 구글의 웨이모가 특히 그런 생각을 강하게 만들었다. 몇년전부터 웨이모와 월마트가...',
#        '■ 제목 : 뤼이드, 교육 AI 학습 효과 입증에서 신뢰기반 구축까지 다각적... ■ 내용 : 특히, EDM에 채택된 점수 예측 알고리즘 연구는 최신 자연어 처리 기술을 교육 AI에 최초로 접목해 현재 최고 정확도 모델 대비 오차를 4% 감소시키며, 베스트...',
#        '■ 제목 : 패스트캠퍼스 챌린지 6일차(토요일) ■ 내용 : 좋아 자연어처리가 왜 어려운지에 대한 저번 강의에 이어 이번에는 한국어... 많아지고 처리할 것도 많아짐 따라서 형태소 분석기를 통해 하나로 줄여야 함 ex. 잡 / 다...',
#        '■ 제목 : [자연어처리] 자연어처리를 위한 KoNLPy 설치 ■ 내용 : - 한국어 정보 처리를 위한 파이썬 패키지 한국어 자연어처리를 위해선 반드시 필요한 패키지라고 할 수 있습니다. 먼저 KoNLPy를 설치하기 위해선...',
#        '■ 제목 : 자연어 처리 논문 분석 주제 - Opinion Mining and... ■ 내용 : 728x90 반응형 Opinion_mining_and_sentiment_analysis로 정함 https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=7724305 21.11.06 정함 1 해당 논문을 왜 선정하였는지 2...',
#        '■ 제목 : 다음주 정부부처 일정 및 주식/증시 일정 소개(11/8~11/12) ■ 내용 : 엔비디아 CEO 제슨황, GTC 기조연설 진행 엔터프라이즈 및 데이터센터 AI, 대화형 AI 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에...',
#        '■ 제목 : [2022 대선 후보 분석 15화] 민주당 이재명 VS 국민의힘 윤석열... ■ 내용 : 데이터를 분석하여 제공하는 매니지드 웹크롤링(Crawling) 서비스입니다. 자연어처리(감정분석, 형태소분석) 뿐만 아니라 이미지 분석 기술도 사용할 수 있습니다.',
#        '■ 제목 : 11월 공모주 일정 ( 트윔, 마인즈랩, 알비더블유, 바이옵트로... ■ 내용 : 사람이미지의 키오스크라는 건데, 마인즈랩의 M1은 아바타 기술, 음성인식·합성 기술, 자연어처리(NLP) 기술과 역량 등 AI기술을 총망라된 서비스입니다. 그냥 사람이...',
#        '■ 제목 : 쏘나타 장기렌트_비교견적을 통해 착한 가격으로 스마트하게... ■ 내용 : 기반의 자연어 음성 명령 기능과, 준자율주행급의 스마트 크루즈 컨트롤... 비용처리할 수 있으며, 추가로 차량 유류비로 사용되는 비용 중 매년 700만원까지 비용처리를...',
#        '■ 제목 : 패스트캠퍼스 챌린지 5일차 ■ 내용 : 자연어처리부트캠프에 합격한 나는 오늘밤이 지나가기전에 배송지를 입력해야한다. 이게 맞는 길이 맞을까 계속 고민되지만 꿈에다가 한표를 던지기로 했다. 자꾸...',
#        "■ 제목 : [IT 소식] 젠슨 황 엔비디아 CEO, 'GTC' 기조연설 나선다…AI... ■ 내용 : 젠슨 황 CEO는 기조연설에서 엔터프라이즈 및 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 최신 기술을 비롯해 로보틱스부터 헬스케어, 자율주행차량에...",
#        '■ 제목 : 마이크로소프트(MSFT) 주가: 마소도 메타버스, 인공지능(AI)... ■ 내용 : Open AI란 일론머스크가 처음 투자했던 인공지능 개발 기구인데, 이 기구에 지분을 투자해 만든 대규모 자연어처리 모델이 GPT-3다. MS가 이 모델의 라이선스 독점...',
#        '■ 제목 : 인공지능 대규모(그랜드) 도전잇기(챌린지) 5차대회 2단계... ■ 내용 : 5차대회는 자연어의 이해와 수리적 사고?추론에 기반 한 복합지능 기술... 대회에서 자연어 처리 규칙을 완화하고 문서(텍스트)로 묘사된 도형문제를 추가하는...',
#        '■ 제목 : [ESG/투자] 팬데믹 시대가 일깨워준 지속가능한 투자의 중요성 ■ 내용 : 이 연구는 자연어 처리를 이용하여 노무 관리, 공급망 관리, 기업 운영 등에서 기업이 취한 이해관계자 친화적인 행동을 평가하였습니다. 이해관계자 친화적인 행동을...',
#        '■ 제목 : [물류매거진] CJ대한통운 / 택배기사 돕는 ‘AI 비서’ 도입 ■ 내용 : 음성인식(STT), 음성합성(TTS), 자연어처리(NLP) 등 다양한 AI 기술을 융·복합해 사용자 환경에 최적화했다. CJ대한통운은 체감도 높은 정교한 서비스를 구현하기 위해...',
#        '■ 제목 : 딥러닝, 머신러닝, 인공지능 차이점 알아보기 ■ 내용 : 자연어 처리 4. 추천시스템 이렇게 4가지 분야에서 다양하게 사용되고 있더라고요. 지금까지 인공지능, 머신러닝, 딥러닝에 대하여 간단하게 알아보는 시간을 가졌는데...',
#        '■ 제목 : 과기정통부, ‘인공지능 그랜드 챌린지’ 진행 ■ 내용 : 5차 대회는 AI 기술을 활용한 수학 문제 해결을 주제로, 자연어 이해와 수리적... 대회에서 자연어 처리 규칙을 완화하고 텍스트로 묘사된 도형문제를 추가하는 등...',
#        '■ 제목 : 콴다라는 별이 뜨고 메가스터디는 지고 있네 ■ 내용 : 요새는 자연어처리 AI를 통해 문자로 하는 질문에 대해서도 답변할 수 있도록 하는 방안도 추진 중이라는데, 이뿐만 아니라 콴다 이용자들끼리 공부 잘하는 법, 입시...',
#        '■ 제목 : 수지군청 전화안내시스템에 음성합성기 ReadSpeaker™ 혜련... ■ 내용 : 성우, #자연어처리, #TTS프로그램, #콜센터, #아나운서, #영어 교육, #DNN, #NLP, #목소리프로그램 #e-book #마이토키 #STT #영어교육 #리드스피커...',
#        '■ 제목 : AI그랜드 챌린지, 원자력연-젠티연합팀 1위로 3단계 진출 ■ 내용 : 5차 대회는 자연어의 이해와 수리적 사고 추론에 기반한 복합지능 기술 확보를... 성균관대 인공지능대학원 연구팀은 자연어 처리 연구 역량을 바탕으로 수학 문제...'],
#       dtype=object)

# %%
#제목과 내용 
print('● 데이터 타입 : ', type(data_tit_con))
print('● shape : ', data_tit_con.shape)  #1차원 리스트 개념 
print('● 데이터 개수 : ',len(data_tit_con))
# Out:
# ● 데이터 타입 :  <class 'numpy.ndarray'>
# ● shape :  (100,)
# ● 데이터 개수 :  100

# %%
num = 1

for i in data_tit_con :
    print('제목과 내용', num, ')', i)
    print(type(i))
    print('-'*50)
    num += 1
# Out:
# 제목과 내용 1 ) ■ 제목 : 트링크AI는 지역관광 솔루션입니다 ■ 내용 : 텍스트 마이닝, 대화형 자연어 처리 기술로 강화된 인공지능이 해답을 제시합니다. 3. 모든 담당자가 쉽게 인사이트를 활용할 수 있도록 시각화 자료를 제공합니다....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 2 ) ■ 제목 : 패스트캠퍼스 챌린지 10일차(수요일) ■ 내용 : ly/3FVdhDa #패스트캠퍼스 #패캠챌린지 #직장인인강 #직장인자기계발 #패스트캠퍼스후기 #김기현의딥러닝을활용한자연어처리입문올인원패키지Online
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 3 ) ■ 제목 : 다급한 기업, IT인재 직접 키워…컴공·전산 서울 대졸자 추월 ■ 내용 : 이 프로그램은 자연어 처리 기법을 활용해 법률 문서의 내용이 잘 요약된 문장을... 신경망처리장치(NPU) 개발을 위 해선 컴퓨터공학을 비롯한 소프트웨어에 대한...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 4 ) ■ 제목 : 2021년 11월 9일 상한가(갤럭시아에스엠, 셀바스AI, 하이트론... ■ 내용 : 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공하고... 이 회사는 건축용 자재를 제조하는 데크 플레이트 부문, 조선용 철판을 표면처리...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 5 ) ■ 제목 : 인공지능을 넘어 인공자아의 시대로 도약 ■ 내용 : 일각에서는 2032년이면 GPT-3보다 1000배의 학습처리능력을 가진 인공지능이 탄생할... 또한, 일반 상식에 대한 이미지나 자연어 처리가 가능하도록, 상식을 객관적으로...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 6 ) ■ 제목 : [디지털 시대의 전공들] 중앙대학교 소프트웨어 학부 ■ 내용 : 영상처리 4학년 캡스톤디자인(2), 멀티코어컴퓨팅, 무선이동통신, 네트워크응용설계, 정보보호이론, 생체인식및응용, 자연어처리및정보검색, 패턴인식, 컴퓨터비전...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 7 ) ■ 제목 : 셀바스AI-우리가 모르는 메타버스 수혜주, 절대적 저평가... ■ 내용 : 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고 있다. 셀바스AI의 음성기술을 주목해야한다. 각 도메 인별 데이터 학습을 통해 98...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 8 ) ■ 제목 : NVIDIA, 신규 Jetson AGX Orin 공개 ■ 내용 : 향상된 처리능력, 이전 세대인 Jetson AGX Xavier의 폼팩터 및 핀에 대한... 이는 개발자가 자연어 이해, 3D 인식, 멀티센서 퓨전 등과 관련된 엣지(edge)...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 9 ) ■ 제목 : 메타버스 관련주로 떠오르는 셀바스AI +78% 성공 ■ 내용 : 영상지능, 자연어처리 등 HCI 기술 경쟁력을 강화하고 있다고 재벌투자연구소 전문가분께서 알려주셨습니다 주식 후기에서 가장 중요한 수익 이야기를 해볼까...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 10 ) ■ 제목 : [GIP 뉴스레터_11월 2주] 넷플릭스가 게임 만든다고? ■ 내용 : 대표적으로 신약개발, 배터리 성능 개선, 날씨 예측, 주식 선별, 양자 자연어처리, 이동경로 최적화, 교통 관리, 데이터 보호 등 생활과 밀접한 기술에 양자 컴퓨터가...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 11 ) ■ 제목 : [자바공부] 자바알고리즘이란 무엇인가? ■ 내용 : 컴퓨터는 정확하게 무엇을 해야 할지 처리 내용과 처리 순서를 모두 구체적으로... 알고리즘은 자연어, 의사코드, 순서도, 프로그래밍 언어 등으로 표현이 가능합니다....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 12 ) ■ 제목 : 파이썬의 강력함을 느낄 수 있는 「한 권으로 다지는 머신... ■ 내용 : ▶ 심층 신경망(DNN) 처리 ▶ 자연어 처리 ▶ 편미분 방정식 ▶ 추상화 ▶ 이미지... 주요 역할: 데이터 조작 및 분석 NLTK NLTK는 Natural Language Toolkit(자연어 툴킷)의...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 13 ) ■ 제목 : 11/10 주린이의 받아쓰는 시황정리(feat. 삼프로 tv) ■ 내용 : AI, 자연어 처리 기술 - 로보틱스, 헬스케어, 자율주행 관련 AI 기술 - 메타버스를 위한 새로운 애플리케이션 - 공장도시 및 지역 디지털 트윈 구축 =>딥러닝...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 14 ) ■ 제목 : [월230/수원] 삼성전기 AI인공지능 챗봇 트레이너 ■ 내용 : 20년간 자체 개발한 자연어처리기술과 머신러닝, 텍스트마이닝, 의미분석 및 검색 등이 복합적으로 융합된 인공지능 기반 하이브리드 챗봇 솔루션입니다....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 15 ) ■ 제목 : [영상] 전상호 코어에이아이(kore.ai,) 상무, '대화형 AI... ■ 내용 : kr) #데모 #코어에이아이 #원격지원 #챗봇 #IVR #컨택센터 #자연어처리... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 16 ) ■ 제목 : 빅 데이터란? 특징과 의미를 알아봅니다. ■ 내용 : 학습, 자연어 처리, 패턴 인식 등이 분석 기법에 해당한다. 복잡성(Complexity) 데이터의 구조나 데이터의 획득과 처리에 드는 속도, 도메인 규칙이나, 저장 타입 등...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 17 ) ■ 제목 : [개발 2유닛] 무하유의 서비스를 만들어가는 “서비스... ■ 내용 : 민프로 저는 ‘자연어를 이해하는 AI 기술 기업, 무하유’라는 회사 슬로건을 보고... 서비스에 문장 처리 기술과 AI 기술을 적용시키는 좋은 경험을 할 수 있고요....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 18 ) ■ 제목 : [에임리치] 비트코인 시총 3조 달러 근접… ‘ETH’ 급등... ■ 내용 : 예산법안을 처리한 것이 증시에 호재로 작용하면서 소폭 상승 마감했다.... 추출하여 자연어 처리방식으로 실시한 '비트코인'(bitcoin)라는 단어에 대한...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 19 ) ■ 제목 : 11월 10일 삼프로 티비 - 월가모닝라이브, 오늘아침라이브 ■ 내용 : 대화형AI, 자연어 처리기술, 로보틱스, 헬스케어, 자율주행 관련기술 메타버스를 위한 새로운 어플리케이션 공장도시 및 지역 디지털 트윈 구축 -딥 러닝...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 20 ) ■ 제목 : "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼... ■ 내용 : 제목: "공식의 아름다움" 원자폭탄에서 비트코인까지 세상을 바꾼 절대 공식 저자: 양자학파 출판: 미디어숲 발매: 2021. 11. 10 저자 : 양자학파 양자학파는 자연 과학(수학...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 21 ) ■ 제목 : Meta의 AI 전략 (AI 시리즈 1) ■ 내용 : Natural Language Processing Natural Language, 즉 인간이 사용하는 자연어를 처리하는 기술입니다. 언어 장벽을 허물고 어떤 언어를 사용하든 누구와 대화하든 쉽게...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 22 ) ■ 제목 : 21,11,10 검색조회수가장많은 단어키워드 상위노출유입분석 ■ 내용 : 16% 자연어 처리 국어 0.16% 전자순찰 tcr-200 0.16% 토카막 네트워크 0.16% 폐기물이 에너지로 변환 미분방정식 0.16% 홍합 접착 단백질 0.16...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 23 ) ■ 제목 : 멀티캠퍼스 인공지능 자연어처리(NLP) 기반 기업 데이터 분석... ■ 내용 : 단순히 '인공지능 자연어처리'라는 키워드만 보고 바로 지원했고, NLP가 무엇인지도 모르는 상태였다. 개념적인 내용은 블로그, 유튜브를 통해 공부하고 있었지만...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 24 ) ■ 제목 : (211109) 셀바스AI - 우리가 모르는 메타버스 수혜주, 절대적... ■ 내용 : (TTS), 자연어처리, 필기인식 등 AI솔루션 제공 └ 국내 최고 음성인식률 보유, 음성합성 기술 M/S 60%로 국내 1위 └ 쌍방향커뮤니케이션 핵심기술인 음성기술을...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 25 ) ■ 제목 : 셀바스AI 주가 전망 : 인공지능, 메타버스, 음성인식 관련주 ■ 내용 : 영상지능, 자연어처리 등 HCI 기술 경쟁력을 가오하하고 있음 - 음성합성... 마우스, 키보드 등 전통적인 컴퓨터 입력장치가 음성인식, 음성합성, 자여어처리...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 26 ) ■ 제목 : 2021/11/09 ■ 내용 : 흘러흘러 자연어처리 딥러닝을 하는중이다. 문제는 단기간에 계속 효율이 안나와서 열심히 자신과의 싸움중 나무만보고 숲은 못본다는게 이런 경우인거같다 내년쯤 이...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 27 ) ■ 제목 : 마이크로소프트(MSFT)도 메타버스에 합류! 그에 대한 완벽 분석! ■ 내용 : ☆ Azure Open AI Service 현존 최대 자연어 처리 프로그램인 GPT-3 API를 클라우드 기반으로 제공합니다. 즉, 애저를 사용하면 고객 서비스 로그 상의 공통된 불만사항을...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 28 ) ■ 제목 : 셀바스AI 주가 숨겨진 메타버스 수혜주 기대감에 상한가 ■ 내용 : 음성합성, 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을 주목해야 한다고 합니다 각 도메인별 데이터 학습을 통해 98% 이상의 국내 최고 음성...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 29 ) ■ 제목 : AI 최강의 수업 ■ 내용 : 전처리 방법이라고 볼 수 있다. 차원 감소를 위 해서는 주성분 분석... - 자연어는 애매하다. 상황에 따라 단어의 역할, 의미가 달라진다. 의미만 전달하는 것이 아니라...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 30 ) ■ 제목 : [경북대학교 데이터융합연구원] 2021년 고용노동부 K... ■ 내용 : 데이터 처리 라이브러리 Pandas ▶ 데이터 크롤링정제 등 총 256시간 진행된다. 심화과정은 47일 동안 ▶ 빅데이터 통계기본 ▶ 자연어 처리 ▶ 데이터 분석...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 31 ) ■ 제목 : 21년 11월 9일 화 주식시황 ■ 내용 : #코스피#코스닥#상한가 21년 11월 9일 화요일 주식시황입니다. 양대 지수 모두 소폭 상승하면서 강보합입니다. 코스피는 여전히 하락하는 중이고 코스닥은 옆으로...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 32 ) ■ 제목 : 아진산업,하이트론,제일테크노스,셀바스AI ■ 내용 : 표면처리(Shot Blast) 및 절단가공(Steel Cutting)하는 조선부문으로 사업을 영위하고... (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공중인데 특히 음성기술을...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 33 ) ■ 제목 : 프로그래밍 언어의 간추린 역사 ■ 내용 : 상당부분 자연어에 의존하며, 포트란에 비해 많은 양의 데이터를 처리하도록 설계됐다. 코볼은 처음 등장한 후 가장 널리 사용되는 프로그램 언어 중 하나로...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 34 ) ■ 제목 : [Kore.ai XO Platform Release v9.1] 100개 이상 언어로... ■ 내용 : 컨택센터 #자연어처리 #챗봇솔루션 #자동응답서비스 #AI비서 #KOREAI #코어AI... 인지검색 #자연언어처리 #챗봇고도화 #챗봇플랫폼 #가상직원 #디지털직원 #AI직원...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 35 ) ■ 제목 : 상한가(11월9일),갤럭시아에스이엠/하이트론... ■ 내용 : 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을... 표면처리·절단가공하는 조선부문 등을 영위하고 있습니다. 이 회사의 박정식...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 36 ) ■ 제목 : [2021 금융산업 전문인력 AI 역량강화] #온라인으로_배우는... ■ 내용 : OCR, 자연어 처리 등 딥러닝을 통해 해결한 문제 소개 코스 2 소개 페이지 ♂? 수강하러 가기 ♀? 코스 3. 간편결제 및 자산관리 사례 ? 디지털 전환을 통한...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 37 ) ■ 제목 : 셀바스AI 메타버스 가상 캐릭터와 소통하는 AI음성인식기술로... ■ 내용 : 셀바스AI는 AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을 제공하는 업체다. 최근 증권가에서 셀바스AI가 주목받는 건 메타버스 내에서 셀바스AI...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 38 ) ■ 제목 : [가까운 책] 트렌드코리아 2022 - 김난도, 전미영, 최지혜 외 ■ 내용 : 빅데이터 자연어 처리NLP 등 데이터를 다양한 관점에서 분석하고 있다. 코오롱-카이스트 라이프스타일 이노베이션 최우수상을 수상했다. 저자 : 권정윤...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 39 ) ■ 제목 : 셀바스AI 주가 상한가 메타버스 음성인식 ■ 내용 : 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음.... 셀바스AI는 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 40 ) ■ 제목 : [재벌투자연구소 투자정보]-장중에 78%로 수익매도#셀바스AI ■ 내용 : 동사는 22년간의 지속적인 연구개발 투자를 통해 음성지능, 필기지능, 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고 있음....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 41 ) ■ 제목 : 가을의 기록 ■ 내용 : 회사에서 자연어처리 특강을 하는데 나는 1도 모르겠다.. 꼭 배워야할 것 같은데 과외를 해야나아 ㅋㅋㅋㅋ.. 유투브 열심히보면 알 수 있지않나여? 하핳,, 어렵네여 진짜...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 42 ) ■ 제목 : 기술평가 A, AA 등급을 받고 기술특례상장 초읽기에 들어간... ■ 내용 : 음성인식과 자연어처리(NLP) 등의 기술을 이전 받아 다양한 분야의 첨단 AI 서비스 플랫폼을 개발하며 대표적인 AI 기업으로 성장중인 비상장회사 "마인즈랩"를...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 43 ) ■ 제목 : 품절주 관련주, 하이트론 주가,이재명 후보 수술실 관련 발언... ■ 내용 : 오늘의급등주 하이트론 셀바스AI 갤럭시아에스엠 일정실업 갤럭시아머니트리 셀바스AI AI 기술을 활용해 음성인식과 음성합성, 자연어 처리 등의 기술을...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 44 ) ■ 제목 : 경북대학교, K-Digital Training 빅데이터 분석가 양성과정 ■ 내용 : 한국어 처리 패키지 8 자연어 처리 미니프로젝트 16 데이터 분석 데이터 기초통계분석 8 데이터 심화 분석 8 데이터 분석 미니프로젝트 16 데이터 시각화와...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 45 ) ■ 제목 : <그냥 하지 말라> | 빅데이터 전문가 송길영 부사장이 말하는... ■ 내용 : 바이브컴퍼니는 텍스트 마이닝, 대규모 정보탐색과 자연어 처리 등 수십억 개의 소셜미디어 글들이 담고 있는 소비자의 의견을 인공지능 기술을 이용하여 자동으로...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 46 ) ■ 제목 : 콘텐츠 홍수 속, 플랫폼이 필요해 ■ 내용 : 구글 번역 아닌가 했는데, 헤이버니를 만든 트위그팜 은 딥러닝 기반의 자연어처리 전문기업으로 번역쪽에 특화되어 있었다. 오, 멋진데. 헤이버니 웹사이트 캡쳐...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 47 ) ■ 제목 : 기 들릴(Guy Delisle) - 평양(Pyongyang) (2003) ■ 내용 : 만화영화 제작이나 해킹 같은 거야 나랑 관련이 별로 없는 분야라지만, 자연어처리에서마저... 나는 대체 뭐란 말인가. 사실 직원들은 별도로 봉급을 받긴 하지만, 쌀...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 48 ) ■ 제목 : 엔비디아 GTC 컨퍼런스 개최 (feat. 무료 등록방법) ■ 내용 : <메타버스에서의 연결 : 엔비디아 GTC 키노트 제작 과정> 젠슨 황 CEO는 기조연설에서 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 기술, 로보틱스, 헬스케어...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 49 ) ■ 제목 : 중국 빅테크, 반도체 자체 개발에 나서는 이유 ■ 내용 : 그중에서도 텐센트가 주력하는 것은 AI반도체가 될 것이며, 추후 이미지·동영상 처리, 자연어 처리, 검색 추천 등의 기능을 개발할 예정으로 알려졌다. 텐센트 본사...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 50 ) ■ 제목 : 키플홀딩스 장외주식매도매수문의 ■ 내용 : #키플홀딩스 #키플홀딩스주식 #키플홀딩스장외주식 #음성인식#기계번역#자연어처리 #오픈API #AI기반언어처리 #언어솔루션 #AI어시스턴트시스템공동개발...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 51 ) ■ 제목 : 매일매일 경제노트(2021년11월3일) ■ 내용 : 자동화해 처리하는 기술이다. 네이버클라우드는 RPA 서비스의 경쟁력 확보를... MS는 또 현재 가장 강력한 자연어 처리 인공지능 모델인 GPT-3를 자신의 클라우드...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 52 ) ■ 제목 : 치매 예방부터 돌봄까지…AI로 어르신 건강·안전 지키는 광주... ■ 내용 : 인공지능 자연어 처리기술을 접목해 120만건의 회화 전개가 가능하고 보호자, 관리자 애플리케이션을 통해 돌봄 인형의 목소리로 어르신과 대화도 할 수 있다. AI...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 53 ) ■ 제목 : "전문가 수준의 영어 문제, AI가 5초 만에 제작"...이형종... ■ 내용 : 영어 문제 자동생성 서비스 'ATM(AI Test Maker)' 개발 자연어처리(NLP) 기반으로 지문... 그만큼 지문을 분석하는 자연어처리(NLP) 기술이 높아야 하고, 이를 응용할 수...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 54 ) ■ 제목 : 초거대 AI 개발에 한창인 LG, 계열사별 AI 연구 상황은? ■ 내용 : 활용 중인 AI 기술 종류는 음성인식·합성, 자연어처리, 영상처리·추천·예측 등 다양하다. LG유플러스가 가장 많은 AI 기술을 적용하는 서비스 주제는 IPTV다. IPTV...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 55 ) ■ 제목 : [사주임의 전략소개 #11] Ai주식자동매매프로그램의... ■ 내용 : 딥러닝과 자연어 처리에 크게 의존하고 있고, 이런 기술들을 통해 엄청 많은 데이터의 패턴을 인식하고 처리하며 실생활에도 많이 활용되고 있어요 이러한 인공지능의...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 56 ) ■ 제목 : 마이크로소프트 3D 아바타 회의/매타버스, 인공지능AI GPT-3... ■ 내용 : 만든 자연어 처리 모델인 GPT-3은 인류 역사상 가장 뛰어난 언어 인공지능 모델이라고 평가를 받고 있다 GPT-3 이 기존 AI보다 뛰어난 점은 1) 특정 주제만이 아닌...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 57 ) ■ 제목 : 딥 러닝 - fastai 를 이용한 예제 ■ 내용 : 현재 사용되는 분야 ● 컴퓨터 영상 처리 · 물체 인식: object... ( 자연어 처리 ) · 게시글의 답글 달기 · 모방한 글 쓰기...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 58 ) ■ 제목 : 2021. 11. 8 ■ 내용 : (TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제공 - 이에 셀바스AI는 쌍방향커뮤니케이션 핵심기술인 음성기술을 메타버스 세계관 속 버추얼 휴먼에 접목시킬...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 59 ) ■ 제목 : 마이크로소프트의 또 다른 전략 ■ 내용 : 대규모 자연어처리(NLP) 모델인 GPT-3의 라이선스 독점 사용권을 사들였다고 발표 = GPT-3는 인류 역사상 가장 뛰어난 '언어 인공지능'이라고 평가 받아온 모델...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 60 ) ■ 제목 : [SBA 새싹(SeSAC) X 솔트룩스] 취업연계 인공지능 SW교육... ■ 내용 : [인공지능 자연어처리 및 음성인식/합성기술을 활용한 응용SW 개발자 양성과정] ● 모집개요 - 자연어처리와 음성인식/합성 기술을 활용하여 현업에서 사용하는...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 61 ) ■ 제목 : AI 스타트업, 브랜드 포지셔닝부터 제대로 <#솔트룩스> ■ 내용 : 기계학습과 자연어 처리 스타트업 ㈜시스메타가 이들의 시초라고 합니다. 창업... 대화 처리 딥러닝 기반의 지식 학습, 음성인식/합성 등에 많은 투자를 진행하기도...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 62 ) ■ 제목 : 기계번역 솔루션 랭귀지 위버 CASE STUDY :: 한화 디펜스 ■ 내용 : 안녕하세요, 유니포인트 입니다. 여러 기업, 기관들도 물론이지만, 특히나 국방관련의 사업에서의 글로벌 의사소통 역량은 보다 더욱 빠르고 정확해야합니다....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 63 ) ■ 제목 : nlp ALBERT 논문 정리(논문 리뷰) - A Lite BERT for... ■ 내용 : 포스팅 개요 이번 포스팅은 자연어처리(NLP) 논문 중 A Lite BERT... 데이터 처리량 (number of training steps) 을 제어하는 대신 ? Actual...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 64 ) ■ 제목 : 인간보다 우월한 AI, 축복인가 재앙인가 ■ 내용 : 자연어 처리기술(Natural language processing)이 있다. 컴퓨터가 인간의 언어를 알아들을 수 있게 해 사람처럼 인식하고 말하고 소통할 수 있게 하는 기술이다. 자연어...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 65 ) ■ 제목 : 마인즈랩공모주 분석 : 상담도 AI로 ■ 내용 : 12 마인즈랩은 어떤 회사인가 마인즈랩은 자연어라고 불리는 사람들의 일상적인... 물론 아직까지는 자연어 처리 기술이 좀 더 발전되어야 하겠지만 향후 매우...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 66 ) ■ 제목 : Tech Trends_VR 비즈니스 동향 ('211112)_MS도 메타버스 진격... ■ 내용 : MS는 자연어 처리 인공지능 모델인 GPT-3를 활용해 대량의 텍스트를 자동 요약해주는 소프트웨어, MS 오피스 제품과 결합해 표나 메모를 자유롭게 캔버스에 그리듯...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 67 ) ■ 제목 : 211108 2022년 전망~ 어떤 섹터, 종목들이 괜찮을지? 한번... ■ 내용 : 제가 매일 듣는 하나금융투자의 하나모닝브리핑 방송에 언급된 것을 요약 위주로 기술하였고 기억하고 싶은 요점만 뽑아봤습니다. 상세한 내용은 Daily Report를....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 68 ) ■ 제목 : [기업분석] 셀바스AI - 절대적 저평가 상태인 메타버스... ■ 내용 : 분야에서 #자연어처리 기술의 중요성이 증가하고 있습니다. 셀바스AI는 음성... 음성인식(STT), 음성합성(TTS), 자연어처리, 필기인식 등의 AI 솔루션을 제 공하고...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 69 ) ■ 제목 : GPT-1, BERT, GPT-2 모델 이해 ■ 내용 : next sentence prediction(NSP) 문장 두 개를 처리하는 자연어 처리의 예로는 질의 및 응답을 하는 경우가 있고, 문장 간의 상관관계를 예측하는...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 70 ) ■ 제목 : 11월 8일~11월12일(11월2주차)주요 증시일정-엔비디아... ■ 내용 : 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에 이르기까지 모든 분야를 아우르는 엔비디아의 최신 AI를 공개할 예정) →메타버스...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 71 ) ■ 제목 : 자료구조 총정리 ■ 내용 : docx 파일 다운로드 1장 자료구조와 알고리즘 문제 처리를 위한 프로그램 작성... 알고리즘을 자연어로 구체적으로 적고 > 흐름도를 그리고 > 의사 코드(유사코드)를...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 72 ) ■ 제목 : Transformer 이론 및 구성요소 ■ 내용 : 트랜스포머는 비전 테스크에 좋은 Batch Normalization이 아닌 자연어 처리에 강한 Layer Normalization을 사용하고 있습니다. 이미지는 사이즈가 고정되어...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 73 ) ■ 제목 : [셀바스AI] 메타버스의 잠재력을 가진 AI기업 ■ 내용 : 영상지능, 자연어처리 등 HCI(Human-Computer Interaction) 기술 경쟁력을 강화하고... 음성합성, 자연어처리, 필기인식 등으로 진화시키는 기술을 의미합니다. 제품에 대한...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 74 ) ■ 제목 : 메타버스 영향력, 기대, 평가, 취약점, 필요요소, 전망 등... ■ 내용 : 자연어처리, 음성처리, 시각처리 등 AI 기술이 사람이 못하는 부분을 감시자로서 역할을 하여 이용자들로 하여금 충분히 경각심을 고취시킬 수 있으리라 생각합니다....
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 75 ) ■ 제목 : [Book]AI 101, 인공지능 비즈니스의 모든 것 ■ 내용 : 그러던 중 2010년 세번째 붐이 일어나게되는데 그 원동력은 강력한 그래픽처리장... 6-3 자연어처리 기술 6-4 엘모와 버트 6-5 자연어처리를 넘어 7장 AI 공정성 7-1 AI...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 76 ) ■ 제목 : [3줄 독후감] 네이버 vs 카카오 ■ 내용 : 선순환 구조가 완성된 것으로 보이나, 카카오는 아직 중구 난방의 느낌. (개인 의견) * 양사 모두 AI / 로봇 / IOT / TTS / OCR / 자연어 처리 등등에 대한 연구를 진행 중.
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 77 ) ■ 제목 : IONQ(아이온큐) - 투자설명서 2편 (사업편) ■ 내용 : 정보 처리, 통신, 에너지, 운송, 생명 공학, 생명을 포함한 과학, 농업 및 산업... 발전했으며 처리 능력은 몇 년마다 약 2배씩 증가합니다(무어의 법칙)...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 78 ) ■ 제목 : 인공지능개발 에이아이글로벌 ! ■ 내용 : 자연어 처리 기반으로 최적의 답변을 제공는 챗봇을 개발 텍스트 정보를... 영상콘텐츠 속의 내용까지 검색하는 AI 기술 이 있어요 자연어 이해 기술로 구축된 AI 챗봇...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 79 ) ■ 제목 : [에이블런] 소셜 빅데이터 분석캠프_에이블캠프 체험활동단 1주차 ■ 내용 : 소셜 빅데이터를 통해 유의미한 정보 추출 및 인사이트를 얻는게 중요해짐 : 소셜 빅데이터 분석 프로세스 데이터 수집 -> 텍스트 마이닝(자연어처리, 키워드 및...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 80 ) ■ 제목 : 빅데이터 분석과 R 10편, 빅데이터 관련 용어 이해 ■ 내용 : 빅데이터를 처리하기 위해 개발한 소프트웨어 프레임워크 3) 아파치 하둡... 5) 자연어 처리 인간이 말하는, 발화하는 언어 현상을 기계적으로 분석해서...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 81 ) ■ 제목 : GM 크루즈 인베스터데이Under the Hood 2021: 자율주행... ■ 내용 : AI를 이용한 자연어 처리 기술이나 집을 구매하고 판매하는 ibuying도 그렇지만 구글의 웨이모가 특히 그런 생각을 강하게 만들었다. 몇년전부터 웨이모와 월마트가...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 82 ) ■ 제목 : 뤼이드, 교육 AI 학습 효과 입증에서 신뢰기반 구축까지 다각적... ■ 내용 : 특히, EDM에 채택된 점수 예측 알고리즘 연구는 최신 자연어 처리 기술을 교육 AI에 최초로 접목해 현재 최고 정확도 모델 대비 오차를 4% 감소시키며, 베스트...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 83 ) ■ 제목 : 패스트캠퍼스 챌린지 6일차(토요일) ■ 내용 : 좋아 자연어처리가 왜 어려운지에 대한 저번 강의에 이어 이번에는 한국어... 많아지고 처리할 것도 많아짐 따라서 형태소 분석기를 통해 하나로 줄여야 함 ex. 잡 / 다...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 84 ) ■ 제목 : [자연어처리] 자연어처리를 위한 KoNLPy 설치 ■ 내용 : - 한국어 정보 처리를 위한 파이썬 패키지 한국어 자연어처리를 위해선 반드시 필요한 패키지라고 할 수 있습니다. 먼저 KoNLPy를 설치하기 위해선...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 85 ) ■ 제목 : 자연어 처리 논문 분석 주제 - Opinion Mining and... ■ 내용 : 728x90 반응형 Opinion_mining_and_sentiment_analysis로 정함 https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=7724305 21.11.06 정함 1 해당 논문을 왜 선정하였는지 2...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 86 ) ■ 제목 : 다음주 정부부처 일정 및 주식/증시 일정 소개(11/8~11/12) ■ 내용 : 엔비디아 CEO 제슨황, GTC 기조연설 진행 엔터프라이즈 및 데이터센터 AI, 대화형 AI 및 자연어 처리를 위한 최신 기술과 로보틱스부터 헬스케어, 자율주행차량에...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 87 ) ■ 제목 : [2022 대선 후보 분석 15화] 민주당 이재명 VS 국민의힘 윤석열... ■ 내용 : 데이터를 분석하여 제공하는 매니지드 웹크롤링(Crawling) 서비스입니다. 자연어처리(감정분석, 형태소분석) 뿐만 아니라 이미지 분석 기술도 사용할 수 있습니다.
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 88 ) ■ 제목 : 11월 공모주 일정 ( 트윔, 마인즈랩, 알비더블유, 바이옵트로... ■ 내용 : 사람이미지의 키오스크라는 건데, 마인즈랩의 M1은 아바타 기술, 음성인식·합성 기술, 자연어처리(NLP) 기술과 역량 등 AI기술을 총망라된 서비스입니다. 그냥 사람이...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 89 ) ■ 제목 : 쏘나타 장기렌트_비교견적을 통해 착한 가격으로 스마트하게... ■ 내용 : 기반의 자연어 음성 명령 기능과, 준자율주행급의 스마트 크루즈 컨트롤... 비용처리할 수 있으며, 추가로 차량 유류비로 사용되는 비용 중 매년 700만원까지 비용처리를...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 90 ) ■ 제목 : 패스트캠퍼스 챌린지 5일차 ■ 내용 : 자연어처리부트캠프에 합격한 나는 오늘밤이 지나가기전에 배송지를 입력해야한다. 이게 맞는 길이 맞을까 계속 고민되지만 꿈에다가 한표를 던지기로 했다. 자꾸...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 91 ) ■ 제목 : [IT 소식] 젠슨 황 엔비디아 CEO, 'GTC' 기조연설 나선다…AI... ■ 내용 : 젠슨 황 CEO는 기조연설에서 엔터프라이즈 및 데이터센터 AI, 대화형 AI와 자연어 처리를 위한 최신 기술을 비롯해 로보틱스부터 헬스케어, 자율주행차량에...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 92 ) ■ 제목 : 마이크로소프트(MSFT) 주가: 마소도 메타버스, 인공지능(AI)... ■ 내용 : Open AI란 일론머스크가 처음 투자했던 인공지능 개발 기구인데, 이 기구에 지분을 투자해 만든 대규모 자연어처리 모델이 GPT-3다. MS가 이 모델의 라이선스 독점...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 93 ) ■ 제목 : 인공지능 대규모(그랜드) 도전잇기(챌린지) 5차대회 2단계... ■ 내용 : 5차대회는 자연어의 이해와 수리적 사고?추론에 기반 한 복합지능 기술... 대회에서 자연어 처리 규칙을 완화하고 문서(텍스트)로 묘사된 도형문제를 추가하는...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 94 ) ■ 제목 : [ESG/투자] 팬데믹 시대가 일깨워준 지속가능한 투자의 중요성 ■ 내용 : 이 연구는 자연어 처리를 이용하여 노무 관리, 공급망 관리, 기업 운영 등에서 기업이 취한 이해관계자 친화적인 행동을 평가하였습니다. 이해관계자 친화적인 행동을...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 95 ) ■ 제목 : [물류매거진] CJ대한통운 / 택배기사 돕는 ‘AI 비서’ 도입 ■ 내용 : 음성인식(STT), 음성합성(TTS), 자연어처리(NLP) 등 다양한 AI 기술을 융·복합해 사용자 환경에 최적화했다. CJ대한통운은 체감도 높은 정교한 서비스를 구현하기 위해...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 96 ) ■ 제목 : 딥러닝, 머신러닝, 인공지능 차이점 알아보기 ■ 내용 : 자연어 처리 4. 추천시스템 이렇게 4가지 분야에서 다양하게 사용되고 있더라고요. 지금까지 인공지능, 머신러닝, 딥러닝에 대하여 간단하게 알아보는 시간을 가졌는데...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 97 ) ■ 제목 : 과기정통부, ‘인공지능 그랜드 챌린지’ 진행 ■ 내용 : 5차 대회는 AI 기술을 활용한 수학 문제 해결을 주제로, 자연어 이해와 수리적... 대회에서 자연어 처리 규칙을 완화하고 텍스트로 묘사된 도형문제를 추가하는 등...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 98 ) ■ 제목 : 콴다라는 별이 뜨고 메가스터디는 지고 있네 ■ 내용 : 요새는 자연어처리 AI를 통해 문자로 하는 질문에 대해서도 답변할 수 있도록 하는 방안도 추진 중이라는데, 이뿐만 아니라 콴다 이용자들끼리 공부 잘하는 법, 입시...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 99 ) ■ 제목 : 수지군청 전화안내시스템에 음성합성기 ReadSpeaker™ 혜련... ■ 내용 : 성우, #자연어처리, #TTS프로그램, #콜센터, #아나운서, #영어 교육, #DNN, #NLP, #목소리프로그램 #e-book #마이토키 #STT #영어교육 #리드스피커...
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 100 ) ■ 제목 : AI그랜드 챌린지, 원자력연-젠티연합팀 1위로 3단계 진출 ■ 내용 : 5차 대회는 자연어의 이해와 수리적 사고 추론에 기반한 복합지능 기술 확보를... 성균관대 인공지능대학원 연구팀은 자연어 처리 연구 역량을 바탕으로 수학 문제...
# <class 'str'>
# --------------------------------------------------

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 3. 문장에서 [(형태소, 품사)] 및 명사 추출하기
# </span>

# %% [markdown]
# <span style="color: magenta ; font-size: 18pt">
# ● Okt() 활용한 한국어 분석
# </span>

# %% [markdown]
# <span style="color: red ; font-size: 14pt">
# 3.1. pos() 함수를 이용한 [(형태소, 품사)] 추출하기
# </span>

# %%
okt_pos=[]  #형태소와 품사 부분 저장을 위한 리스트

for data in data_tit_con : 
    #형태소와 품사 부분 리스트에 추가 
    #okt.pos()는 리스트 안에 (튜플)을 넣어서 리턴
    #okt_pos는 리스트이고,okt.pos() 결과도 리스트이므로 2차원리스트 생성 
    
    okt_pos.append(okt.pos(data))

# %%
#바깥쪽 리스트 안에 또 하나의 리스트가 포함되어 있으며
#내부 리스트 안에 튜플이 있는 구조

print(okt_pos)
# Out:
# [[('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('트', 'Noun'), ('링크', 'Noun'), ('AI', 'Alpha'), ('는', 'Verb'), ('지역', 'Noun'), ('관광', 'Noun'), ('솔루션', 'Noun'), ('입니다', 'Adjective'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('텍스트', 'Noun'), ('마', 'Noun'), ('이닝', 'Noun'), (',', 'Punctuation'), ('대화', 'Noun'), ('형', 'Suffix'), ('자연어', 'Noun'), ('처리', 'Noun'), ('기술', 'Noun'), ('로', 'Josa'), ('강화', 'Noun'), ('된', 'Verb'), ('인공', 'Noun'), ('지능', 'Noun'), ('이', 'Josa'), ('해답', 'Noun'), ('을', 'Josa'), ('제시', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('3', 'Number'), ('.', 'Punctuation'), ('모든', 'Noun'), ('담당자', 'Noun'), ('가', 'Josa'), ('쉽게', 'Verb'), ('인사이트', 'Noun'), ('를', 'Josa'), ('활용', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있도록', 'Adjective'), ('시각', 'Noun'), ('화', 'Suffix'), ('자료', 'Noun'), ('를', 'Josa'), ('제공', 'Noun'), ('합니다', 'Verb'), ('....', 'Punctuation')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('패스트', 'Noun'), ('캠퍼스', 'Noun'), ('챌', 'Verb'), ('린지', 'Noun'), ('10일', 'Number'), ('차', 'Foreign'), ('(', 'Punctuation'), ('수요일', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('ly', 'Alpha'), ('/', 'Punctuation'), ('3', 'Number'), ('FVdhDa', 'Alpha'), ('#패스트캠퍼스', 'Hashtag'), ('#패캠챌린지', 'Hashtag'), ('#직장인인강', 'Hashtag'), ('#직장인자기계발', 'Hashtag'), ('#패스트캠퍼스후기', 'Hashtag'), ('#김기현의딥러닝을활용한자연어처리입문올인원패키지Online', 'Hashtag')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('다급한', 'Adjective'), ('기업', 'Noun'), (',', 'Punctuation'), ('IT', 'Alpha'), ('인재', 'Noun'), ('직접', 'Noun'), ('키워', 'Verb'), ('…', 'Punctuation'), ('컴공', 'Noun'), ('·', 'Punctuation'), ('전산', 'Noun'), ('서울', 'Noun'), ('대졸', 'Noun'), ('자', 'Suffix'), ('추월', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('이', 'Noun'), ('프로그램', 'Noun'), ('은', 'Josa'), ('자연어', 'Noun'), ('처리', 'Noun'), ('기법', 'Noun'), ('을', 'Josa'), ('활용', 'Noun'), ('해', 'Verb'), ('법률', 'Noun'), ('문서', 'Noun'), ('의', 'Josa'), ('내용', 'Noun'), ('이', 'Josa'), ('잘', 'Verb'), ('요약', 'Noun'), ('된', 'Verb'), ('문장', 'Noun'), ('을', 'Josa'), ('...', 'Punctuation'), ('신경망', 'Noun'), ('처리장치', 'Noun'), ('(', 'Punctuation'), ('NPU', 'Alpha'), (')', 'Punctuation'), ('개발', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('해선', 'Noun'), ('컴퓨터공학', 'Noun'), ('을', 'Josa'), ('비롯', 'Noun'), ('한', 'Josa'), ('소프트웨어', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('...', 'Punctuation')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('2021년', 'Number'), ('11월', 'Number'), ('9일', 'Number'), ('상한', 'Noun'), ('가', 'Josa'), ('(', 'Punctuation'), ('갤럭시', 'Noun'), ('아', 'Josa'), ('에스', 'Noun'), ('엠', 'Noun'), (',', 'Punctuation'), ('셀', 'Noun'), ('바스', 'Noun'), ('AI', 'Alpha'), (',', 'Punctuation'), ('하이', 'Noun'), ('트론', 'Noun'), ('...', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('음성인식', 'Noun'), ('(', 'Punctuation'), ('STT', 'Alpha'), ('),', 'Punctuation'), ('음성합성', 'Noun'), ('(', 'Punctuation'), ('TTS', 'Alpha'), ('),', 'Punctuation'), ('자연어', 'Noun'), ('처리', 'Noun'), (',', 'Punctuation'), ('필기', 'Noun'), ('인식', 'Noun'), ('등', 'Noun'), ('의', 'Josa'), ('AI', 'Alpha'), ('솔루션', 'Noun'), ('을', 'Josa'), ('제공', 'Noun'), ('하고', 'Josa'), ('...', 'Punctuation'), ('이', 'Noun'), ('회사', 'Noun'), ('는', 'Josa'), ('건축', 'Noun'), ('용', 'Noun'), ('자재', 'Noun'), ('를', 'Josa'), ('제조', 'Noun'), ('하는', 'Verb'), ('데크', 'Noun'), ('플레이', 'Noun'), ('트', 'Noun'), ('부문', 'Noun'), (',', 'Punctuation'), ('조', 'Modifier'), ('선용', 'Noun'), ('철판', 'Noun'), ('을', 'Josa'), ('표면처리', 'Noun'), ('...', 'Punctuation')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('인공', 'Noun'), ('지능', 'Noun'), ('을', 'Josa'), ('넘어', 'Verb'), ('인공', 'Noun'), ('자아', 'Noun'), ('의', 'Josa'), ('시대', 'Noun'), ('로', 'Josa'), ('도약', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('일각', 'Noun'), ('에서는', 'Josa'), ('2032년', 'Number'), ('이면', 'Foreign'), ('GPT', 'Alpha'), ('-', 'Punctuation'), ('3', 'Number'), ('보다', 'Verb'), ( ...

# %%
import numpy as np
print('● 데이터 타입 : ', type(okt_pos)) 
print("● [(형태소, 품사), ...(형태소, 품사)] 리스트 개수 : ", len(okt_pos) )
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● [(형태소, 품사), ...(형태소, 품사)] 리스트 개수 :  100

# %%
okt_pos
# Out:
# [[('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('트', 'Noun'),
#   ('링크', 'Noun'),
#   ('AI', 'Alpha'),
#   ('는', 'Verb'),
#   ('지역', 'Noun'),
#   ('관광', 'Noun'),
#   ('솔루션', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('텍스트', 'Noun'),
#   ('마', 'Noun'),
#   ('이닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('대화', 'Noun'),
#   ('형', 'Suffix'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('기술', 'Noun'),
#   ('로', 'Josa'),
#   ('강화', 'Noun'),
#   ('된', 'Verb'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('이', 'Josa'),
#   ('해답', 'Noun'),
#   ('을', 'Josa'),
#   ('제시', 'Noun'),
#   ('합니다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('3', 'Number'),
#   ('.', 'Punctuation'),
#   ('모든', 'Noun'),
#   ('담당자', 'Noun'),
#   ('가', 'Josa'),
#   ('쉽게', 'Verb'),
#   ('인사이트', 'Noun'),
#   ('를', 'Josa'),
#   ('활용', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있도록', 'Adjective'),
#   ('시각', 'Noun'),
#   ('화', 'Suffix'),
#   ('자료', 'Noun'),
#   ('를', 'Josa'),
#   ('제공', 'Noun'),
#   ('합니다', 'Verb'),
#   ('....', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('패스트', 'Noun'),
#   ('캠퍼스', 'Noun'),
#   ('챌', 'Verb'),
#   ('린지', 'Noun'),
#   ('10일', 'Number'),
#   ('차', 'Foreign'),
#   ('(', 'Punctuation'),
#   ('수요일', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('ly', 'Alpha'),
#   ('/', 'Punctuation'),
#   ('3', 'Number'),
#   ('FVdhDa', 'Alpha'),
#   ('#패스트캠퍼스', 'Hashtag'),
#   ('#패캠챌린지', 'Hashtag'),
#   ('#직장인인강', 'Hashtag'),
#   ('#직장인자기계발', 'Hashtag'),
#   ('#패스트캠퍼스후기', 'Hashtag'),
#   ('#김기현의딥러닝을활용한자연어처리입문올인원패키지Online', 'Hashtag')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('다급한', 'Adjective'),
#   ('기업', 'Noun'),
#   (',', 'Punctuation'),
#   ('IT', 'Alpha'),
#   ('인재', 'Noun'),
#   ('직접', 'Noun'),
#   ('키워', 'Verb'),
#   ('…', 'Punctuation'),
#   ('컴공', 'Noun'),
#   ('·', 'Punctuation'),
#   ('전산', 'Noun'),
#   ('서울', 'Noun'),
#   ('대졸', 'Noun'),
#   ('자', 'Suffix'),
#   ('추월', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('이', 'Noun'),
#   ('프로그램', 'Noun'),
#   ('은', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('기법', 'Noun'),
#   ('을', 'Josa'),
#   ('활용', 'Noun'),
#   ('해', 'Verb'),
#   ('법률', 'Noun'),
#   ('문서', 'Noun'),
#   ('의', 'Josa'),
#   ('내용', 'Noun'),
#   ('이', 'Josa'),
#   ('잘', 'Verb'),
#   ('요약', 'Noun'),
#   ('된', 'Verb'),
#   ('문장', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation'),
#   ('신경망', 'Noun'),
#   ('처리장치', 'Noun'),
#   ('(', 'Punctuation'),
#   ('NPU', 'Alpha'),
#   (')', 'Punctuation'),
#   ('개발', 'Noun'),
#   ('을', 'Josa'),
#   ('위', 'Noun'),
#   ('해선', 'Noun'),
#   ('컴퓨터공학', 'Noun'),
#   ('을', 'Josa'),
#   ('비롯', 'Noun'),
#   ('한', 'Josa'),
#   ('소프트웨어', 'Noun'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('2021년', 'Number'),
#   ('11월', 'Number'),
#   ('9일', 'Number'),
#   ('상한', 'Noun'),
#   ('가', 'Josa'),
#   ('(', 'Punctuation'),
#   ('갤럭시', 'Noun'),
#   ('아', 'Josa'),
#   ('에스', 'Noun'),
#   ('엠', 'Noun'),
#   (',', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   (',', 'Punctuation'),
#   ('하이', 'Noun'),
#   ('트론', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('음성인식', 'Noun'),
#   ('(', 'Punctuation'),
#   ('STT', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('을', 'Josa'),
#   ('제공', 'Noun'),
#   ('하고', 'Josa'),
#   ('...', 'Punctuation'),
#   ('이', 'Noun'),
#   ('회사', 'Noun'),
#   ('는', 'Josa'),
#   ('건축', 'Noun'),
#   ('용', 'Noun'),
#   ('자재', 'Noun'),
#   ('를', 'Josa'),
#   ('제조', 'Noun'),
#   ('하는', 'Verb'),
#   ('데크', 'Noun'),
#   ('플레이', 'Noun'),
#   ('트', 'Noun'),
#   ('부문', 'Noun'),
#   (',', 'Punctuation'),
#   ('조', 'Modifier'),
#   ('선용', 'Noun'),
#   ('철판', 'Noun'),
#   ('을', 'Josa'),
#   ('표면처리', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('을', 'Josa'),
#   ('넘어', 'Verb'),
#   ('인공', 'Noun'),
#   ('자아', 'Noun'),
#   ('의', 'Josa'),
#   ('시대', 'Noun'),
#   ('로', 'Josa'),
#   ('도약', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('일각', 'Noun'),
#   ('에서는', 'Josa'),
#   ('2032년', 'Number'),
#   ('이면', 'Foreign'),
#   ('GPT', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('3', 'Number'),
#   ('보다', 'Verb'),
#   ('1000', 'Number'),
#   ('배', 'Noun'),
#   ('의', 'Josa'),
#   ('학습', 'Noun'),
#   ('처리', 'Noun'),
#   ('능력', 'Noun'),
#   ('을', 'Josa'),
#   ('가진', 'Verb'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('이', 'Josa'),
#   ('탄생', 'Noun'),
#   ('할', 'Verb'),
#   ('...', 'Punctuation'),
#   ('또한', 'Noun'),
#   (',', 'Punctuation'),
#   ('일반', 'Noun'),
#   ('상식', 'Noun'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('이미지', 'Noun'),
#   ('나', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('가', 'Josa'),
#   ('가능하도록', 'Adjective'),
#   (',', 'Punctuation'),
#   ('상식', 'Noun'),
#   ('을', 'Josa'),
#   ('객관', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('디지털', 'Noun'),
#   ('시대', 'Noun'),
#   ('의', 'Josa'),
#   ('전공', 'Noun'),
#   ('들', 'Suffix'),
#   (']', 'Punctuation'),
#   ('중앙', 'Noun'),
#   ('대학교', 'Noun'),
#   ('소프트웨어', 'Noun'),
#   ('학부', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('영', 'Modifier'),
#   ('상처리', 'Noun'),
#   ('4', 'Number'),
#   ('학년', 'Noun'),
#   ('캡', 'Noun'),
#   ('스톤', 'Noun'),
#   ('디자인', 'Noun'),
#   ('(', 'Punctuation'),
#   ('2', 'Number'),
#   ('),', 'Punctuation'),
#   ('멀티코어', 'Noun'),
#   ('컴퓨팅', 'Noun'),
#   (',', 'Punctuation'),
#   ('무선', 'Noun'),
#   ('이동통신', 'Noun'),
#   (',', 'Punctuation'),
#   ('네트워크', 'Noun'),
#   ('응용', 'Noun'),
#   ('설계', 'Noun'),
#   (',', 'Punctuation'),
#   ('정보보호', 'Noun'),
#   ('이론', 'Noun'),
#   (',', 'Punctuation'),
#   ('생체인식', 'Noun'),
#   ('및', 'Noun'),
#   ('응용', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('및', 'Noun'),
#   ('정보검색', 'Noun'),
#   (',', 'Punctuation'),
#   ('패턴인식', 'Noun'),
#   (',', 'Punctuation'),
#   ('컴퓨터', 'Noun'),
#   ('비전', 'Verb'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('우리', 'Noun'),
#   ('가', 'Josa'),
#   ('모르는', 'Verb'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('수', 'Modifier'),
#   ('혜주', 'Noun'),
#   (',', 'Punctuation'),
#   ('절대', 'Noun'),
#   ('적', 'Suffix'),
#   ('저', 'Determiner'),
#   ('평가', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('음성인식', 'Noun'),
#   ('(', 'Punctuation'),
#   ('STT', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('을', 'Josa'),
#   ('제', 'Noun'),
#   ('공', 'Noun'),
#   ('하고', 'Josa'),
#   ('있다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('의', 'Noun'),
#   ('음성', 'Noun'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('주목', 'Noun'),
#   ('해야', 'Verb'),
#   ('한다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('각', 'Noun'),
#   ('도메', 'Noun'),
#   ('인별', 'Noun'),
#   ('데이터', 'Noun'),
#   ('학습', 'Noun'),
#   ('을', 'Josa'),
#   ('통해', 'Noun'),
#   ('98', 'Number'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NVIDIA', 'Alpha'),
#   (',', 'Punctuation'),
#   ('신규', 'Noun'),
#   ('Jetson', 'Alpha'),
#   ('AGX', 'Alpha'),
#   ('Orin', 'Alpha'),
#   ('공개', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('향상', 'Noun'),
#   ('된', 'Verb'),
#   ('처리', 'Noun'),
#   ('능력', 'Noun'),
#   (',', 'Punctuation'),
#   ('이전', 'Noun'),
#   ('세대', 'Noun'),
#   ('인', 'Josa'),
#   ('Jetson', 'Alpha'),
#   ('AGX', 'Alpha'),
#   ('Xavier', 'Alpha'),
#   ('의', 'Noun'),
#   ('폼팩터', 'Noun'),
#   ('및', 'Noun'),
#   ('핀', 'Noun'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('...', 'Punctuation'),
#   ('이는', 'Verb'),
#   ('개발자', 'Noun'),
#   ('가', 'Josa'),
#   ('자연어', 'Noun'),
#   ('이해', 'Noun'),
#   (',', 'Punctuation'),
#   ('3', 'Number'),
#   ('D', 'Alpha'),
#   ('인식', 'Noun'),
#   (',', 'Punctuation'),
#   ('멀티', 'Noun'),
#   ('센서', 'Noun'),
#   ('퓨전', 'Noun'),
#   ('등', 'Noun'),
#   ('과', 'Josa'),
#   ('관련', 'Noun'),
#   ('된', 'Verb'),
#   ('엣지', 'Noun'),
#   ('(', 'Punctuation'),
#   ('edge', 'Alpha'),
#   (')...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('관련', 'Noun'),
#   ('주로', 'Noun'),
#   ('떠오르는', 'Verb'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('+', 'Punctuation'),
#   ('78%', 'Number'),
#   ('성공', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('영상', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('HCI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('경쟁력', 'Noun'),
#   ('을', 'Josa'),
#   ('강화하고', 'Adjective'),
#   ('있다고', 'Adjective'),
#   ('재벌', 'Noun'),
#   ('투자', 'Noun'),
#   ('연구소', 'Noun'),
#   ('전문가', 'Noun'),
#   ('분', 'Suffix'),
#   ('께서', 'Josa'),
#   ('알려주셨습니다', 'Verb'),
#   ('주식', 'Noun'),
#   ('후기', 'Noun'),
#   ('에서', 'Josa'),
#   ('가장', 'Noun'),
#   ('중요한', 'Adjective'),
#   ('수익', 'Noun'),
#   ('이야기', 'Noun'),
#   ('를', 'Josa'),
#   ('해볼까', 'Verb'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('GIP', 'Alpha'),
#   ('뉴스레터', 'Noun'),
#   ('_', 'Punctuation'),
#   ('11월', 'Number'),
#   ('2', 'Number'),
#   ('주', 'Noun'),
#   (']', 'Punctuation'),
#   ('넷플릭스', 'Noun'),
#   ('가', 'Josa'),
#   ('게임', 'Noun'),
#   ('만든다고', 'Verb'),
#   ('?', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('대표', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('신약', 'Noun'),
#   ('개발', 'Noun'),
#   (',', 'Punctuation'),
#   ('배터리', 'Noun'),
#   ('성능', 'Noun'),
#   ('개선', 'Noun'),
#   (',', 'Punctuation'),
#   ('날씨', 'Noun'),
#   ('예측', 'Noun'),
#   (',', 'Punctuation'),
#   ('주식', 'Noun'),
#   ('선별', 'Noun'),
#   (',', 'Punctuation'),
#   ('양자', 'Noun'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('이동', 'Noun'),
#   ('경로', 'Noun'),
#   ('최적화', 'Noun'),
#   (',', 'Punctuation'),
#   ('교통', 'Noun'),
#   ('관리', 'Noun'),
#   (',', 'Punctuation'),
#   ('데이터', 'Noun'),
#   ('보호', 'Noun'),
#   ('등', 'Noun'),
#   ('생활', 'Noun'),
#   ('과', 'Josa'),
#   ('밀접한', 'Adjective'),
#   ('기술', 'Noun'),
#   ('에', 'Josa'),
#   ('양자', 'Noun'),
#   ('컴퓨터', 'Noun'),
#   ('가', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('자바', 'Noun'),
#   ('공부', 'Noun'),
#   (']', 'Punctuation'),
#   ('자바', 'Noun'),
#   ('알고리즘', 'Noun'),
#   ('이란', 'Josa'),
#   ('무엇', 'Noun'),
#   ('인가', 'Josa'),
#   ('?', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('컴퓨터', 'Noun'),
#   ('는', 'Josa'),
#   ('정확하게', 'Adjective'),
#   ('무엇', 'Noun'),
#   ('을', 'Josa'),
#   ('해야', 'Verb'),
#   ('할지', 'Verb'),
#   ('처리', 'Noun'),
#   ('내용', 'Noun'),
#   ('과', 'Josa'),
#   ('처리', 'Noun'),
#   ('순서', 'Noun'),
#   ('를', 'Josa'),
#   ('모두', 'Noun'),
#   ('구체', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('...', 'Punctuation'),
#   ('알고리즘', 'Noun'),
#   ('은', 'Josa'),
#   ('자연어', 'Noun'),
#   (',', 'Punctuation'),
#   ('의사코드', 'Noun'),
#   (',', 'Punctuation'),
#   ('순서도', 'Noun'),
#   (',', 'Punctuation'),
#   ('프로그래밍', 'Noun'),
#   ('언어', 'Noun'),
#   ('등', 'Noun'),
#   ('으로', 'Josa'),
#   ('표현', 'Noun'),
#   ('이', 'Josa'),
#   ('가능합니다', 'Adjective'),
#   ('....', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('파이썬', 'Noun'),
#   ('의', 'Josa'),
#   ('강력함을', 'Adjective'),
#   ('느낄', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('「', 'Foreign'),
#   ('한', 'Verb'),
#   ('권', 'Noun'),
#   ('으로', 'Josa'),
#   ('다지는', 'Verb'),
#   ('머신', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('▶', 'Foreign'),
#   ('심층', 'Noun'),
#   ('신경망', 'Noun'),
#   ('(', 'Punctuation'),
#   ('DNN', 'Alpha'),
#   (')', 'Punctuation'),
#   ('처리', 'Noun'),
#   ('▶', 'Foreign'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('▶', 'Foreign'),
#   ('편미분', 'Noun'),
#   ('방정식', 'Noun'),
#   ('▶', 'Foreign'),
#   ('추상화', 'Noun'),
#   ('▶', 'Foreign'),
#   ('이미지', 'Noun'),
#   ('...', 'Punctuation'),
#   ('주요', 'Noun'),
#   ('역할', 'Noun'),
#   (':', 'Punctuation'),
#   ('데이터', 'Noun'),
#   ('조작', 'Noun'),
#   ('및', 'Noun'),
#   ('분석', 'Noun'),
#   ('NLTK', 'Alpha'),
#   ('NLTK', 'Alpha'),
#   ('는', 'Verb'),
#   ('Natural', 'Alpha'),
#   ('Language', 'Alpha'),
#   ('Toolkit', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('툴킷', 'Noun'),
#   (')', 'Punctuation'),
#   ('의', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('11/10', 'Number'),
#   ('주린이의', 'Verb'),
#   ('받아', 'Verb'),
#   ('쓰는', 'Verb'),
#   ('시', 'Modifier'),
#   ('황정리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('삼', 'Modifier'),
#   ('프로', 'Noun'),
#   ('tv', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('AI', 'Alpha'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('기술', 'Noun'),
#   ('-', 'Punctuation'),
#   ('로보틱스', 'Noun'),
#   (',', 'Punctuation'),
#   ('헬', 'Noun'),
#   ('스케', 'Noun'),
#   ('어', 'Suffix'),
#   (',', 'Punctuation'),
#   ('자율', 'Noun'),
#   ('주행', 'Noun'),
#   ('관련', 'Noun'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('-', 'Punctuation'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('를', 'Josa'),
#   ('위', 'Noun'),
#   ('한', 'Josa'),
#   ('새로운', 'Adjective'),
#   ('애플리케이션', 'Noun'),
#   ('-', 'Punctuation'),
#   ('공장', 'Noun'),
#   ('도시', 'Noun'),
#   ('및', 'Noun'),
#   ('지역', 'Noun'),
#   ('디지털', 'Noun'),
#   ('트윈', 'Noun'),
#   ('구축', 'Noun'),
#   ('=>', 'Punctuation'),
#   ('딥', 'Noun'),
#   ('러닝', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('월', 'Noun'),
#   ('230', 'Number'),
#   ('/', 'Punctuation'),
#   ('수원', 'Noun'),
#   (']', 'Punctuation'),
#   ('삼성', 'Noun'),
#   ('전기', 'Noun'),
#   ('AI', 'Alpha'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('챗봇', 'Noun'),
#   ('트레이너', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('20년', 'Number'),
#   ('간', 'Foreign'),
#   ('자체', 'Noun'),
#   ('개발', 'Noun'),
#   ('한', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('기술', 'Noun'),
#   ('과', 'Josa'),
#   ('머신', 'Noun'),
#   ('러닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('텍스트', 'Noun'),
#   ('마', 'Noun'),
#   ('이닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('의미', 'Noun'),
#   ('분석', 'Noun'),
#   ('및', 'Noun'),
#   ('검색', 'Noun'),
#   ('등', 'Noun'),
#   ('이', 'Josa'),
#   ('복합', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('융합', 'Noun'),
#   ('된', 'Verb'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('기반', 'Noun'),
#   ('하이브리드', 'Noun'),
#   ('챗봇', 'Noun'),
#   ('솔루션', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('....', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('영상', 'Noun'),
#   (']', 'Punctuation'),
#   ('전상호', 'Noun'),
#   ('코어', 'Noun'),
#   ('에이', 'Noun'),
#   ('아이', 'Noun'),
#   ('(', 'Punctuation'),
#   ('kore', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('ai', 'Alpha'),
#   (',)', 'Punctuation'),
#   ('상무', 'Noun'),
#   (',', 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('대화', 'Noun'),
#   ('형', 'Suffix'),
#   ('AI', 'Alpha'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('kr', 'Alpha'),
#   (')', 'Punctuation'),
#   ('#데모', 'Hashtag'),
#   ('#코어에이아이', 'Hashtag'),
#   ('#원격지원', 'Hashtag'),
#   ('#챗봇', 'Hashtag'),
#   ('#IVR', 'Hashtag'),
#   ('#컨택센터', 'Hashtag'),
#   ('#자연어처리', 'Hashtag'),
#   ('...', 'Punctuation'),
#   ('인지', 'Noun'),
#   ('검색', 'Noun'),
#   ('#자연언어처리', 'Hashtag'),
#   ('#챗봇고도화', 'Hashtag'),
#   ('#챗봇플랫폼', 'Hashtag'),
#   ('#가상직원', 'Hashtag'),
#   ('#디지털직원', 'Hashtag'),
#   ('#AI직원', 'Hashtag'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('빅', 'Noun'),
#   ('데이터', 'Noun'),
#   ('란', 'Noun'),
#   ('?', 'Punctuation'),
#   ('특징', 'Noun'),
#   ('과', 'Josa'),
#   ('의미', 'Noun'),
#   ('를', 'Josa'),
#   ('알아봅니다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('학습', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('패턴', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('이', 'Josa'),
#   ('분석', 'Noun'),
#   ('기법', 'Noun'),
#   ('에', 'Josa'),
#   ('해당', 'Noun'),
#   ('한', 'Josa'),
#   ('다', 'Adverb'),
#   ('.', 'Punctuation'),
#   ('복잡', 'Noun'),
#   ('성', 'Suffix'),
#   ('(', 'Punctuation'),
#   ('Complexity', 'Alpha'),
#   (')', 'Punctuation'),
#   ('데이터', 'Noun'),
#   ('의', 'Josa'),
#   ('구조', 'Noun'),
#   ('나', 'Josa'),
#   ('데이터', 'Noun'),
#   ('의', 'Josa'),
#   ('획득', 'Noun'),
#   ('과', 'Josa'),
#   ('처리', 'Noun'),
#   ('에', 'Josa'),
#   ('드는', 'Verb'),
#   ('속도', 'Noun'),
#   (',', 'Punctuation'),
#   ('도메인', 'Noun'),
#   ('규칙', 'Noun'),
#   ('이나', 'Josa'),
#   (',', 'Punctuation'),
#   ('저장', 'Noun'),
#   ('타입', 'Noun'),
#   ('등', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('개발', 'Noun'),
#   ('2', 'Number'),
#   ('유닛', 'Noun'),
#   (']', 'Punctuation'),
#   ('무하', 'Noun'),
#   ('유의', 'Noun'),
#   ('서비스', 'Noun'),
#   ('를', 'Josa'),
#   ('만들어가는', 'Verb'),
#   ('“', 'Foreign'),
#   ('서비스', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('민', 'Noun'),
#   ('프로', 'Noun'),
#   ('저', 'Noun'),
#   ('는', 'Josa'),
#   ('‘', 'Foreign'),
#   ('자연어', 'Noun'),
#   ('를', 'Josa'),
#   ('이해', 'Noun'),
#   ('하는', 'Verb'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('기업', 'Noun'),
#   (',', 'Punctuation'),
#   ('무하', 'Noun'),
#   ('유', 'Noun'),
#   ('’', 'Punctuation'),
#   ('라는', 'Josa'),
#   ('회사', 'Noun'),
#   ('슬로건', 'Noun'),
#   ('을', 'Josa'),
#   ('보고', 'Noun'),
#   ('...', 'Punctuation'),
#   ('서비스', 'Noun'),
#   ('에', 'Josa'),
#   ('문장', 'Noun'),
#   ('처리', 'Noun'),
#   ('기술', 'Noun'),
#   ('과', 'Josa'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('적용', 'Noun'),
#   ('시키는', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('경험', 'Noun'),
#   ('을', 'Josa'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있고요', 'Adjective'),
#   ('....', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('에', 'Josa'),
#   ('임', 'Noun'),
#   ('리치', 'Noun'),
#   (']', 'Punctuation'),
#   ('비트코인', 'Noun'),
#   ('시', 'Modifier'),
#   ('총', 'Noun'),
#   ('3조', 'Number'),
#   ('달러', 'Noun'),
#   ('근접', 'Noun'),
#   ('…', 'Punctuation'),
#   ('‘', 'Foreign'),
#   ('ETH', 'Alpha'),
#   ('’', 'Punctuation'),
#   ('급등', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('예산', 'Noun'),
#   ('법안', 'Noun'),
#   ('을', 'Josa'),
#   ('처리', 'Noun'),
#   ('한', 'Josa'),
#   ('것', 'Noun'),
#   ('이', 'Josa'),
#   ('증시', 'Noun'),
#   ('에', 'Josa'),
#   ('호재', 'Noun'),
#   ('로', 'Josa'),
#   ('작용', 'Noun'),
#   ('하면서', 'Verb'),
#   ('소', 'Modifier'),
#   ('폭', 'Noun'),
#   ('상승', 'Noun'),
#   ('마감', 'Noun'),
#   ('했다', 'Verb'),
#   ('....', 'Punctuation'),
#   ('추출', 'Noun'),
#   ('하여', 'Verb'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('방식', 'Noun'),
#   ('으로', 'Josa'),
#   ('실시', 'Noun'),
#   ('한', 'Josa'),
#   ("'", 'Punctuation'),
#   ('비트코인', 'Noun'),
#   ("'(", 'Punctuation'),
#   ('bitcoin', 'Alpha'),
#   (')', 'Punctuation'),
#   ('라는', 'Josa'),
#   ('단어', 'Noun'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('11월', 'Number'),
#   ('10일', 'Number'),
#   ('삼', 'Modifier'),
#   ('프로', 'Noun'),
#   ('티비', 'Noun'),
#   ('-', 'Punctuation'),
#   ('월', 'Noun'),
#   ('가', 'Josa'),
#   ('모닝', 'Noun'),
#   ('라이브', 'Noun'),
#   (',', 'Punctuation'),
#   ('오늘아침', 'Noun'),
#   ('라이브', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('대화', 'Noun'),
#   ('형', 'Suffix'),
#   ('AI', 'Alpha'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('기술', 'Noun'),
#   (',', 'Punctuation'),
#   ('로보틱스', 'Noun'),
#   (',', 'Punctuation'),
#   ('헬', 'Noun'),
#   ('스케', 'Noun'),
#   ('어', 'Suffix'),
#   (',', 'Punctuation'),
#   ('자율', 'Noun'),
#   ('주행', 'Noun'),
#   ('관련', 'Noun'),
#   ('기술', 'Noun'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('를', 'Josa'),
#   ('위', 'Noun'),
#   ('한', 'Josa'),
#   ('새로운', 'Adjective'),
#   ('어플리케이션', 'Noun'),
#   ('공장', 'Noun'),
#   ('도시', 'Noun'),
#   ('및', 'Noun'),
#   ('지역', 'Noun'),
#   ('디지털', 'Noun'),
#   ('트윈', 'Noun'),
#   ('구축', 'Noun'),
#   ('-', 'Punctuation'),
#   ('딥', 'Noun'),
#   ('러닝', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('"', 'Punctuation'),
#   ('공식', 'Noun'),
#   ('의', 'Josa'),
#   ('아름다', 'Adjective'),
#   ('움', 'Noun'),
#   ('"', 'Punctuation'),
#   ('원자폭탄', 'Noun'),
#   ('에서', 'Josa'),
#   ('비트코인', 'Noun'),
#   ('까지', 'Josa'),
#   ('세상', 'Noun'),
#   ('을', 'Josa'),
#   ('바꾼', 'Verb'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('"', 'Punctuation'),
#   ('공식', 'Noun'),
#   ('의', 'Josa'),
#   ('아름다', 'Adjective'),
#   ('움', 'Noun'),
#   ('"', 'Punctuation'),
#   ('원자폭탄', 'Noun'),
#   ('에서', 'Josa'),
#   ('비트코인', 'Noun'),
#   ('까지', 'Josa'),
#   ('세상', 'Noun'),
#   ('을', 'Josa'),
#   ('바꾼', 'Verb'),
#   ('절대', 'Noun'),
#   ('공식', 'Noun'),
#   ('저자', 'Noun'),
#   (':', 'Punctuation'),
#   ('양자', 'Noun'),
#   ('학파', 'Noun'),
#   ('출판', 'Noun'),
#   (':', 'Punctuation'),
#   ('미디어', 'Noun'),
#   ('숲', 'Noun'),
#   ('발매', 'Noun'),
#   (':', 'Punctuation'),
#   ('2021', 'Number'),
#   ('.', 'Punctuation'),
#   ('11', 'Number'),
#   ('.', 'Punctuation'),
#   ('10', 'Number'),
#   ('저자', 'Noun'),
#   (':', 'Punctuation'),
#   ('양자', 'Noun'),
#   ('학파', 'Noun'),
#   ('양자', 'Noun'),
#   ('학파', 'Noun'),
#   ('는', 'Josa'),
#   ('자연', 'Noun'),
#   ('과학', 'Noun'),
#   ('(', 'Punctuation'),
#   ('수학', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Meta', 'Alpha'),
#   ('의', 'Noun'),
#   ('AI', 'Alpha'),
#   ('전략', 'Noun'),
#   ('(', 'Punctuation'),
#   ('AI', 'Alpha'),
#   ('시리즈', 'Noun'),
#   ('1', 'Number'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Natural', 'Alpha'),
#   ('Language', 'Alpha'),
#   ('Processing', 'Alpha'),
#   ('Natural', 'Alpha'),
#   ('Language', 'Alpha'),
#   (',', 'Punctuation'),
#   ('즉', 'Noun'),
#   ('인간', 'Noun'),
#   ('이', 'Josa'),
#   ('사용', 'Noun'),
#   ('하는', 'Verb'),
#   ('자연어', 'Noun'),
#   ('를', 'Josa'),
#   ('처리', 'Noun'),
#   ('하는', 'Verb'),
#   ('기술', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('언어', 'Noun'),
#   ('장벽', 'Noun'),
#   ('을', 'Josa'),
#   ('허물', 'Noun'),
#   ('고', 'Josa'),
#   ('어떤', 'Adjective'),
#   ('언어', 'Noun'),
#   ('를', 'Josa'),
#   ('사용', 'Noun'),
#   ('하든', 'Verb'),
#   ('누구', 'Noun'),
#   ('와', 'Josa'),
#   ('대화', 'Noun'),
#   ('하든', 'Verb'),
#   ('쉽게', 'Verb'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('21', 'Number'),
#   (',', 'Punctuation'),
#   ('11', 'Number'),
#   (',', 'Punctuation'),
#   ('10', 'Number'),
#   ('검색', 'Noun'),
#   ('조회', 'Noun'),
#   ('수가', 'Noun'),
#   ('장', 'Suffix'),
#   ('많은', 'Adjective'),
#   ('단어', 'Noun'),
#   ('키', 'Noun'),
#   ('워드', 'Noun'),
#   ('상위', 'Noun'),
#   ('노출', 'Noun'),
#   ('유입', 'Noun'),
#   ('분석', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('16%', 'Number'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('국어', 'Noun'),
#   ('0.16%', 'Number'),
#   ('전자', 'Noun'),
#   ('순찰', 'Noun'),
#   ('tcr', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('200', 'Number'),
#   ('0.16%', 'Number'),
#   ('토카막', 'Noun'),
#   ('네트워크', 'Noun'),
#   ('0.16%', 'Number'),
#   ('폐기물', 'Noun'),
#   ('이', 'Josa'),
#   ('에너지', 'Noun'),
#   ('로', 'Josa'),
#   ('변환', 'Noun'),
#   ('미분방정식', 'Noun'),
#   ('0.16%', 'Number'),
#   ('홍합', 'Noun'),
#   ('접착', 'Noun'),
#   ('단백질', 'Noun'),
#   ('0.16', 'Number'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('멀티', 'Noun'),
#   ('캠퍼스', 'Noun'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('NLP', 'Alpha'),
#   (')', 'Punctuation'),
#   ('기반', 'Noun'),
#   ('기업', 'Noun'),
#   ('데이터', 'Noun'),
#   ('분석', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('단순히', 'Adjective'),
#   ("'", 'Punctuation'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ("'", 'Punctuation'),
#   ('라는', 'Josa'),
#   ('키', 'Noun'),
#   ('워드', 'Noun'),
#   ('만', 'Josa'),
#   ('보고', 'Noun'),
#   ('바로', 'Noun'),
#   ('지원', 'Noun'),
#   ('했고', 'Verb'),
#   (',', 'Punctuation'),
#   ('NLP', 'Alpha'),
#   ('가', 'Verb'),
#   ('무엇', 'Noun'),
#   ('인지도', 'Noun'),
#   ('모르는', 'Verb'),
#   ('상태', 'Noun'),
#   ('였다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('개념', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('내용', 'Noun'),
#   ('은', 'Josa'),
#   ('블로그', 'Noun'),
#   (',', 'Punctuation'),
#   ('유튜브', 'Noun'),
#   ('를', 'Josa'),
#   ('통해', 'Noun'),
#   ('공부', 'Noun'),
#   ('하고', 'Josa'),
#   ('있었지만', 'Adjective'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('211109', 'Number'),
#   (')', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('우리', 'Noun'),
#   ('가', 'Josa'),
#   ('모르는', 'Verb'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('수', 'Modifier'),
#   ('혜주', 'Noun'),
#   (',', 'Punctuation'),
#   ('절대', 'Noun'),
#   ('적', 'Suffix'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('제공', 'Noun'),
#   ('└', 'Foreign'),
#   ('국내', 'Noun'),
#   ('최고', 'Noun'),
#   ('음성인식', 'Noun'),
#   ('률', 'Noun'),
#   ('보유', 'Noun'),
#   (',', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('기술', 'Noun'),
#   ('M', 'Alpha'),
#   ('/', 'Punctuation'),
#   ('S', 'Alpha'),
#   ('60%', 'Number'),
#   ('로', 'Noun'),
#   ('국내', 'Noun'),
#   ('1', 'Number'),
#   ('위', 'Noun'),
#   ('└', 'Foreign'),
#   ('쌍', 'Noun'),
#   ('방향', 'Noun'),
#   ('커뮤니케이션', 'Noun'),
#   ('핵심', 'Noun'),
#   ('기술', 'Noun'),
#   ('인', 'Josa'),
#   ('음성', 'Noun'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('주가', 'Noun'),
#   ('전망', 'Noun'),
#   (':', 'Punctuation'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   (',', 'Punctuation'),
#   ('음성인식', 'Noun'),
#   ('관련', 'Noun'),
#   ('주', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('영상', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('HCI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('경쟁력', 'Noun'),
#   ('을', 'Josa'),
#   ('가오', 'Noun'),
#   ('하', 'Suffix'),
#   ('하고', 'Josa'),
#   ('있음', 'Adjective'),
#   ('-', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('...', 'Punctuation'),
#   ('마우스', 'Noun'),
#   (',', 'Punctuation'),
#   ('키', 'Noun'),
#   ('보드', 'Noun'),
#   ('등', 'Noun'),
#   ('전통', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('컴퓨터', 'Noun'),
#   ('입력장치', 'Noun'),
#   ('가', 'Josa'),
#   ('음성인식', 'Noun'),
#   (',', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   (',', 'Punctuation'),
#   ('자', 'Noun'),
#   ('여어', 'Verb'),
#   ('처리', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('2021/11', 'Number'),
#   ('/', 'Punctuation'),
#   ('09', 'Number'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('흘러', 'Verb'),
#   ('흘러', 'Verb'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('딥', 'Noun'),
#   ('러닝', 'Noun'),
#   ('을', 'Josa'),
#   ('하는', 'Verb'),
#   ('중이', 'Noun'),
#   ('다', 'Josa'),
#   ('.', 'Punctuation'),
#   ('문제', 'Noun'),
#   ('는', 'Josa'),
#   ('단기간', 'Noun'),
#   ('에', 'Josa'),
#   ('계속', 'Noun'),
#   ('효율', 'Noun'),
#   ('이', 'Josa'),
#   ('안', 'VerbPrefix'),
#   ('나와서', 'Verb'),
#   ('열심히', 'Adverb'),
#   ('자신', 'Noun'),
#   ('과의', 'Josa'),
#   ('싸움', 'Noun'),
#   ('중', 'Suffix'),
#   ('나무', 'Noun'),
#   ('만', 'Josa'),
#   ('보고', 'Noun'),
#   ('숲', 'Noun'),
#   ('은', 'Josa'),
#   ('못', 'VerbPrefix'),
#   ('본다는게', 'Verb'),
#   ('이런', 'Adjective'),
#   ('경우', 'Noun'),
#   ('인거', 'Josa'),
#   ('같다', 'Adjective'),
#   ('내년', 'Noun'),
#   ('쯤', 'Suffix'),
#   ('이', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('마이크로소프트', 'Noun'),
#   ('(', 'Punctuation'),
#   ('MSFT', 'Alpha'),
#   (')', 'Punctuation'),
#   ('도', 'Noun'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('에', 'Josa'),
#   ('합류', 'Noun'),
#   ('!', 'Punctuation'),
#   ('그', 'Noun'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('완벽', 'Noun'),
#   ('분석', 'Noun'),
#   ('!', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('☆', 'Foreign'),
#   ('Azure', 'Alpha'),
#   ('Open', 'Alpha'),
#   ('AI', 'Alpha'),
#   ('Service', 'Alpha'),
#   ('현', 'Modifier'),
#   ('존', 'Noun'),
#   ('최대', 'Noun'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('프로그램', 'Noun'),
#   ('인', 'Josa'),
#   ('GPT', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('3', 'Number'),
#   ('API', 'Alpha'),
#   ('를', 'Noun'),
#   ('클라우드', 'Noun'),
#   ('기반', 'Noun'),
#   ('으로', 'Josa'),
#   ('제공', 'Noun'),
#   ('합니다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('즉', 'Noun'),
#   (',', 'Punctuation'),
#   ('애저', 'Noun'),
#   ('를', 'Josa'),
#   ('사용', 'Noun'),
#   ('하면', 'Verb'),
#   ('고객', 'Noun'),
#   ('서비스', 'Noun'),
#   ('로그', 'Noun'),
#   ('상의', 'Noun'),
#   ('공통', 'Noun'),
#   ('된', 'Verb'),
#   ('불만', 'Noun'),
#   ('사항', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('주가', 'Noun'),
#   ('숨겨진', 'Verb'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('수', 'Modifier'),
#   ('혜주', 'Noun'),
#   ('기', 'Modifier'),
#   ('대감', 'Noun'),
#   ('에', 'Josa'),
#   ('상한', 'Noun'),
#   ('가', 'Josa'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('을', 'Josa'),
#   ('제공', 'Noun'),
#   ('중', 'Suffix'),
#   ('인데', 'Josa'),
#   ('특히', 'Adverb'),
#   ('음성', 'Noun'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('주목', 'Noun'),
#   ('해야', 'Verb'),
#   ('한다고', 'Verb'),
#   ('합니다', 'Verb'),
#   ('각', 'Noun'),
#   ('도메인', 'Noun'),
#   ('별', 'Noun'),
#   ('데이터', 'Noun'),
#   ('학습', 'Noun'),
#   ('을', 'Josa'),
#   ('통해', 'Noun'),
#   ('98%', 'Number'),
#   ('이상', 'Noun'),
#   ('의', 'Josa'),
#   ('국내', 'Noun'),
#   ('최고', 'Noun'),
#   ('음성', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('AI', 'Alpha'),
#   ('최강', 'Noun'),
#   ('의', 'Josa'),
#   ('수업', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('전', 'Modifier'),
#   ('처리', 'Noun'),
#   ('방법', 'Noun'),
#   ('이라고', 'Josa'),
#   ('볼', 'Noun'),
#   ('수', 'Noun'),
#   ('있다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('차원', 'Noun'),
#   ('감소', 'Noun'),
#   ('를', 'Josa'),
#   ('위', 'Noun'),
#   ('해서는', 'Verb'),
#   ('주성분', 'Noun'),
#   ('분석', 'Noun'),
#   ('...', 'Punctuation'),
#   ('-', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('는', 'Josa'),
#   ('애매하다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('상황', 'Noun'),
#   ('에', 'Josa'),
#   ('따라', 'Verb'),
#   ('단어', 'Noun'),
#   ('의', 'Josa'),
#   ('역할', 'Noun'),
#   (',', 'Punctuation'),
#   ('의미', 'Noun'),
#   ('가', 'Josa'),
#   ('달라진다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('의미', 'Noun'),
#   ('만', 'Josa'),
#   ('전달', 'Noun'),
#   ('하는', 'Verb'),
#   ('것', 'Noun'),
#   ('이', 'Josa'),
#   ('아니라', 'Adjective'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('경북', 'Noun'),
#   ('대학교', 'Noun'),
#   ('데이터', 'Noun'),
#   ('융합', 'Noun'),
#   ('연구원', 'Noun'),
#   (']', 'Punctuation'),
#   ('2021년', 'Number'),
#   ('고용노동부', 'Noun'),
#   ('K', 'Alpha'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('데이터', 'Noun'),
#   ('처리', 'Noun'),
#   ('라이브러리', 'Noun'),
#   ('Pandas', 'Alpha'),
#   ('▶', 'Foreign'),
#   ('데이터', 'Noun'),
#   ('크롤', 'Noun'),
#   ('링', 'Noun'),
#   ('정제', 'Noun'),
#   ('등', 'Noun'),
#   ('총', 'Noun'),
#   ('256시간', 'Number'),
#   ('진행', 'Noun'),
#   ('된다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('심화', 'Noun'),
#   ('과정', 'Noun'),
#   ('은', 'Josa'),
#   ('47일', 'Number'),
#   ('동안', 'Noun'),
#   ('▶', 'Foreign'),
#   ('빅데이터', 'Noun'),
#   ('통계', 'Noun'),
#   ('기본', 'Noun'),
#   ('▶', 'Foreign'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('▶', 'Foreign'),
#   ('데이터', 'Noun'),
#   ('분석', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('21년', 'Number'),
#   ('11월', 'Number'),
#   ('9일', 'Number'),
#   ('화', 'Noun'),
#   ('주식', 'Noun'),
#   ('시', 'Modifier'),
#   ('황', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('#코스피', 'Hashtag'),
#   ('#', 'Punctuation'),
#   ('코스닥', 'Noun'),
#   ('#', 'Punctuation'),
#   ('상한', 'Noun'),
#   ('가', 'Josa'),
#   ('21년', 'Number'),
#   ('11월', 'Number'),
#   ('9일', 'Number'),
#   ('화요일', 'Noun'),
#   ('주식', 'Noun'),
#   ('시', 'Modifier'),
#   ('황', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('양대', 'Modifier'),
#   ('지수', 'Noun'),
#   ('모두', 'Noun'),
#   ('소', 'Modifier'),
#   ('폭', 'Noun'),
#   ('상승', 'Noun'),
#   ('하면서', 'Verb'),
#   ('강', 'Noun'),
#   ('보합', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('코스피', 'Noun'),
#   ('는', 'Josa'),
#   ('여전히', 'Adjective'),
#   ('하락', 'Noun'),
#   ('하는', 'Verb'),
#   ('중이', 'Noun'),
#   ('고', 'Josa'),
#   ('코스닥', 'Noun'),
#   ('은', 'Josa'),
#   ('옆', 'Noun'),
#   ('으로', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('아진산업', 'Noun'),
#   (',', 'Punctuation'),
#   ('하이', 'Noun'),
#   ('트론', 'Noun'),
#   (',', 'Punctuation'),
#   ('제', 'Modifier'),
#   ('일', 'Modifier'),
#   ('테크', 'Noun'),
#   ('노스', 'Noun'),
#   (',', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('표면처리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Shot', 'Alpha'),
#   ('Blast', 'Alpha'),
#   (')', 'Punctuation'),
#   ('및', 'Noun'),
#   ('절단', 'Noun'),
#   ('가공', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Steel', 'Alpha'),
#   ('Cutting', 'Alpha'),
#   (')', 'Punctuation'),
#   ('하는', 'Verb'),
#   ('조선', 'Noun'),
#   ('부문', 'Noun'),
#   ('으로', 'Josa'),
#   ('사업', 'Noun'),
#   ('을', 'Josa'),
#   ('영위', 'Noun'),
#   ('하고', 'Josa'),
#   ('...', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('을', 'Josa'),
#   ('제공', 'Noun'),
#   ('중', 'Suffix'),
#   ('인데', 'Josa'),
#   ('특히', 'Adverb'),
#   ('음성', 'Noun'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('프로그래밍', 'Noun'),
#   ('언어', 'Noun'),
#   ('의', 'Josa'),
#   ('간추린', 'Noun'),
#   ('역사', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('상당', 'Noun'),
#   ('부분', 'Noun'),
#   ('자연어', 'Noun'),
#   ('에', 'Josa'),
#   ('의존', 'Noun'),
#   ('하며', 'Verb'),
#   (',', 'Punctuation'),
#   ('포트란', 'Noun'),
#   ('에', 'Josa'),
#   ('비해', 'Verb'),
#   ('많은', 'Adjective'),
#   ('양', 'Noun'),
#   ('의', 'Josa'),
#   ('데이터', 'Noun'),
#   ('를', 'Josa'),
#   ('처리', 'Noun'),
#   ('하도록', 'Verb'),
#   ('설계', 'Noun'),
#   ('됐다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('코볼', 'Noun'),
#   ('은', 'Josa'),
#   ('처음', 'Noun'),
#   ('등장', 'Noun'),
#   ('한', 'Josa'),
#   ('후', 'Noun'),
#   ('가장', 'Noun'),
#   ('널리', 'Noun'),
#   ('사용', 'Noun'),
#   ('되는', 'Verb'),
#   ('프로그램', 'Noun'),
#   ('언어', 'Noun'),
#   ('중', 'Noun'),
#   ('하나로', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('Kore', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('ai', 'Alpha'),
#   ('XO', 'Alpha'),
#   ('Platform', 'Alpha'),
#   ('Release', 'Alpha'),
#   ('v', 'Alpha'),
#   ('9.1', 'Number'),
#   (']', 'Punctuation'),
#   ('100', 'Number'),
#   ('개', 'Noun'),
#   ('이상', 'Noun'),
#   ('언어', 'Noun'),
#   ('로', 'Josa'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('컨택', 'Noun'),
#   ('센터', 'Noun'),
#   ('#자연어처리', 'Hashtag'),
#   ('#챗봇솔루션', 'Hashtag'),
#   ('#자동응답서비스', 'Hashtag'),
#   ('#AI비서', 'Hashtag'),
#   ('#KOREAI', 'Hashtag'),
#   ('#코어AI', 'Hashtag'),
#   ('...', 'Punctuation'),
#   ('인지', 'Noun'),
#   ('검색', 'Noun'),
#   ('#자연언어처리', 'Hashtag'),
#   ('#챗봇고도화', 'Hashtag'),
#   ('#챗봇플랫폼', 'Hashtag'),
#   ('#가상직원', 'Hashtag'),
#   ('#디지털직원', 'Hashtag'),
#   ('#AI직원', 'Hashtag'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('상한', 'Noun'),
#   ('가', 'Josa'),
#   ('(', 'Punctuation'),
#   ('11월', 'Number'),
#   ('9일', 'Number'),
#   ('),', 'Punctuation'),
#   ('갤럭시', 'Noun'),
#   ('아', 'Josa'),
#   ('에스', 'Noun'),
#   ('이엠', 'Noun'),
#   ('/', 'Punctuation'),
#   ('하이', 'Noun'),
#   ('트론', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('는', 'Verb'),
#   ('음성인식', 'Noun'),
#   ('(', 'Punctuation'),
#   ('STT', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation'),
#   ('표면처리', 'Noun'),
#   ('·', 'Punctuation'),
#   ('절단', 'Noun'),
#   ('가공', 'Noun'),
#   ('하', 'Suffix'),
#   ('는', 'Josa'),
#   ('조선', 'Noun'),
#   ('부문', 'Noun'),
#   ('등', 'Noun'),
#   ('을', 'Josa'),
#   ('영위', 'Noun'),
#   ('하고', 'Josa'),
#   ('있습니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('이', 'Noun'),
#   ('회사', 'Noun'),
#   ('의', 'Josa'),
#   ('박정식', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('2021', 'Number'),
#   ('금융', 'Noun'),
#   ('산업', 'Noun'),
#   ('전문', 'Noun'),
#   ('인력', 'Noun'),
#   ('AI', 'Alpha'),
#   ('역량', 'Noun'),
#   ('강화', 'Noun'),
#   (']', 'Punctuation'),
#   ('#온라인으로_배우는', 'Hashtag'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('OCR', 'Alpha'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('딥', 'Noun'),
#   ('러닝', 'Noun'),
#   ('을', 'Josa'),
#   ('통해', 'Noun'),
#   ('해결', 'Noun'),
#   ('한', 'Josa'),
#   ('문제', 'Noun'),
#   ('소개', 'Noun'),
#   ('코스', 'Noun'),
#   ('2', 'Number'),
#   ('소개', 'Noun'),
#   ('페이지', 'Noun'),
#   ('♂', 'Foreign'),
#   ('?', 'Punctuation'),
#   ('수강', 'Noun'),
#   ('하러', 'Verb'),
#   ('가기', 'Noun'),
#   ('♀', 'Foreign'),
#   ('?', 'Punctuation'),
#   ('코스', 'Noun'),
#   ('3', 'Number'),
#   ('.', 'Punctuation'),
#   ('간편', 'Noun'),
#   ('결제', 'Noun'),
#   ('및', 'Noun'),
#   ('자산', 'Noun'),
#   ('관리', 'Noun'),
#   ('사례', 'Noun'),
#   ('?', 'Punctuation'),
#   ('디지털', 'Noun'),
#   ('전환', 'Noun'),
#   ('을', 'Josa'),
#   ('통한', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('가상', 'Noun'),
#   ('캐릭터', 'Noun'),
#   ('와', 'Josa'),
#   ('소통', 'Noun'),
#   ('하는', 'Verb'),
#   ('AI', 'Alpha'),
#   ('음성인식', 'Noun'),
#   ('기술', 'Noun'),
#   ('로', 'Josa'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('는', 'Verb'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('활용', 'Noun'),
#   ('해', 'Verb'),
#   ('음성인식', 'Noun'),
#   ('과', 'Josa'),
#   ('음성합성', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('제공', 'Noun'),
#   ('하는', 'Verb'),
#   ('업체', 'Noun'),
#   ('다', 'Josa'),
#   ('.', 'Punctuation'),
#   ('최근', 'Noun'),
#   ('증권', 'Noun'),
#   ('가에서', 'Verb'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('가', 'Verb'),
#   ('주목', 'Noun'),
#   ('받는', 'Verb'),
#   ('건', 'Noun'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('내', 'Noun'),
#   ('에서', 'Josa'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('가까운', 'Adjective'),
#   ('책', 'Noun'),
#   (']', 'Punctuation'),
#   ('트렌드', 'Noun'),
#   ('코리아', 'Noun'),
#   ('2022', 'Number'),
#   ('-', 'Punctuation'),
#   ('김난도', 'Noun'),
#   (',', 'Punctuation'),
#   ('전미영', 'Noun'),
#   (',', 'Punctuation'),
#   ('최지혜', 'Noun'),
#   ('외', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('빅데이터', 'Noun'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('NLP', 'Alpha'),
#   ('등', 'Noun'),
#   ('데이터', 'Noun'),
#   ('를', 'Josa'),
#   ('다양한', 'Adjective'),
#   ('관점', 'Noun'),
#   ('에서', 'Josa'),
#   ('분석', 'Noun'),
#   ('하고', 'Josa'),
#   ('있다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('코오롱', 'Noun'),
#   ('-', 'Punctuation'),
#   ('카이스트', 'Noun'),
#   ('라이프스타일', 'Noun'),
#   ('이노베이션', 'Noun'),
#   ('최우수상', 'Noun'),
#   ('을', 'Josa'),
#   ('수상했다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('저자', 'Noun'),
#   (':', 'Punctuation'),
#   ('권', 'Noun'),
#   ('정윤', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('주가', 'Noun'),
#   ('상한', 'Noun'),
#   ('가', 'Josa'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   ('음성인식', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('영상', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('HCI', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('Human', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('Computer', 'Alpha'),
#   ('Interaction', 'Alpha'),
#   (')', 'Punctuation'),
#   ('기술', 'Noun'),
#   ('경쟁력', 'Noun'),
#   ('을', 'Josa'),
#   ('강화하고', 'Adjective'),
#   ('있음', 'Adjective'),
#   ('....', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('는', 'Verb'),
#   ('음성인식', 'Noun'),
#   ('(', 'Punctuation'),
#   ('STT', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('인식', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('AI', 'Alpha'),
#   ('솔루션', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('재벌', 'Noun'),
#   ('투자', 'Noun'),
#   ('연구소', 'Noun'),
#   ('투자', 'Noun'),
#   ('정보', 'Noun'),
#   (']-', 'Punctuation'),
#   ('장', 'Noun'),
#   ('중', 'Suffix'),
#   ('에', 'Josa'),
#   ('78%', 'Number'),
#   ('로', 'Noun'),
#   ('수익', 'Noun'),
#   ('매도', 'Noun'),
#   ('#', 'Punctuation'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('동사', 'Noun'),
#   ('는', 'Josa'),
#   ('22년', 'Number'),
#   ('간의', 'Foreign'),
#   ('지속', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('연구개발', 'Noun'),
#   ('투자', 'Noun'),
#   ('를', 'Josa'),
#   ('통해', 'Noun'),
#   ('음성', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('필기', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('영상', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('HCI', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('Human', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('Computer', 'Alpha'),
#   ('Interaction', 'Alpha'),
#   (')', 'Punctuation'),
#   ('기술', 'Noun'),
#   ('경쟁력', 'Noun'),
#   ('을', 'Josa'),
#   ('강화하고', 'Adjective'),
#   ('있음', 'Adjective'),
#   ('....', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('가을', 'Noun'),
#   ('의', 'Josa'),
#   ('기록', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('회사', 'Noun'),
#   ('에서', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('특강', 'Noun'),
#   ('을', 'Josa'),
#   ('하는데', 'Verb'),
#   ('나', 'Noun'),
#   ('는', 'Josa'),
#   ('1', 'Number'),
#   ('도', 'Noun'),
#   ('모르겠다', 'Verb'),
#   ('..', 'Punctuation'),
#   ('꼭', 'Noun'),
#   ('배워', 'Verb'),
#   ('야할', 'Adjective'),
#   ('것', 'Noun'),
#   ('같은데', 'Adjective'),
#   ('과외', 'Noun'),
#   ('를', 'Josa'),
#   ('해야나아', 'Verb'),
#   ('ㅋㅋㅋㅋ', 'KoreanParticle'),
#   ('..', 'Punctuation'),
#   ('유투브', 'Noun'),
#   ('열심히', 'Adverb'),
#   ('보면', 'Verb'),
#   ('알', 'Noun'),
#   ('수', 'Noun'),
#   ('있지', 'Adjective'),
#   ('않나여', 'Verb'),
#   ('?', 'Punctuation'),
#   ('하', 'Exclamation'),
#   ('핳', 'Exclamation'),
#   (',,', 'Punctuation'),
#   ('어렵', 'Adjective'),
#   ('네', 'Determiner'),
#   ('여', 'Noun'),
#   ('진짜', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('기술', 'Noun'),
#   ('평가', 'Noun'),
#   ('A', 'Alpha'),
#   (',', 'Punctuation'),
#   ('AA', 'Alpha'),
#   ('등급', 'Noun'),
#   ('을', 'Josa'),
#   ('받고', 'Verb'),
#   ('기술', 'Noun'),
#   ('특례', 'Noun'),
#   ('상장', 'Noun'),
#   ('초읽기', 'Noun'),
#   ('에', 'Josa'),
#   ('들어간', 'Verb'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('음성인식', 'Noun'),
#   ('과', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('NLP', 'Alpha'),
#   (')', 'Punctuation'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('이전', 'Noun'),
#   ('받아', 'Verb'),
#   ('다양한', 'Adjective'),
#   ('분야', 'Noun'),
#   ('의', 'Josa'),
#   ('첨단', 'Noun'),
#   ('AI', 'Alpha'),
#   ('서비스', 'Noun'),
#   ('플랫폼', 'Noun'),
#   ('을', 'Josa'),
#   ('개발', 'Noun'),
#   ('하며', 'Verb'),
#   ('대표', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('AI', 'Alpha'),
#   ('기업', 'Noun'),
#   ('으로', 'Josa'),
#   ('성장', 'Noun'),
#   ('중', 'Suffix'),
#   ('인', 'Josa'),
#   ('비', 'Noun'),
#   ('상장회사', 'Noun'),
#   ('"', 'Punctuation'),
#   ('마인', 'Noun'),
#   ('즈', 'Modifier'),
#   ('랩', 'Noun'),
#   ('"', 'Punctuation'),
#   ('를', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('품절', 'Noun'),
#   ('주', 'Noun'),
#   ('관련', 'Noun'),
#   ('주', 'Noun'),
#   (',', 'Punctuation'),
#   ('하이', 'Noun'),
#   ('트론', 'Noun'),
#   ('주가', 'Noun'),
#   (',', 'Punctuation'),
#   ('이재명', 'Noun'),
#   ('후보', 'Noun'),
#   ('수술실', 'Noun'),
#   ('관련', 'Noun'),
#   ('발언', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('오늘', 'Noun'),
#   ('의', 'Josa'),
#   ('급등', 'Noun'),
#   ('주', 'Noun'),
#   ('하이', 'Noun'),
#   ('트론', 'Noun'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('갤럭시', 'Noun'),
#   ('아', 'Josa'),
#   ('에스', 'Noun'),
#   ('엠', 'Noun'),
#   ('일정', 'Noun'),
#   ('실업', 'Noun'),
#   ('갤럭시', 'Noun'),
#   ('아', 'Josa'),
#   ('머니', 'Adjective'),
#   ('트리', 'Noun'),
#   ('셀', 'Noun'),
#   ('바스', 'Noun'),
#   ('AI', 'Alpha'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('활용', 'Noun'),
#   ('해', 'Verb'),
#   ('음성인식', 'Noun'),
#   ('과', 'Josa'),
#   ('음성합성', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
#   ('의', 'Josa'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('경북', 'Noun'),
#   ('대학교', 'Noun'),
#   (',', 'Punctuation'),
#   ('K', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('Digital', 'Alpha'),
#   ('Training', 'Alpha'),
#   ('빅데이터', 'Noun'),
#   ('분석', 'Noun'),
#   ('가', 'Josa'),
#   ('양성', 'Noun'),
#   ('과정', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('한국어', 'Noun'),
#   ('처리', 'Noun'),
#   ('패키지', 'Noun'),
#   ('8', 'Number'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('미니', 'Noun'),
#   ('프로젝트', 'Noun'),
#   ('16', 'Number'),
#   ('데이터', 'Noun'),
#   ('분석', 'Noun'),
#   ('데이터', 'Noun'),
#   ('기초', 'Noun'),
#   ('통계', 'Noun'),
#   ('분석', 'Noun'),
#   ('8', 'Number'),
#   ('데이터', 'Noun'),
#   ('심화', 'Noun'),
#   ('분석', 'Noun'),
#   ('8', 'Number'),
#   ('데이터', 'Noun'),
#   ('분석', 'Noun'),
#   ('미니', 'Noun'),
#   ('프로젝트', 'Noun'),
#   ('16', 'Number'),
#   ('데이터', 'Noun'),
#   ('시각', 'Noun'),
#   ('화', 'Suffix'),
#   ('와', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('<', 'Punctuation'),
#   ('그냥', 'Noun'),
#   ('하지', 'Verb'),
#   ('말라', 'Adjective'),
#   ('>', 'Punctuation'),
#   ('|', 'Punctuation'),
#   ('빅데이터', 'Noun'),
#   ('전문가', 'Noun'),
#   ('송길영', 'Noun'),
#   ('부사', 'Noun'),
#   ('장이', 'Suffix'),
#   ('말', 'Noun'),
#   ('하는', 'Verb'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('바이브', 'Noun'),
#   ('컴퍼니', 'Noun'),
#   ('는', 'Josa'),
#   ('텍스트', 'Noun'),
#   ('마', 'Noun'),
#   ('이닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('대규모', 'Noun'),
#   ('정보', 'Noun'),
#   ('탐색', 'Noun'),
#   ('과', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('등', 'Noun'),
# ...
#   ('후보', 'Noun'),
#   ('분석', 'Noun'),
#   ('15', 'Number'),
#   ('화', 'Noun'),
#   (']', 'Punctuation'),
#   ('민주당', 'Noun'),
#   ('이재명', 'Noun'),
#   ('VS', 'Alpha'),
#   ('국민', 'Noun'),
#   ('의', 'Josa'),
#   ('힘', 'Noun'),
#   ('윤석열', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('데이터', 'Noun'),
#   ('를', 'Josa'),
#   ('분석', 'Noun'),
#   ('하여', 'Verb'),
#   ('제공', 'Noun'),
#   ('하는', 'Verb'),
#   ('매니', 'Noun'),
#   ('지드', 'Noun'),
#   ('웹', 'Noun'),
#   ('크롤', 'Noun'),
#   ('링', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Crawling', 'Alpha'),
#   (')', 'Punctuation'),
#   ('서비스', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('감정', 'Noun'),
#   ('분석', 'Noun'),
#   (',', 'Punctuation'),
#   ('형태소', 'Noun'),
#   ('분석', 'Noun'),
#   (')', 'Punctuation'),
#   ('뿐', 'Noun'),
#   ('만', 'Josa'),
#   ('아니라', 'Adjective'),
#   ('이미지', 'Noun'),
#   ('분석', 'Noun'),
#   ('기술', 'Noun'),
#   ('도', 'Josa'),
#   ('사용', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있습니다', 'Adjective'),
#   ('.', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('11월', 'Number'),
#   ('공', 'Modifier'),
#   ('모주', 'Noun'),
#   ('일정', 'Noun'),
#   ('(', 'Punctuation'),
#   ('트윔', 'Noun'),
#   (',', 'Punctuation'),
#   ('마인', 'Noun'),
#   ('즈', 'Modifier'),
#   ('랩', 'Noun'),
#   (',', 'Punctuation'),
#   ('알비', 'Noun'),
#   ('더블유', 'Noun'),
#   (',', 'Punctuation'),
#   ('바이옵트', 'Noun'),
#   ('로', 'Josa'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사람', 'Noun'),
#   ('이미지', 'Noun'),
#   ('의', 'Josa'),
#   ('키', 'Noun'),
#   ('오스', 'Noun'),
#   ('크라는', 'Verb'),
#   ('건데', 'Eomi'),
#   (',', 'Punctuation'),
#   ('마인', 'Noun'),
#   ('즈', 'Modifier'),
#   ('랩', 'Noun'),
#   ('의', 'Josa'),
#   ('M', 'Alpha'),
#   ('1', 'Number'),
#   ('은', 'Noun'),
#   ('아바타', 'Noun'),
#   ('기술', 'Noun'),
#   (',', 'Punctuation'),
#   ('음성인식', 'Noun'),
#   ('·', 'Punctuation'),
#   ('합성', 'Noun'),
#   ('기술', 'Noun'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('NLP', 'Alpha'),
#   (')', 'Punctuation'),
#   ('기술', 'Noun'),
#   ('과', 'Josa'),
#   ('역량', 'Noun'),
#   ('등', 'Noun'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('총', 'Modifier'),
#   ('망라', 'Noun'),
#   ('된', 'Verb'),
#   ('서비스', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('그냥', 'Noun'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('쏘나타', 'Noun'),
#   ('장기', 'Noun'),
#   ('렌트', 'Noun'),
#   ('_', 'Punctuation'),
#   ('비교', 'Noun'),
#   ('견적', 'Noun'),
#   ('을', 'Josa'),
#   ('통해', 'Noun'),
#   ('착한', 'Adjective'),
#   ('가격', 'Noun'),
#   ('으로', 'Josa'),
#   ('스마트', 'Noun'),
#   ('하게', 'Verb'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('기반', 'Noun'),
#   ('의', 'Josa'),
#   ('자연어', 'Noun'),
#   ('음성', 'Noun'),
#   ('명령', 'Noun'),
#   ('기능', 'Noun'),
#   ('과', 'Josa'),
#   (',', 'Punctuation'),
#   ('준', 'Noun'),
#   ('자율', 'Noun'),
#   ('주행', 'Noun'),
#   ('급', 'Suffix'),
#   ('의', 'Josa'),
#   ('스마트', 'Noun'),
#   ('크루즈', 'Noun'),
#   ('컨트롤', 'Noun'),
#   ('...', 'Punctuation'),
#   ('비용', 'Noun'),
#   ('처리', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있으며', 'Adjective'),
#   (',', 'Punctuation'),
#   ('추가', 'Noun'),
#   ('로', 'Josa'),
#   ('차량', 'Noun'),
#   ('유류', 'Noun'),
#   ('비', 'Noun'),
#   ('로', 'Josa'),
#   ('사용', 'Noun'),
#   ('되는', 'Verb'),
#   ('비용', 'Noun'),
#   ('중', 'Noun'),
#   ('매년', 'Noun'),
#   ('700만원', 'Number'),
#   ('까지', 'Foreign'),
#   ('비용', 'Noun'),
#   ('처리', 'Noun'),
#   ('를', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('패스트', 'Noun'),
#   ('캠퍼스', 'Noun'),
#   ('챌', 'Verb'),
#   ('린지', 'Noun'),
#   ('5일', 'Number'),
#   ('차', 'Foreign'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('부트캠프', 'Noun'),
#   ('에', 'Josa'),
#   ('합격', 'Noun'),
#   ('한', 'Josa'),
#   ('나', 'Noun'),
#   ('는', 'Josa'),
#   ('오늘밤', 'Noun'),
#   ('이', 'Josa'),
#   ('지나가기전에', 'Verb'),
#   ('배송지', 'Noun'),
#   ('를', 'Josa'),
#   ('입력', 'Noun'),
#   ('해야', 'Verb'),
#   ('한다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('이', 'Noun'),
#   ('게', 'Josa'),
#   ('맞는', 'Verb'),
#   ('길이', 'Noun'),
#   ('맞을까', 'Verb'),
#   ('계속', 'Noun'),
#   ('고민', 'Noun'),
#   ('되지만', 'Verb'),
#   ('꿈', 'Noun'),
#   ('에다가', 'Josa'),
#   ('한', 'Determiner'),
#   ('표', 'Noun'),
#   ('를', 'Josa'),
#   ('던지기', 'Noun'),
#   ('로', 'Josa'),
#   ('했다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('자꾸', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('IT', 'Alpha'),
#   ('소식', 'Noun'),
#   (']', 'Punctuation'),
#   ('젠슨', 'Noun'),
#   ('황', 'Noun'),
#   ('엔비디아', 'Noun'),
#   ('CEO', 'Alpha'),
#   (',', 'Punctuation'),
#   ("'", 'Punctuation'),
#   ('GTC', 'Alpha'),
#   ("'", 'Punctuation'),
#   ('기', 'Modifier'),
#   ('조', 'Modifier'),
#   ('연설', 'Noun'),
#   ('나선다', 'Verb'),
#   ('…', 'Punctuation'),
#   ('AI', 'Alpha'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('젠슨', 'Noun'),
#   ('황', 'Noun'),
#   ('CEO', 'Alpha'),
#   ('는', 'Verb'),
#   ('기', 'Modifier'),
#   ('조', 'Modifier'),
#   ('연설', 'Noun'),
#   ('에서', 'Josa'),
#   ('엔터프라이즈', 'Noun'),
#   ('및', 'Noun'),
#   ('데이터', 'Noun'),
#   ('센터', 'Noun'),
#   ('AI', 'Alpha'),
#   (',', 'Punctuation'),
#   ('대화', 'Noun'),
#   ('형', 'Suffix'),
#   ('AI', 'Alpha'),
#   ('와', 'Verb'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('를', 'Josa'),
#   ('위', 'Noun'),
#   ('한', 'Josa'),
#   ('최신', 'Noun'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('비롯', 'Noun'),
#   ('해', 'Verb'),
#   ('로보틱스', 'Noun'),
#   ('부터', 'Josa'),
#   ('헬', 'Noun'),
#   ('스케', 'Noun'),
#   ('어', 'Suffix'),
#   (',', 'Punctuation'),
#   ('자율', 'Noun'),
#   ('주행', 'Noun'),
#   ('차량', 'Noun'),
#   ('에', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('마이크로소프트', 'Noun'),
#   ('(', 'Punctuation'),
#   ('MSFT', 'Alpha'),
#   (')', 'Punctuation'),
#   ('주가', 'Noun'),
#   (':', 'Punctuation'),
#   ('마소', 'Noun'),
#   ('도', 'Josa'),
#   ('메타', 'Noun'),
#   ('버스', 'Noun'),
#   (',', 'Punctuation'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('(', 'Punctuation'),
#   ('AI', 'Alpha'),
#   (')...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Open', 'Alpha'),
#   ('AI', 'Alpha'),
#   ('란', 'Noun'),
#   ('일', 'Modifier'),
#   ('론', 'Noun'),
#   ('머스크', 'Noun'),
#   ('가', 'Josa'),
#   ('처음', 'Noun'),
#   ('투자', 'Noun'),
#   ('했던', 'Verb'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('개발', 'Noun'),
#   ('기구', 'Noun'),
#   ('인데', 'Josa'),
#   (',', 'Punctuation'),
#   ('이', 'Noun'),
#   ('기구', 'Noun'),
#   ('에', 'Josa'),
#   ('지', 'Modifier'),
#   ('분', 'Noun'),
#   ('을', 'Josa'),
#   ('투자', 'Noun'),
#   ('해', 'Verb'),
#   ('만든', 'Verb'),
#   ('대규모', 'Noun'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('모델', 'Noun'),
#   ('이', 'Josa'),
#   ('GPT', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('3', 'Number'),
#   ('다', 'Adverb'),
#   ('.', 'Punctuation'),
#   ('MS', 'Alpha'),
#   ('가', 'Verb'),
#   ('이', 'Noun'),
#   ('모델', 'Noun'),
#   ('의', 'Josa'),
#   ('라이선스', 'Noun'),
#   ('독점', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('대규모', 'Noun'),
#   ('(', 'Punctuation'),
#   ('그랜드', 'Noun'),
#   (')', 'Punctuation'),
#   ('도전', 'Noun'),
#   ('잇기', 'Verb'),
#   ('(', 'Punctuation'),
#   ('챌', 'Verb'),
#   ('린지', 'Noun'),
#   (')', 'Punctuation'),
#   ('5', 'Number'),
#   ('차', 'Noun'),
#   ('대회', 'Noun'),
#   ('2', 'Number'),
#   ('단계', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('5', 'Number'),
#   ('차', 'Noun'),
#   ('대회', 'Noun'),
#   ('는', 'Josa'),
#   ('자연어', 'Noun'),
#   ('의', 'Josa'),
#   ('이해', 'Noun'),
#   ('와', 'Josa'),
#   ('수리', 'Noun'),
#   ('적', 'Suffix'),
#   ('사고', 'Noun'),
#   ('?', 'Punctuation'),
#   ('추론', 'Noun'),
#   ('에', 'Josa'),
#   ('기반', 'Noun'),
#   ('한', 'Verb'),
#   ('복합', 'Noun'),
#   ('지능', 'Noun'),
#   ('기술', 'Noun'),
#   ('...', 'Punctuation'),
#   ('대회', 'Noun'),
#   ('에서', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('규칙', 'Noun'),
#   ('을', 'Josa'),
#   ('완화', 'Noun'),
#   ('하고', 'Josa'),
#   ('문서', 'Noun'),
#   ('(', 'Punctuation'),
#   ('텍스트', 'Noun'),
#   (')', 'Punctuation'),
#   ('로', 'Noun'),
#   ('묘사', 'Noun'),
#   ('된', 'Verb'),
#   ('도형', 'Noun'),
#   ('문제', 'Noun'),
#   ('를', 'Josa'),
#   ('추가', 'Noun'),
#   ('하는', 'Verb'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('ESG', 'Alpha'),
#   ('/', 'Punctuation'),
#   ('투자', 'Noun'),
#   (']', 'Punctuation'),
#   ('팬데믹', 'Noun'),
#   ('시대', 'Noun'),
#   ('가', 'Josa'),
#   ('일', 'Noun'),
#   ('깨워', 'Verb'),
#   ('준', 'Noun'),
#   ('지속', 'Noun'),
#   ('가능한', 'Adjective'),
#   ('투자', 'Noun'),
#   ('의', 'Josa'),
#   ('중요성', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('이', 'Noun'),
#   ('연구', 'Noun'),
#   ('는', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('를', 'Josa'),
#   ('이용', 'Noun'),
#   ('하여', 'Verb'),
#   ('노무', 'Noun'),
#   ('관리', 'Noun'),
#   (',', 'Punctuation'),
#   ('공급망', 'Noun'),
#   ('관리', 'Noun'),
#   (',', 'Punctuation'),
#   ('기업', 'Noun'),
#   ('운영', 'Noun'),
#   ('등', 'Noun'),
#   ('에서', 'Josa'),
#   ('기업', 'Noun'),
#   ('이', 'Josa'),
#   ('취한', 'Noun'),
#   ('이해관계자', 'Noun'),
#   ('친', 'Noun'),
#   ('화', 'Suffix'),
#   ('적', 'Noun'),
#   ('인', 'Josa'),
#   ('행동', 'Noun'),
#   ('을', 'Josa'),
#   ('평가', 'Noun'),
#   ('하였습니다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('이해관계자', 'Noun'),
#   ('친', 'Noun'),
#   ('화', 'Suffix'),
#   ('적', 'Noun'),
#   ('인', 'Josa'),
#   ('행동', 'Noun'),
#   ('을', 'Josa'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('[', 'Punctuation'),
#   ('물류', 'Noun'),
#   ('매거진', 'Verb'),
#   (']', 'Punctuation'),
#   ('CJ', 'Alpha'),
#   ('대', 'Modifier'),
#   ('한', 'Modifier'),
#   ('통운', 'Noun'),
#   ('/', 'Punctuation'),
#   ('택배', 'Noun'),
#   ('기사', 'Noun'),
#   ('돕는', 'Verb'),
#   ('‘', 'Foreign'),
#   ('AI', 'Alpha'),
#   ('비서', 'Noun'),
#   ('’', 'Punctuation'),
#   ('도입', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('음성인식', 'Noun'),
#   ('(', 'Punctuation'),
#   ('STT', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('음성합성', 'Noun'),
#   ('(', 'Punctuation'),
#   ('TTS', 'Alpha'),
#   ('),', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('(', 'Punctuation'),
#   ('NLP', 'Alpha'),
#   (')', 'Punctuation'),
#   ('등', 'Noun'),
#   ('다양한', 'Adjective'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('융', 'Noun'),
#   ('·', 'Punctuation'),
#   ('복합', 'Noun'),
#   ('해', 'Verb'),
#   ('사용자', 'Noun'),
#   ('환경', 'Noun'),
#   ('에', 'Josa'),
#   ('최적화', 'Noun'),
#   ('했다', 'Verb'),
#   ('.', 'Punctuation'),
#   ('CJ', 'Alpha'),
#   ('대', 'Modifier'),
#   ('한', 'Modifier'),
#   ('통운', 'Noun'),
#   ('은', 'Josa'),
#   ('체감', 'Noun'),
#   ('도', 'Josa'),
#   ('높은', 'Adjective'),
#   ('정교한', 'Adjective'),
#   ('서비스', 'Noun'),
#   ('를', 'Josa'),
#   ('구현', 'Noun'),
#   ('하기', 'Verb'),
#   ('위해', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('딥', 'Noun'),
#   ('러닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('머신', 'Noun'),
#   ('러닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('차이점', 'Noun'),
#   ('알아보기', 'Verb'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('4', 'Number'),
#   ('.', 'Punctuation'),
#   ('추천', 'Noun'),
#   ('시스템', 'Noun'),
#   ('이렇게', 'Adverb'),
#   ('4', 'Number'),
#   ('가지', 'Noun'),
#   ('분야', 'Noun'),
#   ('에서', 'Josa'),
#   ('다양하게', 'Adjective'),
#   ('사용', 'Noun'),
#   ('되고', 'Verb'),
#   ('있더라고요', 'Adjective'),
#   ('.', 'Punctuation'),
#   ('지금', 'Noun'),
#   ('까지', 'Josa'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   (',', 'Punctuation'),
#   ('머신', 'Noun'),
#   ('러닝', 'Noun'),
#   (',', 'Punctuation'),
#   ('딥', 'Noun'),
#   ('러닝', 'Noun'),
#   ('에', 'Josa'),
#   ('대하', 'Noun'),
#   ('여', 'Josa'),
#   ('간단하게', 'Adjective'),
#   ('알아보는', 'Verb'),
#   ('시간', 'Noun'),
#   ('을', 'Josa'),
#   ('가졌는데', 'Verb'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('과', 'Noun'),
#   ('기', 'Modifier'),
#   ('정통부', 'Noun'),
#   (',', 'Punctuation'),
#   ('‘', 'Foreign'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('그랜드', 'Noun'),
#   ('챌', 'Verb'),
#   ('린지', 'Noun'),
#   ('’', 'Punctuation'),
#   ('진행', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('5', 'Number'),
#   ('차', 'Noun'),
#   ('대회', 'Noun'),
#   ('는', 'Josa'),
#   ('AI', 'Alpha'),
#   ('기술', 'Noun'),
#   ('을', 'Josa'),
#   ('활용', 'Noun'),
#   ('한', 'Josa'),
#   ('수학', 'Noun'),
#   ('문제', 'Noun'),
#   ('해결', 'Noun'),
#   ('을', 'Josa'),
#   ('주제', 'Noun'),
#   ('로', 'Josa'),
#   (',', 'Punctuation'),
#   ('자연어', 'Noun'),
#   ('이해', 'Noun'),
#   ('와', 'Josa'),
#   ('수리', 'Noun'),
#   ('적', 'Suffix'),
#   ('...', 'Punctuation'),
#   ('대회', 'Noun'),
#   ('에서', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('규칙', 'Noun'),
#   ('을', 'Josa'),
#   ('완화', 'Noun'),
#   ('하고', 'Josa'),
#   ('텍스트', 'Noun'),
#   ('로', 'Josa'),
#   ('묘사', 'Noun'),
#   ('된', 'Verb'),
#   ('도형', 'Noun'),
#   ('문제', 'Noun'),
#   ('를', 'Josa'),
#   ('추가', 'Noun'),
#   ('하는', 'Verb'),
#   ('등', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('콴다', 'Noun'),
#   ('라는', 'Josa'),
#   ('별', 'Noun'),
#   ('이', 'Josa'),
#   ('뜨고', 'Verb'),
#   ('메가스터디', 'Noun'),
#   ('는', 'Josa'),
#   ('지고', 'Noun'),
#   ('있네', 'Adjective'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('요새', 'Noun'),
#   ('는', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('AI', 'Alpha'),
#   ('를', 'Noun'),
#   ('통해', 'Noun'),
#   ('문자', 'Noun'),
#   ('로', 'Josa'),
#   ('하는', 'Verb'),
#   ('질문', 'Noun'),
#   ('에', 'Josa'),
#   ('대해', 'Noun'),
#   ('서도', 'Noun'),
#   ('답변', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있도록', 'Adjective'),
#   ('하는', 'Verb'),
#   ('방안', 'Noun'),
#   ('도', 'Josa'),
#   ('추진', 'Noun'),
#   ('중이', 'Noun'),
#   ('라는', 'Josa'),
#   ('데', 'Noun'),
#   (',', 'Punctuation'),
#   ('이뿐만', 'Adjective'),
#   ('아니라', 'Adjective'),
#   ('콴다', 'Noun'),
#   ('이용자', 'Noun'),
#   ('들', 'Suffix'),
#   ('끼리', 'Noun'),
#   ('공부', 'Noun'),
#   ('잘', 'VerbPrefix'),
#   ('하는', 'Verb'),
#   ('법', 'Noun'),
#   (',', 'Punctuation'),
#   ('입시', 'Noun'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('수지', 'Noun'),
#   ('군청', 'Noun'),
#   ('전화', 'Noun'),
#   ('안내', 'Noun'),
#   ('시스템', 'Noun'),
#   ('에', 'Josa'),
#   ('음성합성', 'Noun'),
#   ('기', 'Noun'),
#   ('ReadSpeaker', 'Alpha'),
#   ('™', 'Foreign'),
#   ('혜련', 'Noun'),
#   ('...', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('성우', 'Noun'),
#   (',', 'Punctuation'),
#   ('#자연어처리', 'Hashtag'),
#   (',', 'Punctuation'),
#   ('#TTS프로그램', 'Hashtag'),
#   (',', 'Punctuation'),
#   ('#콜센터', 'Hashtag'),
#   (',', 'Punctuation'),
#   ('#아나운서', 'Hashtag'),
#   (',', 'Punctuation'),
#   ('#영어', 'Hashtag'),
#   ('교육', 'Noun'),
#   (',', 'Punctuation'),
#   ('#DNN', 'Hashtag'),
#   (',', 'Punctuation'),
#   ('#NLP', 'Hashtag'),
#   (',', 'Punctuation'),
#   ('#목소리프로그램', 'Hashtag'),
#   ('#e', 'Hashtag'),
#   ('-', 'Punctuation'),
#   ('book', 'Alpha'),
#   ('#마이토키', 'Hashtag'),
#   ('#STT', 'Hashtag'),
#   ('#영어교육', 'Hashtag'),
#   ('#리드스피커', 'Hashtag'),
#   ('...', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('AI', 'Alpha'),
#   ('그랜드', 'Noun'),
#   ('챌', 'Verb'),
#   ('린지', 'Noun'),
#   (',', 'Punctuation'),
#   ('원자력', 'Noun'),
#   ('연', 'Noun'),
#   ('-', 'Punctuation'),
#   ('젠티', 'Noun'),
#   ('연합팀', 'Noun'),
#   ('1', 'Number'),
#   ('위로', 'Noun'),
#   ('3', 'Number'),
#   ('단계', 'Noun'),
#   ('진출', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('5', 'Number'),
#   ('차', 'Noun'),
#   ('대회', 'Noun'),
#   ('는', 'Josa'),
#   ('자연어', 'Noun'),
#   ('의', 'Josa'),
#   ('이해', 'Noun'),
#   ('와', 'Josa'),
#   ('수리', 'Noun'),
#   ('적', 'Suffix'),
#   ('사고', 'Noun'),
#   ('추론', 'Noun'),
#   ('에', 'Josa'),
#   ('기반', 'Noun'),
#   ('한', 'Josa'),
#   ('복합', 'Noun'),
#   ('지능', 'Noun'),
#   ('기술', 'Noun'),
#   ('확보', 'Noun'),
#   ('를', 'Josa'),
#   ('...', 'Punctuation'),
#   ('성균관대', 'Noun'),
#   ('인공', 'Noun'),
#   ('지능', 'Noun'),
#   ('대학원', 'Noun'),
#   ('연', 'Modifier'),
#   ('구', 'Modifier'),
#   ('팀', 'Noun'),
#   ('은', 'Josa'),
#   ('자연어', 'Noun'),
#   ('처리', 'Noun'),
#   ('연구', 'Noun'),
#   ('역량', 'Noun'),
#   ('을', 'Josa'),
#   ('바탕', 'Noun'),
#   ('으로', 'Josa'),
#   ('수학', 'Noun'),
#   ('문제', 'Noun'),
#   ('...', 'Punctuation')]]

# %%
okt_pos_result =[ ]

#바깥쪽 리스트 okt_pos에서 안쪽 리스트 pos에 해당하는 100개의 리스트를 반복
for pos in okt_pos : 
    for i in pos :   #안쪽 리스트 pos에서 각각의 튜플 i를 반복
        okt_pos_result.append(i)  #(튜플) i 값을 추가하는 리스트 pos_result

# %%
print(okt_pos_result) #하나의 리스트 안에 튜플들이 있는 구조
# Out:
# [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('트', 'Noun'), ('링크', 'Noun'), ('AI', 'Alpha'), ('는', 'Verb'), ('지역', 'Noun'), ('관광', 'Noun'), ('솔루션', 'Noun'), ('입니다', 'Adjective'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('텍스트', 'Noun'), ('마', 'Noun'), ('이닝', 'Noun'), (',', 'Punctuation'), ('대화', 'Noun'), ('형', 'Suffix'), ('자연어', 'Noun'), ('처리', 'Noun'), ('기술', 'Noun'), ('로', 'Josa'), ('강화', 'Noun'), ('된', 'Verb'), ('인공', 'Noun'), ('지능', 'Noun'), ('이', 'Josa'), ('해답', 'Noun'), ('을', 'Josa'), ('제시', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('3', 'Number'), ('.', 'Punctuation'), ('모든', 'Noun'), ('담당자', 'Noun'), ('가', 'Josa'), ('쉽게', 'Verb'), ('인사이트', 'Noun'), ('를', 'Josa'), ('활용', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있도록', 'Adjective'), ('시각', 'Noun'), ('화', 'Suffix'), ('자료', 'Noun'), ('를', 'Josa'), ('제공', 'Noun'), ('합니다', 'Verb'), ('....', 'Punctuation'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('패스트', 'Noun'), ('캠퍼스', 'Noun'), ('챌', 'Verb'), ('린지', 'Noun'), ('10일', 'Number'), ('차', 'Foreign'), ('(', 'Punctuation'), ('수요일', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('ly', 'Alpha'), ('/', 'Punctuation'), ('3', 'Number'), ('FVdhDa', 'Alpha'), ('#패스트캠퍼스', 'Hashtag'), ('#패캠챌린지', 'Hashtag'), ('#직장인인강', 'Hashtag'), ('#직장인자기계발', 'Hashtag'), ('#패스트캠퍼스후기', 'Hashtag'), ('#김기현의딥러닝을활용한자연어처리입문올인원패키지Online', 'Hashtag'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('다급한', 'Adjective'), ('기업', 'Noun'), (',', 'Punctuation'), ('IT', 'Alpha'), ('인재', 'Noun'), ('직접', 'Noun'), ('키워', 'Verb'), ('…', 'Punctuation'), ('컴공', 'Noun'), ('·', 'Punctuation'), ('전산', 'Noun'), ('서울', 'Noun'), ('대졸', 'Noun'), ('자', 'Suffix'), ('추월', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('이', 'Noun'), ('프로그램', 'Noun'), ('은', 'Josa'), ('자연어', 'Noun'), ('처리', 'Noun'), ('기법', 'Noun'), ('을', 'Josa'), ('활용', 'Noun'), ('해', 'Verb'), ('법률', 'Noun'), ('문서', 'Noun'), ('의', 'Josa'), ('내용', 'Noun'), ('이', 'Josa'), ('잘', 'Verb'), ('요약', 'Noun'), ('된', 'Verb'), ('문장', 'Noun'), ('을', 'Josa'), ('...', 'Punctuation'), ('신경망', 'Noun'), ('처리장치', 'Noun'), ('(', 'Punctuation'), ('NPU', 'Alpha'), (')', 'Punctuation'), ('개발', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('해선', 'Noun'), ('컴퓨터공학', 'Noun'), ('을', 'Josa'), ('비롯', 'Noun'), ('한', 'Josa'), ('소프트웨어', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('...', 'Punctuation'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('2021년', 'Number'), ('11월', 'Number'), ('9일', 'Number'), ('상한', 'Noun'), ('가', 'Josa'), ('(', 'Punctuation'), ('갤럭시', 'Noun'), ('아', 'Josa'), ('에스', 'Noun'), ('엠', 'Noun'), (',', 'Punctuation'), ('셀', 'Noun'), ('바스', 'Noun'), ('AI', 'Alpha'), (',', 'Punctuation'), ('하이', 'Noun'), ('트론', 'Noun'), ('...', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('음성인식', 'Noun'), ('(', 'Punctuation'), ('STT', 'Alpha'), ('),', 'Punctuation'), ('음성합성', 'Noun'), ('(', 'Punctuation'), ('TTS', 'Alpha'), ('),', 'Punctuation'), ('자연어', 'Noun'), ('처리', 'Noun'), (',', 'Punctuation'), ('필기', 'Noun'), ('인식', 'Noun'), ('등', 'Noun'), ('의', 'Josa'), ('AI', 'Alpha'), ('솔루션', 'Noun'), ('을', 'Josa'), ('제공', 'Noun'), ('하고', 'Josa'), ('...', 'Punctuation'), ('이', 'Noun'), ('회사', 'Noun'), ('는', 'Josa'), ('건축', 'Noun'), ('용', 'Noun'), ('자재', 'Noun'), ('를', 'Josa'), ('제조', 'Noun'), ('하는', 'Verb'), ('데크', 'Noun'), ('플레이', 'Noun'), ('트', 'Noun'), ('부문', 'Noun'), (',', 'Punctuation'), ('조', 'Modifier'), ('선용', 'Noun'), ('철판', 'Noun'), ('을', 'Josa'), ('표면처리', 'Noun'), ('...', 'Punctuation'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('인공', 'Noun'), ('지능', 'Noun'), ('을', 'Josa'), ('넘어', 'Verb'), ('인공', 'Noun'), ('자아', 'Noun'), ('의', 'Josa'), ('시대', 'Noun'), ('로', 'Josa'), ('도약', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('일각', 'Noun'), ('에서는', 'Josa'), ('2032년', 'Number'), ('이면', 'Foreign'), ('GPT', 'Alpha'), ('-', 'Punctuation'), ('3', 'Number'), ('보다', 'Verb'), ('1000', ' ...

# %%
print('● 데이터 타입 : ', type(okt_pos_result)) 
print('● shape : ', np.shape(okt_pos_result))
print("● 리스트에 있는 튜플 개수 : ", len(okt_pos_result))
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● shape :  (5496, 2)
# ● 리스트에 있는 튜플 개수 :  5496

# %% [markdown]
# <span style="color: red ; font-size: 14pt">
# 3.2. nouns() 함수를 이용한 명사 추출하기
# </span>

# %%
okt_nouns=[]  #명사 부분 저장을 위한 리스트

for data in data_tit_con : 
    #명사 부분 리스트에 추가 
    #okt.nouns()는 리스트 안에 '스트링'을 넣어서 리턴
    #okt_nouns는 리스트이고,okt.nouns() 결과도 리스트이므로 2차원리스트 생성 
    
    okt_nouns.append(okt.nouns(data))

# %%
#바깥쪽 리스트 안에 또 하나의 리스트가 포함되어 있으며
#내부 리스트 안에 튜플이 있는 구조

print(okt_nouns)
# Out:
# [['제목', '트', '링크', '지역', '관광', '솔루션', '내용', '텍스트', '마', '이닝', '대화', '자연어', '처리', '기술', '강화', '인공', '지능', '해답', '제시', '모든', '담당자', '인사이트', '활용', '수', '시각', '자료', '제공'], ['제목', '패스트', '캠퍼스', '린지', '수요일', '내용'], ['제목', '기업', '인재', '직접', '컴공', '전산', '서울', '대졸', '추월', '내용', '이', '프로그램', '자연어', '처리', '기법', '활용', '법률', '문서', '내용', '요약', '문장', '신경망', '처리장치', '개발', '위', '해선', '컴퓨터공학', '비롯', '소프트웨어', '대한'], ['제목', '상한', '갤럭시', '에스', '엠', '셀', '바스', '하이', '트론', '내용', '음성인식', '음성합성', '자연어', '처리', '필기', '인식', '등', '솔루션', '제공', '이', '회사', '건축', '용', '자재', '제조', '데크', '플레이', '트', '부문', '선용', '철판', '표면처리'], ['제목', '인공', '지능', '인공', '자아', '시대', '도약', '내용', '일각', '배', '학습', '처리', '능력', '인공', '지능', '탄생', '또한', '일반', '상식', '대한', '이미지', '자연어', '처리', '상식', '객관'], ['제목', '디지털', '시대', '전공', '중앙', '대학교', '소프트웨어', '학부', '내용', '상처리', '학년', '캡', '스톤', '디자인', '멀티코어', '컴퓨팅', '무선', '이동통신', '네트워크', '응용', '설계', '정보보호', '이론', '생체인식', '및', '응용', '자연어', '처리', '및', '정보검색', '패턴인식', '컴퓨터'], ['제목', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '평가', '내용', '음성인식', '음성합성', '자연어', '처리', '필기', '인식', '등', '솔루션', '제', '공', '셀', '바스', '의', '음성', '기술', '주목', '각', '도메', '인별', '데이터', '학습', '통해'], ['제목', '신규', '공개', '내용', '향상', '처리', '능력', '이전', '세대', '의', '폼팩터', '및', '핀', '대한', '개발자', '자연어', '이해', '인식', '멀티', '센서', '퓨전', '등', '관련', '엣지'], ['제목', '메타', '버스', '관련', '주로', '셀', '바스', '성공', '내용', '영상', '지능', '자연어', '처리', '등', '기술', '경쟁력', '재벌', '투자', '연구소', '전문가', '주식', '후기', '가장', '수익', '이야기'], ['제목', '뉴스레터', '주', '넷플릭스', '게임', '내용', '대표', '신약', '개발', '배터리', '성능', '개선', '날씨', '예측', '주식', '선별', '양자', '자연어', '처리', '이동', '경로', '최적화', '교통', '관리', '데이터', '보호', '등', '생활', '기술', '양자', '컴퓨터'], ['제목', '자바', '공부', '자바', '알고리즘', '무엇', '내용', '컴퓨터', '무엇', '처리', '내용', '처리', '순서', '모두', '구체', '알고리즘', '자연어', '의사코드', '순서도', '프로그래밍', '언어', '등', '표현'], ['제목', '파이썬', '수', '권', '머신', '내용', '심층', '신경망', '처리', '자연어', '처리', '편미분', '방정식', '추상화', '이미지', '주요', '역할', '데이터', '조작', '및', '분석', '자연어', '툴킷', '의'], ['제목', '황정리', '프로', '내용', '자연어', '처리', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '애플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝'], ['제목', '월', '수원', '삼성', '전기', '인공', '지능', '챗봇', '트레이너', '내용', '자체', '개발', '자연어', '처리', '기술', '머신', '러닝', '텍스트', '마', '이닝', '의미', '분석', '및', '검색', '등', '복합', '융합', '인공', '지능', '기반', '하이브리드', '챗봇', '솔루션'], ['제목', '영상', '전상호', '코어', '에이', '아이', '상무', '대화', '내용', '인지', '검색'], ['제목', '빅', '데이터', '란', '특징', '의미', '내용', '학습', '자연어', '처리', '패턴', '인식', '등', '분석', '기법', '해당', '복잡', '데이터', '구조', '데이터', '획득', '처리', '속도', '도메인', '규칙', '저장', '타입', '등'], ['제목', '개발', '유닛', '무하', '유의', '서비스', '서비스', '내용', '민', '프로', '저', '자연어', '이해', '기술', '기업', '무하', '유', '회사', '슬로건', '보고', '서비스', '문장', '처리', '기술', '기술', '적용', '경험', '수'], ['제목', '임', '리치', '비트코인', '총', '달러', '근접', '급등', '내용', '예산', '법안', '처리', '것', '증시', '호재', '작용', '폭', '상승', '마감', '추출', '자연어', '처리', '방식', '실시', '비트코인', '단어', '대한'], ['제목', '프로', '티비', '월', '모닝', '라이브', '오늘아침', '라이브', '내용', '대화', '자연어', '처리', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '어플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝'], ['제목', '공식', '움', '원자폭탄', '비트코인', '세상', '내용', '제목', '공식', '움', '원자폭탄', '비트코인', '세상', '절대', '공식', '저자', '양자', '학파', '출판', '미디어', '숲', '발매', '저자', '양자', '학파', '양자', '학파', '자연', '과학', '수학'], ['제목', '의', '전략', '시리즈', '내용', '즉', '인간', '사용', '자연어', '처리', '기술', '언어', '장벽', '허물', '언어', '사용', '누구', '대화'], ['제목', '검색', '조회', '수가', '단어', '키', '워드', '상위', '노출', '유입', '분석', '내용', '자연어', '처리', '국어', '전자', '순찰', '토카막', '네트워크', '폐기물', '에너지', '변환', '미분방정식', '홍합', '접착', '단백질'], ['제목', '멀티', '캠퍼스', '인공', '지능', '자연어', '처리', '기반', '기업', '데이터', '분석', '내용', '인공', '지능', '자연어', '처리', '키', '워드', '보고', '바로', '지원', '무엇', '인지도', '상태', '개념', '내용', '블로그', '유튜브', '통해', '공부'], ['제목', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '내용', '자연어', '처리', '필기', '인식', '등', '솔루션', '제공', '국내', '최고', '음성인식', '률', '보유', '음성합성', '기술', '로', '국내', '위', '쌍', '방향', '커뮤니케이션', '핵심', '기술', '음성', '기술'], ['제목', '셀', '바스', '주가', '전망', ...

# %%
print('● 데이터 타입 : ', type(okt_nouns)) 
print("● ['스트링', ...'스트링'] 리스트 개수 : ", len(okt_nouns) )
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● ['스트링', ...'스트링'] 리스트 개수 :  100

# %%
okt_nouns_result =[ ]

#바깥쪽 리스트 okt_nouns에서 안쪽 리스트 nouns에 해당하는 100개의 리스트를 반복
for nouns in okt_nouns : 
    for i in nouns :   #안쪽 리스트 nouns에서 각각의 '스트링' i를 반복
        okt_nouns_result.append(i)  #'스트링' i 값을 추가하는 리스트 nouns_result

# %%
print(okt_nouns_result) #하나의 리스트 안에 '스트링'이 있는 구조
# Out:
# ['제목', '트', '링크', '지역', '관광', '솔루션', '내용', '텍스트', '마', '이닝', '대화', '자연어', '처리', '기술', '강화', '인공', '지능', '해답', '제시', '모든', '담당자', '인사이트', '활용', '수', '시각', '자료', '제공', '제목', '패스트', '캠퍼스', '린지', '수요일', '내용', '제목', '기업', '인재', '직접', '컴공', '전산', '서울', '대졸', '추월', '내용', '이', '프로그램', '자연어', '처리', '기법', '활용', '법률', '문서', '내용', '요약', '문장', '신경망', '처리장치', '개발', '위', '해선', '컴퓨터공학', '비롯', '소프트웨어', '대한', '제목', '상한', '갤럭시', '에스', '엠', '셀', '바스', '하이', '트론', '내용', '음성인식', '음성합성', '자연어', '처리', '필기', '인식', '등', '솔루션', '제공', '이', '회사', '건축', '용', '자재', '제조', '데크', '플레이', '트', '부문', '선용', '철판', '표면처리', '제목', '인공', '지능', '인공', '자아', '시대', '도약', '내용', '일각', '배', '학습', '처리', '능력', '인공', '지능', '탄생', '또한', '일반', '상식', '대한', '이미지', '자연어', '처리', '상식', '객관', '제목', '디지털', '시대', '전공', '중앙', '대학교', '소프트웨어', '학부', '내용', '상처리', '학년', '캡', '스톤', '디자인', '멀티코어', '컴퓨팅', '무선', '이동통신', '네트워크', '응용', '설계', '정보보호', '이론', '생체인식', '및', '응용', '자연어', '처리', '및', '정보검색', '패턴인식', '컴퓨터', '제목', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '평가', '내용', '음성인식', '음성합성', '자연어', '처리', '필기', '인식', '등', '솔루션', '제', '공', '셀', '바스', '의', '음성', '기술', '주목', '각', '도메', '인별', '데이터', '학습', '통해', '제목', '신규', '공개', '내용', '향상', '처리', '능력', '이전', '세대', '의', '폼팩터', '및', '핀', '대한', '개발자', '자연어', '이해', '인식', '멀티', '센서', '퓨전', '등', '관련', '엣지', '제목', '메타', '버스', '관련', '주로', '셀', '바스', '성공', '내용', '영상', '지능', '자연어', '처리', '등', '기술', '경쟁력', '재벌', '투자', '연구소', '전문가', '주식', '후기', '가장', '수익', '이야기', '제목', '뉴스레터', '주', '넷플릭스', '게임', '내용', '대표', '신약', '개발', '배터리', '성능', '개선', '날씨', '예측', '주식', '선별', '양자', '자연어', '처리', '이동', '경로', '최적화', '교통', '관리', '데이터', '보호', '등', '생활', '기술', '양자', '컴퓨터', '제목', '자바', '공부', '자바', '알고리즘', '무엇', '내용', '컴퓨터', '무엇', '처리', '내용', '처리', '순서', '모두', '구체', '알고리즘', '자연어', '의사코드', '순서도', '프로그래밍', '언어', '등', '표현', '제목', '파이썬', '수', '권', '머신', '내용', '심층', '신경망', '처리', '자연어', '처리', '편미분', '방정식', '추상화', '이미지', '주요', '역할', '데이터', '조작', '및', '분석', '자연어', '툴킷', '의', '제목', '황정리', '프로', '내용', '자연어', '처리', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '애플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝', '제목', '월', '수원', '삼성', '전기', '인공', '지능', '챗봇', '트레이너', '내용', '자체', '개발', '자연어', '처리', '기술', '머신', '러닝', '텍스트', '마', '이닝', '의미', '분석', '및', '검색', '등', '복합', '융합', '인공', '지능', '기반', '하이브리드', '챗봇', '솔루션', '제목', '영상', '전상호', '코어', '에이', '아이', '상무', '대화', '내용', '인지', '검색', '제목', '빅', '데이터', '란', '특징', '의미', '내용', '학습', '자연어', '처리', '패턴', '인식', '등', '분석', '기법', '해당', '복잡', '데이터', '구조', '데이터', '획득', '처리', '속도', '도메인', '규칙', '저장', '타입', '등', '제목', '개발', '유닛', '무하', '유의', '서비스', '서비스', '내용', '민', '프로', '저', '자연어', '이해', '기술', '기업', '무하', '유', '회사', '슬로건', '보고', '서비스', '문장', '처리', '기술', '기술', '적용', '경험', '수', '제목', '임', '리치', '비트코인', '총', '달러', '근접', '급등', '내용', '예산', '법안', '처리', '것', '증시', '호재', '작용', '폭', '상승', '마감', '추출', '자연어', '처리', '방식', '실시', '비트코인', '단어', '대한', '제목', '프로', '티비', '월', '모닝', '라이브', '오늘아침', '라이브', '내용', '대화', '자연어', '처리', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '어플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝', '제목', '공식', '움', '원자폭탄', '비트코인', '세상', '내용', '제목', '공식', '움', '원자폭탄', '비트코인', '세상', '절대', '공식', '저자', '양자', '학파', '출판', '미디어', '숲', '발매', '저자', '양자', '학파', '양자', '학파', '자연', '과학', '수학', '제목', '의', '전략', '시리즈', '내용', '즉', '인간', '사용', '자연어', '처리', '기술', '언어', '장벽', '허물', '언어', '사용', '누구', '대화', '제목', '검색', '조회', '수가', '단어', '키', '워드', '상위', '노출', '유입', '분석', '내용', '자연어', '처리', '국어', '전자', '순찰', '토카막', '네트워크', '폐기물', '에너지', '변환', '미분방정식', '홍합', '접착', '단백질', '제목', '멀티', '캠퍼스', '인공', '지능', '자연어', '처리', '기반', '기업', '데이터', '분석', '내용', '인공', '지능', '자연어', '처리', '키', '워드', '보고', '바로', '지원', '무엇', '인지도', '상태', '개념', '내용', '블로그', '유튜브', '통해', '공부', '제목', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '내용', '자연어', '처리', '필기', '인식', '등', '솔루션', '제공', '국내', '최고', '음성인식', '률', '보유', '음성합성', '기술', '로', '국내', '위', '쌍', '방향', '커뮤니케이션', '핵심', '기술', '음성', '기술', '제목', '셀', '바스', '주가', '전망', '인공', '지능', '메타', '버스', '음성인식', '관련', '주', '내용', ...

# %%
print('● 데이터 타입 : ', type(okt_nouns_result)) 
print('● shape : ', np.shape(okt_nouns_result))
print("● 리스트에 있는 튜플 개수 : ", len(okt_nouns_result))
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● shape :  (2631,)
# ● 리스트에 있는 튜플 개수 :  2631

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 4. 명사의 빈도수 출력하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# okt.nouns()를 대상으로 Counter()로 명사 빈도수 출력하기
# </span>

# %% [markdown]
# <span style="color: blue">
# ● collections 모듈에서 제공되는 Counter 함수를 사용하여 명사의 빈도수를 출력
# </span>

# %%
from collections import Counter

# %%
#print(okt_nouns_result) #준비된 명사 리스트 확인
print("명사 개수 : ", len(okt_nouns_result))
# Out:
# 명사 개수 :  2631

# %%
#Counter는 from collections import Counter에서 제공되는 함수

okt_nouns_count = Counter(okt_nouns_result)  

print('● 데이터 타입 : ',type(okt_nouns_count))
print('● {명사 : 개수} ',okt_nouns_count)
# Out:
# ● 데이터 타입 :  <class 'collections.Counter'>
# ● {명사 : 개수}  Counter({'처리': 122, '자연어': 106, '내용': 105, '제목': 101, '기술': 66, '등': 39, '지능': 36, '인공': 28, '분석': 28, '데이터': 26, '셀': 22, '바스': 22, '및': 20, '메타': 20, '버스': 20, '음성인식': 19, '인식': 15, '수': 14, '이': 14, '음성합성': 14, '개발': 13, '러닝': 13, '솔루션': 12, '위': 12, '필기': 11, '통해': 11, '기반': 11, '서비스': 11, '를': 11, '활용': 10, '제공': 10, '기업': 10, '관련': 10, '투자': 10, '언어': 10, '딥': 10, '사용': 10, '빅데이터': 10, '모델': 10, '대화': 9, '음성': 9, '것': 9, '문제': 9, '텍스트': 8, '대한': 8, '이해': 8, '영상': 8, '평가': 7, '주식': 7, '자율': 7, '주행': 7, '린지': 6, '학습': 6, '이미지': 6, '컴퓨터': 6, '경쟁력': 6, '가장': 6, '로보틱스': 6, '헬': 6, '스케': 6, '의미': 6, '검색': 6, '키': 6, '로': 6, '중': 6, '정보': 6, '분야': 6, '마인': 6, '랩': 6, '엔비디아': 6, '대회': 6, '프로그램': 5, '상한': 5, '하이': 5, '트론': 5, '회사': 5, '의': 5, '주': 5, '양자': 5, '알고리즘': 5, '주가': 5, '진행': 5, '황': 5, '나': 5, '일정': 5, '연구': 5, '합성': 5, '논문': 5, '사람': 5, '최신': 5, '마': 4, '이닝': 4, '캠퍼스': 4, '문장': 4, '소프트웨어': 4, '갤럭시': 4, '디지털': 4, '응용': 4, '절대': 4, '예측': 4, '관리': 4, '머신': 4, '구축': 4, '챗봇': 4, '복합': 4, '에이': 4, '비트코인': 4, '인간': 4, '마이크로소프트': 4, '도': 4, '과정': 4, '센터': 4, '역량': 4, '소개': 4, '한국어': 4, '말': 4, '대규모': 4, '이용': 4, '연설': 4, '주제': 4, '교육': 4, '차량': 4, '위해': 4, '차': 4, '지역': 3, '모든': 3, '시각': 3, '패스트': 3, '요약': 3, '에스': 3, '부문': 3, '표면처리': 3, '시대': 3, '능력': 3, '대학교': 3, '혜주': 3, '제': 3, '주목': 3, '전문가': 3, '공부': 3, '무엇': 3, '모두': 3, '역할': 3, '프로': 3, '규칙': 3, '보고': 3, '증시': 3, '단어': 3, '공식': 3, '저자': 3, '학파': 3, '수학': 3, '전략': 3, '워드': 3, '국내': 3, '최고': 3, '전망': 3, '중이': 3, '클라우드': 3, '사업': 3, '개': 3, '장': 3, '패키지': 3, '글': 3, '속': 3, '은': 3, '제작': 3, '젠슨': 3, '추천': 3, '현재': 3, '접목': 3, '선': 3, '편': 3, '소셜': 3, '비용': 3, '추가': 3, '그랜드': 3, '수리': 3, '트': 2, '강화': 2, '인사이트': 2, '기법': 2, '문서': 2, '신경망': 2, '비롯': 2, '엠': 2, '배': 2, '상식': 2, '상처리': 2, '네트워크': 2, '설계': 2, '이론': 2, '우리': 2, '공': 2, '각': 2, '공개': 2, '이전': 2, '개발자': 2, '멀티': 2, '재벌': 2, '연구소': 2, '수익': 2, '대표': 2, '최적화': 2, '자바': 2, '구체': 2, '프로그래밍': 2, '파이썬': 2, '권': 2, '주요': 2, '애플리케이션': 2, '공장': 2, '도시': 2, '트윈': 2, '월': 2, '자체': 2, '융합': 2, '아이': 2, '인지': 2, '빅': 2, '란': 2, '패턴': 2, '해당': 2, '구조': 2, '도메인': 2, '무하': 2, '유': 2, '적용': 2, '총': 2, '급등': 2, '폭': 2, '상승': 2, '추출': 2, '모닝': 2, '라이브': 2, '움': 2, '원자폭탄': 2, '세상': 2, '숲': 2, '과학': 2, '즉': 2, '에너지': 2, '상태': 2, '쌍': 2, '방향': 2, '커뮤니케이션': 2, '핵심': 2, '자': 2, '계속': 2, '자신': 2, '경우': 2, '그': 2, '별': 2, '이상': 2, '방법': 2, '감소': 2, '상황': 2, '경북': 2, '크롤': 2, '링': 2, '심화': 2, '통계': 2, '화': 2, '코스닥': 2, '테크': 2, '절단': 2, '가공': 2, '조선': 2, '영위': 2, '부분': 2, '의존': 2, '처음': 2, '하나로': 2, '산업': 2, '해결': 2, '코스': 2, '소통': 2, '지속': 2, '알': 2, '플랫폼': 2, '비': 2, '이재명': 2, '후보': 2, '양성': 2, '미니': 2, '프로젝트': 2, '그냥': 2, '의견': 2, '자동': 2, '콘텐츠': 2, '구글': 2, '번역': 2, '기': 2, '반도체': 2, '텐센트': 2, '기능': 2, '예정': 2, '기계번역': 2, '매일': 2, '네이버': 2, '확보': 2, '또': 2, '어르신': 2, '영어': 2, '지문': 2, '아바타': 2, '인류': 2, '역사상': 2, '라이선스': 2, '독점': 2, '개요': 2, '스타트업': 2, '글로벌': 2, '정리': 2, '포스팅': 2, '이번': 2, '모주': 2, '발전': 2, '비즈니스': 2, '제품': 2, '표': 2, '하나': 2, '중요성': 2, '증가': 2, '주차': 2, '자료구조': 2, '코드': 2, '이용자': 2, '생각': 2, '카카오': 2, '생명': 2, '답변': 2, '캠프': 2, '크루즈': 2, '웨이': 2, '모': 2, '왜': 2, '형태소': 2, '설치': 2, '정함': 2, '엔터프라이즈': 2, '스마트': 2, '준': 2, '기구': 2, '단계': 2, '사고': 2, '추론': 2, '완화': 2, '묘사': 2, '도형': 2, '이해관계자': 2, '친': 2, '적': 2, '행동': 2, '통운': 2, '시스템': 2, '콴다': 2, '링크': 1, '관광': 1, '해답': 1, '제시': 1, '담당자': 1, '자료': 1, '수요일': 1, '인재': 1, '직접': 1, '컴공': 1, '전산': 1, '서울': 1, '대졸': 1, '추월': 1, '법률': 1, '처리장치': 1, '해선': 1, '컴퓨터공학': 1, '건축': 1, '용': 1, '자재': 1, '제조': 1, '데크': 1, '플레이': 1, '선용': 1, '철판': 1, '자아': 1, '도약': 1, '일각': 1, '탄생': 1, '또한': 1, '일반': 1, '객관': 1, '전공': 1, '중앙': 1, '학부': 1, '학년': 1, '캡': 1, '스톤': 1, '디자인': 1, '멀티코어': 1, '컴퓨팅': 1, '무선': 1, '이동통신': 1, '정보보호': 1, '생체인식': 1, '정보검색': 1, '패턴인식': 1, '도메': 1, '인별': 1, '신규': 1, '향상': 1, '세대': 1, '폼팩터': 1, '핀': 1, '센서': 1, '퓨전': 1, '엣지': 1, '주로': 1, '성공': 1, '후기': 1, '이야기': 1, '뉴스레터': 1, '넷플릭스': 1, '게임': 1, '신약': 1, '배터리': 1, '성능': 1, '개선': 1, '날씨': 1, '선별': 1, '이동': 1 ...

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 5. 불용어 사전을 이용한 불필요한 명사 제거하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어 사전을 read()로 읽기 (return type : string)
# </span>

# %%
stop_word = open("불용어사전.txt", encoding='utf-8').read()
print('● 불용어 사전 데이터 타입 : ',type(stop_word))
print('● 불용어 사전 내용 ')  
print(stop_word)  #print()를 사용하면 '\n'이 출력되지 않는다.
# Out:
# ● 불용어 사전 데이터 타입 :  <class 'str'>
# ● 불용어 사전 내용
# 자연어
# 처리
# 제목
# 내용

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어 사전을 기반으로 저장된 명사 데이터셋에서 불용어 제거하기
# </span>

# %% [markdown]
# <span style="color:green">
# ● 파이썬 문법 참고 <br>
# </span>

# %%
#파이썬 문법 참고
#0 에서 9까지 1씩 증가하면서
#x를 2로 나누어서 나머지가 0 인 경우.. 
#즉 짝수인 경우 x만 M에 할당하는 코드 

M = [x for x in range(10) if x % 2 == 0]
print(M)
# Out:
# [0, 2, 4, 6, 8]

# %%
#print("● okt.nouns()를 활용하여 추출된 명사 : %d 개" %len(okt_nouns))
#print(okt_nouns,'\n')

# %%
stop_okt = [ i for i in okt_nouns_result if i in stop_word ] 
          #i가 stop_word에 있으면 i를 stop_okt에 할당한다. 
          #stop_word는 \n 단위로 비교된다.
print("● 추출된 명사가 불용어에 해당되는 명사 : %d 개" %len(stop_okt))
print(stop_okt,'\n')
# Out:
# ● 추출된 명사가 불용어에 해당되는 명사 : 443 개
# ['제목', '내용', '자연어', '처리', '제목', '내용', '제목', '내용', '자연어', '처리', '내용', '제목', '내용', '자연어', '처리', '용', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제', '제목', '내용', '처리', '자연어', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '내용', '처리', '자연어', '제목', '내용', '처리', '자연어', '처리', '자연어', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '제목', '내용', '자연어', '처리', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '제목', '자연', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '자연어', '처리', '내용', '자연어', '처리', '내용', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '자', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '내', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자', '자연어', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '처리', '제목', '내용', '제목', '내용', '자연어', '처리', '처리', '제목', '내용', '자연어', '처리', '자연어', '제목', '내용', '자연어', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '제', '내용', '제목', '내용', '자연어', '처리', '제', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '처리', '제목', '내용', '처리', '자연어', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '처리', '제목', '내용', '자연어', '처리', '내용', '자연어', '제목', '내용', '자연어', '처리', '제목', '내용', '처리', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '처리', '제목', '자연어', '처리', '자연어', '처리', '내용', '처리', '자연어', '처리', '제목', '자연어', '처리', '내용', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '자연어', '자연어', '처리', '제목', '내용', '자연어', '처리', '제목', '내용', '제목', '연', '내용', '자연어', '자연어', '처리']

# %%
non_stop_okt = [ j for j in okt_nouns_result if j not in stop_word ] 
         #j가 stop_word(불용어)에 없으면 j를 non_stop_okt에 할당한다. 
         #stop_word는 \n 단위로 비교된다.
print("● 추출된 명사가 불용어에 해당되지 않는 명사 : %d 개" %len(non_stop_okt))
print(non_stop_okt)
# Out:
# ● 추출된 명사가 불용어에 해당되지 않는 명사 : 2188 개
# ['트', '링크', '지역', '관광', '솔루션', '텍스트', '마', '이닝', '대화', '기술', '강화', '인공', '지능', '해답', '제시', '모든', '담당자', '인사이트', '활용', '수', '시각', '자료', '제공', '패스트', '캠퍼스', '린지', '수요일', '기업', '인재', '직접', '컴공', '전산', '서울', '대졸', '추월', '이', '프로그램', '기법', '활용', '법률', '문서', '요약', '문장', '신경망', '처리장치', '개발', '위', '해선', '컴퓨터공학', '비롯', '소프트웨어', '대한', '상한', '갤럭시', '에스', '엠', '셀', '바스', '하이', '트론', '음성인식', '음성합성', '필기', '인식', '등', '솔루션', '제공', '이', '회사', '건축', '자재', '제조', '데크', '플레이', '트', '부문', '선용', '철판', '표면처리', '인공', '지능', '인공', '자아', '시대', '도약', '일각', '배', '학습', '능력', '인공', '지능', '탄생', '또한', '일반', '상식', '대한', '이미지', '상식', '객관', '디지털', '시대', '전공', '중앙', '대학교', '소프트웨어', '학부', '상처리', '학년', '캡', '스톤', '디자인', '멀티코어', '컴퓨팅', '무선', '이동통신', '네트워크', '응용', '설계', '정보보호', '이론', '생체인식', '및', '응용', '및', '정보검색', '패턴인식', '컴퓨터', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '평가', '음성인식', '음성합성', '필기', '인식', '등', '솔루션', '공', '셀', '바스', '의', '음성', '기술', '주목', '각', '도메', '인별', '데이터', '학습', '통해', '신규', '공개', '향상', '능력', '이전', '세대', '의', '폼팩터', '및', '핀', '대한', '개발자', '이해', '인식', '멀티', '센서', '퓨전', '등', '관련', '엣지', '메타', '버스', '관련', '주로', '셀', '바스', '성공', '영상', '지능', '등', '기술', '경쟁력', '재벌', '투자', '연구소', '전문가', '주식', '후기', '가장', '수익', '이야기', '뉴스레터', '주', '넷플릭스', '게임', '대표', '신약', '개발', '배터리', '성능', '개선', '날씨', '예측', '주식', '선별', '양자', '이동', '경로', '최적화', '교통', '관리', '데이터', '보호', '등', '생활', '기술', '양자', '컴퓨터', '자바', '공부', '자바', '알고리즘', '무엇', '컴퓨터', '무엇', '순서', '모두', '구체', '알고리즘', '의사코드', '순서도', '프로그래밍', '언어', '등', '표현', '파이썬', '수', '권', '머신', '심층', '신경망', '편미분', '방정식', '추상화', '이미지', '주요', '역할', '데이터', '조작', '및', '분석', '툴킷', '의', '황정리', '프로', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '애플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝', '월', '수원', '삼성', '전기', '인공', '지능', '챗봇', '트레이너', '자체', '개발', '기술', '머신', '러닝', '텍스트', '마', '이닝', '의미', '분석', '및', '검색', '등', '복합', '융합', '인공', '지능', '기반', '하이브리드', '챗봇', '솔루션', '영상', '전상호', '코어', '에이', '아이', '상무', '대화', '인지', '검색', '빅', '데이터', '란', '특징', '의미', '학습', '패턴', '인식', '등', '분석', '기법', '해당', '복잡', '데이터', '구조', '데이터', '획득', '속도', '도메인', '규칙', '저장', '타입', '등', '개발', '유닛', '무하', '유의', '서비스', '서비스', '민', '프로', '저', '이해', '기술', '기업', '무하', '유', '회사', '슬로건', '보고', '서비스', '문장', '기술', '기술', '적용', '경험', '수', '임', '리치', '비트코인', '총', '달러', '근접', '급등', '예산', '법안', '것', '증시', '호재', '작용', '폭', '상승', '마감', '추출', '방식', '실시', '비트코인', '단어', '대한', '프로', '티비', '월', '모닝', '라이브', '오늘아침', '라이브', '대화', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '어플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝', '공식', '움', '원자폭탄', '비트코인', '세상', '공식', '움', '원자폭탄', '비트코인', '세상', '절대', '공식', '저자', '양자', '학파', '출판', '미디어', '숲', '발매', '저자', '양자', '학파', '양자', '학파', '과학', '수학', '의', '전략', '시리즈', '즉', '인간', '사용', '기술', '언어', '장벽', '허물', '언어', '사용', '누구', '대화', '검색', '조회', '수가', '단어', '키', '워드', '상위', '노출', '유입', '분석', '국어', '전자', '순찰', '토카막', '네트워크', '폐기물', '에너지', '변환', '미분방정식', '홍합', '접착', '단백질', '멀티', '캠퍼스', '인공', '지능', '기반', '기업', '데이터', '분석', '인공', '지능', '키', '워드', '보고', '바로', '지원', '무엇', '인지도', '상태', '개념', '블로그', '유튜브', '통해', '공부', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '필기', '인식', '등', '솔루션', '제공', '국내', '최고', '음성인식', '률', '보유', '음성합성', '기술', '로', '국내', '위', '쌍', '방향', '커뮤니케이션', '핵심', '기술', '음성', '기술', '셀', '바스', '주가', '전망', '인공', '지능', '메타', '버스', '음성인식', '관련', '주', '영상', '지능', '등', '기술', '경쟁력', '가오', '음성합성', '마우스', '키', '보드', '등', '전통', '컴퓨터', '입력장치', '음성인식', '음성합성', '딥', '러닝', '중이', '문제', '단기간', '계속', '효율', '자신', '싸움', '나무', '보고', '숲', '경우', '내년', '이', '마이크로소프트', '도', '메타', '버스', '합류', '그', '대한', '완벽', '분석', '존', '최대', '프로그램', '를', '클라우드', '기반', '제공', '즉', '애저', '사용', '고객', '서비스', '로그', '상의', '공통', '불만', '사항', '셀', '바스', '주가', '메타', '버스', '혜주', '대감', '상한', '음성합성', '필기', '인식', '등', '솔루션', '제공', '음성', '기술', '주목', '각', '도메인', '별', '데이터', '학습', '통해', '이상', '국내', '최고', '음성', '최강', '수업', '방법', '볼', '수', '차원', '감소', '위', '주성분', '분석', '상황', '단어', '역할', '의미', '의미', '전달', '것', '경북', '대학교', '데이터', '융합', '연구원', '고용노동부', '데이터' ...

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 6. 글자 수 제한으로 불용어 제거 추가하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어 사전을 통과한 okt.nouns()를 대상으로 글자 수 제한으로 불용어 제거하기
# </span>

# %%
print("● 불용어 사전을 통과한 명사 개수 : %d 개" %len(non_stop_okt))
print("● 불용어 사전을 통과한 명사" )
print(non_stop_okt)
# Out:
# ● 불용어 사전을 통과한 명사 개수 : 2188 개
# ● 불용어 사전을 통과한 명사
# ['트', '링크', '지역', '관광', '솔루션', '텍스트', '마', '이닝', '대화', '기술', '강화', '인공', '지능', '해답', '제시', '모든', '담당자', '인사이트', '활용', '수', '시각', '자료', '제공', '패스트', '캠퍼스', '린지', '수요일', '기업', '인재', '직접', '컴공', '전산', '서울', '대졸', '추월', '이', '프로그램', '기법', '활용', '법률', '문서', '요약', '문장', '신경망', '처리장치', '개발', '위', '해선', '컴퓨터공학', '비롯', '소프트웨어', '대한', '상한', '갤럭시', '에스', '엠', '셀', '바스', '하이', '트론', '음성인식', '음성합성', '필기', '인식', '등', '솔루션', '제공', '이', '회사', '건축', '자재', '제조', '데크', '플레이', '트', '부문', '선용', '철판', '표면처리', '인공', '지능', '인공', '자아', '시대', '도약', '일각', '배', '학습', '능력', '인공', '지능', '탄생', '또한', '일반', '상식', '대한', '이미지', '상식', '객관', '디지털', '시대', '전공', '중앙', '대학교', '소프트웨어', '학부', '상처리', '학년', '캡', '스톤', '디자인', '멀티코어', '컴퓨팅', '무선', '이동통신', '네트워크', '응용', '설계', '정보보호', '이론', '생체인식', '및', '응용', '및', '정보검색', '패턴인식', '컴퓨터', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '평가', '음성인식', '음성합성', '필기', '인식', '등', '솔루션', '공', '셀', '바스', '의', '음성', '기술', '주목', '각', '도메', '인별', '데이터', '학습', '통해', '신규', '공개', '향상', '능력', '이전', '세대', '의', '폼팩터', '및', '핀', '대한', '개발자', '이해', '인식', '멀티', '센서', '퓨전', '등', '관련', '엣지', '메타', '버스', '관련', '주로', '셀', '바스', '성공', '영상', '지능', '등', '기술', '경쟁력', '재벌', '투자', '연구소', '전문가', '주식', '후기', '가장', '수익', '이야기', '뉴스레터', '주', '넷플릭스', '게임', '대표', '신약', '개발', '배터리', '성능', '개선', '날씨', '예측', '주식', '선별', '양자', '이동', '경로', '최적화', '교통', '관리', '데이터', '보호', '등', '생활', '기술', '양자', '컴퓨터', '자바', '공부', '자바', '알고리즘', '무엇', '컴퓨터', '무엇', '순서', '모두', '구체', '알고리즘', '의사코드', '순서도', '프로그래밍', '언어', '등', '표현', '파이썬', '수', '권', '머신', '심층', '신경망', '편미분', '방정식', '추상화', '이미지', '주요', '역할', '데이터', '조작', '및', '분석', '툴킷', '의', '황정리', '프로', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '애플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝', '월', '수원', '삼성', '전기', '인공', '지능', '챗봇', '트레이너', '자체', '개발', '기술', '머신', '러닝', '텍스트', '마', '이닝', '의미', '분석', '및', '검색', '등', '복합', '융합', '인공', '지능', '기반', '하이브리드', '챗봇', '솔루션', '영상', '전상호', '코어', '에이', '아이', '상무', '대화', '인지', '검색', '빅', '데이터', '란', '특징', '의미', '학습', '패턴', '인식', '등', '분석', '기법', '해당', '복잡', '데이터', '구조', '데이터', '획득', '속도', '도메인', '규칙', '저장', '타입', '등', '개발', '유닛', '무하', '유의', '서비스', '서비스', '민', '프로', '저', '이해', '기술', '기업', '무하', '유', '회사', '슬로건', '보고', '서비스', '문장', '기술', '기술', '적용', '경험', '수', '임', '리치', '비트코인', '총', '달러', '근접', '급등', '예산', '법안', '것', '증시', '호재', '작용', '폭', '상승', '마감', '추출', '방식', '실시', '비트코인', '단어', '대한', '프로', '티비', '월', '모닝', '라이브', '오늘아침', '라이브', '대화', '기술', '로보틱스', '헬', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '위', '어플리케이션', '공장', '도시', '및', '지역', '디지털', '트윈', '구축', '딥', '러닝', '공식', '움', '원자폭탄', '비트코인', '세상', '공식', '움', '원자폭탄', '비트코인', '세상', '절대', '공식', '저자', '양자', '학파', '출판', '미디어', '숲', '발매', '저자', '양자', '학파', '양자', '학파', '과학', '수학', '의', '전략', '시리즈', '즉', '인간', '사용', '기술', '언어', '장벽', '허물', '언어', '사용', '누구', '대화', '검색', '조회', '수가', '단어', '키', '워드', '상위', '노출', '유입', '분석', '국어', '전자', '순찰', '토카막', '네트워크', '폐기물', '에너지', '변환', '미분방정식', '홍합', '접착', '단백질', '멀티', '캠퍼스', '인공', '지능', '기반', '기업', '데이터', '분석', '인공', '지능', '키', '워드', '보고', '바로', '지원', '무엇', '인지도', '상태', '개념', '블로그', '유튜브', '통해', '공부', '셀', '바스', '우리', '메타', '버스', '혜주', '절대', '필기', '인식', '등', '솔루션', '제공', '국내', '최고', '음성인식', '률', '보유', '음성합성', '기술', '로', '국내', '위', '쌍', '방향', '커뮤니케이션', '핵심', '기술', '음성', '기술', '셀', '바스', '주가', '전망', '인공', '지능', '메타', '버스', '음성인식', '관련', '주', '영상', '지능', '등', '기술', '경쟁력', '가오', '음성합성', '마우스', '키', '보드', '등', '전통', '컴퓨터', '입력장치', '음성인식', '음성합성', '딥', '러닝', '중이', '문제', '단기간', '계속', '효율', '자신', '싸움', '나무', '보고', '숲', '경우', '내년', '이', '마이크로소프트', '도', '메타', '버스', '합류', '그', '대한', '완벽', '분석', '존', '최대', '프로그램', '를', '클라우드', '기반', '제공', '즉', '애저', '사용', '고객', '서비스', '로그', '상의', '공통', '불만', '사항', '셀', '바스', '주가', '메타', '버스', '혜주', '대감', '상한', '음성합성', '필기', '인식', '등', '솔루션', '제공', '음성', '기술', '주목', '각', '도메인', '별', '데이터', '학습', '통해', '이상', '국내', '최고', '음성', '최강', '수업', '방법', '볼', '수', '차원', '감소', '위', '주성분', '분석', '상황', '단어', '역할', '의미', '의미', '전달', '것', '경북', '대학교', '데이터', '융합', '연구원', '고용노동부', '데이터' ...

# %%
refine_non_stop_okt = []

for i in non_stop_okt :  
    #글자수가 2자 ~ 10자에 해당되는 단어만 추출
    if len(i) >= 2 and len(i) <= 10 : 
        refine_non_stop_okt.append(i) 
        
print("● 글자 수가 2~10 사이 명사 : %d 개" %len(refine_non_stop_okt))    
print(refine_non_stop_okt)
# Out:
# ● 글자 수가 2~10 사이 명사 : 1828 개
# ['링크', '지역', '관광', '솔루션', '텍스트', '이닝', '대화', '기술', '강화', '인공', '지능', '해답', '제시', '모든', '담당자', '인사이트', '활용', '시각', '자료', '제공', '패스트', '캠퍼스', '린지', '수요일', '기업', '인재', '직접', '컴공', '전산', '서울', '대졸', '추월', '프로그램', '기법', '활용', '법률', '문서', '요약', '문장', '신경망', '처리장치', '개발', '해선', '컴퓨터공학', '비롯', '소프트웨어', '대한', '상한', '갤럭시', '에스', '바스', '하이', '트론', '음성인식', '음성합성', '필기', '인식', '솔루션', '제공', '회사', '건축', '자재', '제조', '데크', '플레이', '부문', '선용', '철판', '표면처리', '인공', '지능', '인공', '자아', '시대', '도약', '일각', '학습', '능력', '인공', '지능', '탄생', '또한', '일반', '상식', '대한', '이미지', '상식', '객관', '디지털', '시대', '전공', '중앙', '대학교', '소프트웨어', '학부', '상처리', '학년', '스톤', '디자인', '멀티코어', '컴퓨팅', '무선', '이동통신', '네트워크', '응용', '설계', '정보보호', '이론', '생체인식', '응용', '정보검색', '패턴인식', '컴퓨터', '바스', '우리', '메타', '버스', '혜주', '절대', '평가', '음성인식', '음성합성', '필기', '인식', '솔루션', '바스', '음성', '기술', '주목', '도메', '인별', '데이터', '학습', '통해', '신규', '공개', '향상', '능력', '이전', '세대', '폼팩터', '대한', '개발자', '이해', '인식', '멀티', '센서', '퓨전', '관련', '엣지', '메타', '버스', '관련', '주로', '바스', '성공', '영상', '지능', '기술', '경쟁력', '재벌', '투자', '연구소', '전문가', '주식', '후기', '가장', '수익', '이야기', '뉴스레터', '넷플릭스', '게임', '대표', '신약', '개발', '배터리', '성능', '개선', '날씨', '예측', '주식', '선별', '양자', '이동', '경로', '최적화', '교통', '관리', '데이터', '보호', '생활', '기술', '양자', '컴퓨터', '자바', '공부', '자바', '알고리즘', '무엇', '컴퓨터', '무엇', '순서', '모두', '구체', '알고리즘', '의사코드', '순서도', '프로그래밍', '언어', '표현', '파이썬', '머신', '심층', '신경망', '편미분', '방정식', '추상화', '이미지', '주요', '역할', '데이터', '조작', '분석', '툴킷', '황정리', '프로', '기술', '로보틱스', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '애플리케이션', '공장', '도시', '지역', '디지털', '트윈', '구축', '러닝', '수원', '삼성', '전기', '인공', '지능', '챗봇', '트레이너', '자체', '개발', '기술', '머신', '러닝', '텍스트', '이닝', '의미', '분석', '검색', '복합', '융합', '인공', '지능', '기반', '하이브리드', '챗봇', '솔루션', '영상', '전상호', '코어', '에이', '아이', '상무', '대화', '인지', '검색', '데이터', '특징', '의미', '학습', '패턴', '인식', '분석', '기법', '해당', '복잡', '데이터', '구조', '데이터', '획득', '속도', '도메인', '규칙', '저장', '타입', '개발', '유닛', '무하', '유의', '서비스', '서비스', '프로', '이해', '기술', '기업', '무하', '회사', '슬로건', '보고', '서비스', '문장', '기술', '기술', '적용', '경험', '리치', '비트코인', '달러', '근접', '급등', '예산', '법안', '증시', '호재', '작용', '상승', '마감', '추출', '방식', '실시', '비트코인', '단어', '대한', '프로', '티비', '모닝', '라이브', '오늘아침', '라이브', '대화', '기술', '로보틱스', '스케', '자율', '주행', '관련', '기술', '메타', '버스', '어플리케이션', '공장', '도시', '지역', '디지털', '트윈', '구축', '러닝', '공식', '원자폭탄', '비트코인', '세상', '공식', '원자폭탄', '비트코인', '세상', '절대', '공식', '저자', '양자', '학파', '출판', '미디어', '발매', '저자', '양자', '학파', '양자', '학파', '과학', '수학', '전략', '시리즈', '인간', '사용', '기술', '언어', '장벽', '허물', '언어', '사용', '누구', '대화', '검색', '조회', '수가', '단어', '워드', '상위', '노출', '유입', '분석', '국어', '전자', '순찰', '토카막', '네트워크', '폐기물', '에너지', '변환', '미분방정식', '홍합', '접착', '단백질', '멀티', '캠퍼스', '인공', '지능', '기반', '기업', '데이터', '분석', '인공', '지능', '워드', '보고', '바로', '지원', '무엇', '인지도', '상태', '개념', '블로그', '유튜브', '통해', '공부', '바스', '우리', '메타', '버스', '혜주', '절대', '필기', '인식', '솔루션', '제공', '국내', '최고', '음성인식', '보유', '음성합성', '기술', '국내', '방향', '커뮤니케이션', '핵심', '기술', '음성', '기술', '바스', '주가', '전망', '인공', '지능', '메타', '버스', '음성인식', '관련', '영상', '지능', '기술', '경쟁력', '가오', '음성합성', '마우스', '보드', '전통', '컴퓨터', '입력장치', '음성인식', '음성합성', '러닝', '중이', '문제', '단기간', '계속', '효율', '자신', '싸움', '나무', '보고', '경우', '내년', '마이크로소프트', '메타', '버스', '합류', '대한', '완벽', '분석', '최대', '프로그램', '클라우드', '기반', '제공', '애저', '사용', '고객', '서비스', '로그', '상의', '공통', '불만', '사항', '바스', '주가', '메타', '버스', '혜주', '대감', '상한', '음성합성', '필기', '인식', '솔루션', '제공', '음성', '기술', '주목', '도메인', '데이터', '학습', '통해', '이상', '국내', '최고', '음성', '최강', '수업', '방법', '차원', '감소', '주성분', '분석', '상황', '단어', '역할', '의미', '의미', '전달', '경북', '대학교', '데이터', '융합', '연구원', '고용노동부', '데이터', '라이브러리', '데이터', '크롤', '정제', '진행', '심화', '과정', '동안', '빅데이터', '통계', '기본', '데이터', '분석', '주식', '코스닥', '상한', '화요일', '주식', '지수', '모두', '상승', '보합', '코스피', '하락', '중이', '코스닥', '아진산업', '하이', '트론', '테크', '노스', '바스', '표면처리', '절단', '가공', '조선', '부문', '사업', '영위', '필기', '인식', '솔루션', '제공', '음성', '기술', '프로그래밍', '언어', '간추린', '역사', '상당', '부분', '의존', '포트란', '데이터', '설계', '코볼', '처음', '등장', '가장', '널리', '사용', '프로그램', '언어', '하나로', '이상', '언어', '컨택', '센터', '인지', '검색', '상한', '갤럭시',  ...

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 7. 불용어가 제거된 명사를 대상으로 빈도수 다시 출력하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어가 제거된 okt.nouns()를 대상으로 명사의 빈도수 출력하기
# </span>

# %%
#Counter는 from collections import Counter에서 제공되는 함수

re_okt_nouns_count = Counter(refine_non_stop_okt)  

#collections.Counter타입은 딕셔너리의 value를 기준으로 내림차순 정렬
print('● 데이터 타입 : ',type(re_okt_nouns_count))
print('● {명사 : 개수} ',re_okt_nouns_count)
# Out:
# ● 데이터 타입 :  <class 'collections.Counter'>
# ● {명사 : 개수}  Counter({'기술': 66, '지능': 36, '인공': 28, '분석': 28, '데이터': 26, '바스': 22, '메타': 20, '버스': 20, '음성인식': 19, '인식': 15, '음성합성': 14, '개발': 13, '러닝': 13, '솔루션': 12, '필기': 11, '통해': 11, '기반': 11, '서비스': 11, '활용': 10, '제공': 10, '기업': 10, '관련': 10, '투자': 10, '언어': 10, '사용': 10, '빅데이터': 10, '모델': 10, '대화': 9, '음성': 9, '문제': 9, '텍스트': 8, '대한': 8, '이해': 8, '영상': 8, '평가': 7, '주식': 7, '자율': 7, '주행': 7, '린지': 6, '학습': 6, '이미지': 6, '컴퓨터': 6, '경쟁력': 6, '가장': 6, '로보틱스': 6, '스케': 6, '의미': 6, '검색': 6, '정보': 6, '분야': 6, '마인': 6, '엔비디아': 6, '대회': 6, '프로그램': 5, '상한': 5, '하이': 5, '트론': 5, '회사': 5, '양자': 5, '알고리즘': 5, '주가': 5, '진행': 5, '일정': 5, '연구': 5, '합성': 5, '논문': 5, '사람': 5, '최신': 5, '이닝': 4, '캠퍼스': 4, '문장': 4, '소프트웨어': 4, '갤럭시': 4, '디지털': 4, '응용': 4, '절대': 4, '예측': 4, '관리': 4, '머신': 4, '구축': 4, '챗봇': 4, '복합': 4, '에이': 4, '비트코인': 4, '인간': 4, '마이크로소프트': 4, '과정': 4, '센터': 4, '역량': 4, '소개': 4, '한국어': 4, '대규모': 4, '이용': 4, '연설': 4, '주제': 4, '교육': 4, '차량': 4, '위해': 4, '지역': 3, '모든': 3, '시각': 3, '패스트': 3, '요약': 3, '에스': 3, '부문': 3, '표면처리': 3, '시대': 3, '능력': 3, '대학교': 3, '혜주': 3, '주목': 3, '전문가': 3, '공부': 3, '무엇': 3, '모두': 3, '역할': 3, '프로': 3, '규칙': 3, '보고': 3, '증시': 3, '단어': 3, '공식': 3, '저자': 3, '학파': 3, '수학': 3, '전략': 3, '워드': 3, '국내': 3, '최고': 3, '전망': 3, '중이': 3, '클라우드': 3, '사업': 3, '패키지': 3, '제작': 3, '젠슨': 3, '추천': 3, '현재': 3, '접목': 3, '소셜': 3, '비용': 3, '추가': 3, '그랜드': 3, '수리': 3, '강화': 2, '인사이트': 2, '기법': 2, '문서': 2, '신경망': 2, '비롯': 2, '상식': 2, '상처리': 2, '네트워크': 2, '설계': 2, '이론': 2, '우리': 2, '공개': 2, '이전': 2, '개발자': 2, '멀티': 2, '재벌': 2, '연구소': 2, '수익': 2, '대표': 2, '최적화': 2, '자바': 2, '구체': 2, '프로그래밍': 2, '파이썬': 2, '주요': 2, '애플리케이션': 2, '공장': 2, '도시': 2, '트윈': 2, '자체': 2, '융합': 2, '아이': 2, '인지': 2, '패턴': 2, '해당': 2, '구조': 2, '도메인': 2, '무하': 2, '적용': 2, '급등': 2, '상승': 2, '추출': 2, '모닝': 2, '라이브': 2, '원자폭탄': 2, '세상': 2, '과학': 2, '에너지': 2, '상태': 2, '방향': 2, '커뮤니케이션': 2, '핵심': 2, '계속': 2, '자신': 2, '경우': 2, '이상': 2, '방법': 2, '감소': 2, '상황': 2, '경북': 2, '크롤': 2, '심화': 2, '통계': 2, '코스닥': 2, '테크': 2, '절단': 2, '가공': 2, '조선': 2, '영위': 2, '부분': 2, '의존': 2, '처음': 2, '하나로': 2, '산업': 2, '해결': 2, '코스': 2, '소통': 2, '지속': 2, '플랫폼': 2, '이재명': 2, '후보': 2, '양성': 2, '미니': 2, '프로젝트': 2, '그냥': 2, '의견': 2, '자동': 2, '콘텐츠': 2, '구글': 2, '번역': 2, '반도체': 2, '텐센트': 2, '기능': 2, '예정': 2, '기계번역': 2, '매일': 2, '네이버': 2, '확보': 2, '어르신': 2, '영어': 2, '지문': 2, '아바타': 2, '인류': 2, '역사상': 2, '라이선스': 2, '독점': 2, '개요': 2, '스타트업': 2, '글로벌': 2, '정리': 2, '포스팅': 2, '이번': 2, '모주': 2, '발전': 2, '비즈니스': 2, '제품': 2, '하나': 2, '중요성': 2, '증가': 2, '주차': 2, '자료구조': 2, '코드': 2, '이용자': 2, '생각': 2, '카카오': 2, '생명': 2, '답변': 2, '캠프': 2, '크루즈': 2, '웨이': 2, '형태소': 2, '설치': 2, '정함': 2, '엔터프라이즈': 2, '스마트': 2, '기구': 2, '단계': 2, '사고': 2, '추론': 2, '완화': 2, '묘사': 2, '도형': 2, '이해관계자': 2, '행동': 2, '통운': 2, '시스템': 2, '콴다': 2, '링크': 1, '관광': 1, '해답': 1, '제시': 1, '담당자': 1, '자료': 1, '수요일': 1, '인재': 1, '직접': 1, '컴공': 1, '전산': 1, '서울': 1, '대졸': 1, '추월': 1, '법률': 1, '처리장치': 1, '해선': 1, '컴퓨터공학': 1, '건축': 1, '자재': 1, '제조': 1, '데크': 1, '플레이': 1, '선용': 1, '철판': 1, '자아': 1, '도약': 1, '일각': 1, '탄생': 1, '또한': 1, '일반': 1, '객관': 1, '전공': 1, '중앙': 1, '학부': 1, '학년': 1, '스톤': 1, '디자인': 1, '멀티코어': 1, '컴퓨팅': 1, '무선': 1, '이동통신': 1, '정보보호': 1, '생체인식': 1, '정보검색': 1, '패턴인식': 1, '도메': 1, '인별': 1, '신규': 1, '향상': 1, '세대': 1, '폼팩터': 1, '센서': 1, '퓨전': 1, '엣지': 1, '주로': 1, '성공': 1, '후기': 1, '이야기': 1, '뉴스레터': 1, '넷플릭스': 1, '게임': 1, '신약': 1, '배터리': 1, '성능': 1, '개선': 1, '날씨': 1, '선별': 1, '이동': 1, '경로': 1, '교통': 1, '보호': 1, '생활': 1, '순서': 1, '의사코드': 1, '순서도': 1, '표현': 1, '심층': 1, '편미분': 1, '방정식': 1, '추상화': 1, '조작': 1, '툴킷': 1, '황정리': 1, '수원': 1, '삼성': 1, '전기': 1, '트레이너': 1, '하이브리드': 1, '전상호': 1, '코어': 1, '상무': 1, '특징': 1, '복잡': 1, '획득': 1, '속도': 1, '저장': 1, '타입': 1, '유닛': 1, '유의': 1, '슬로건': 1, '경험': 1, '리치': 1, '달러': 1, '근접': 1, '예산': 1, '법안': 1, '호재': 1, '작용': 1, '마감': 1, '방식': 1, '실시': 1, '티비': 1, '오늘아침': 1, '어플리케이션': 1, '출판': 1, '미디어': 1, '발매': 1, '시리즈': 1, '장벽': 1, '허물': 1, '누구': 1, '조회': 1, '수가': 1, '상위': 1, '노출': 1, '유입': 1, '국어': 1, '전자': 1, ' ...

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 8. 워드 클라우드를 활용하여 명사의 빈도수 시각화
# </span>

# %% [markdown]
# wordcloud 공식 홈페이지
# https://amueller.github.io/word_cloud/index.html

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어가 제거된 okt.nouns()를 대상으로 명사의 빈도수를 워드클라우드로 시각화하기
# </span>

# %% [markdown]
# <span style="color: blue">
# ● WordCloud( )의 generate_from_frequencies( ) 함수 input type 은 dictionary 이고, return type은 image 이다.
# </span>

# %%
from wordcloud import WordCloud  

wc = WordCloud(font_path="c:/windows/fonts/HMFMMUEX.TTC" ,  #폰트 설정
                      relative_scaling='auto',  #워드클라우드에 표현될 글자의 상대적 비율 (max:1, auto : 0.5) 
                      background_color='yellow',  #배경색                       
                     ).generate_from_frequencies(re_okt_nouns_count)  #딕셔너리 데이터의 값을 기반으로 워드클라우드를 생성한다.

# %%
wc

# %%
import matplotlib.pyplot as plt 
#아래의 %matplotlib qt5 코드를 입력하면 시각화 결과가 새로운 윈도우 창에 출력됨
#%matplotlib qt5

# %%
plt.rcParams["figure.figsize"] = (14,4) #가로 너비 14인치, 세로 높이 4인치 
plt.rcParams['axes.grid'] = True   #또는 True
fig = plt.figure() #이미지 크기가 할당됨 
print("이미지 크기 : ", fig)
plt.axis('off') 
plt.imshow(wc)  #위에서 설정한 WordCcloud 옵션에 따른 이미지가 화면에 출력
# Out:
# 이미지 크기 :  Figure(1400x400)

# %%
print(fig)
# Out:
# Figure(1400x400)

# %%
plt.rcParams["figure.figsize"] = (14,4) #가로 너비 14인치, 세로 높이 4인치 
plt.rcParams['axes.grid'] = False    #또는 True

fig = plt.figure() #이미지 크기가 할당됨 
print("이미지 크기 : ", fig)

#plt.axis('on' 또는 'off') : 'on'으로 설정하면 x,y축이 출력된다. 
plt.axis('on') 
plt.imshow(wc)  #위에서 설정한 WordCcloud 옵션에 따른 이미지가 화면에 출력

#출련된 워드클라우드 이미지를 파일로 저장
fig.savefig('./result/자연어처리_주요키워드.png')
# Out:
# 이미지 크기 :  Figure(1400x400)

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 9. 그래프를 활용하여 명사의 빈도수 시각화
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 명사의 빈도수를 그래프로 시각화하기
# </span>

# %%
#그래프 그리기 위해서 필요한 모듈 임포트하기 
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib

# %%
#아래의 %matplotlib qt5 코드를 입력하면 시각화 결과가 새로운 윈도우 창에 출력됨
#%matplotlib qt5 

font_location="c:/windows/fonts/HMFMMUEX.TTC"  #한글 폰트를 셋팅함
font_name=fm.FontProperties(fname=font_location).get_name() 

#한글 깨짐을 방지하기 위해서 반드시 해야할 부분 
matplotlib.rc('font',family=font_name)

# %% [markdown]
# <span style="color:blue">
# ● nltk(Natural Language Took Kit) 모듈을 활용하여 plot 그래프를 출력 <br>
# ● plot(플롯)은 일반적으로 둘 이상의 변수 간의 관계를 나타내는 그래프로 데이터 세트를 나타내는 그래픽 기술
# </span>

# %%
from nltk.probability import FreqDist 

#FreqDist()는 딕셔너리 타입의 데이터를 셋팅해야 함
final_okt_sort_dic_graph = FreqDist(re_okt_nouns_count)

# %%
type(re_okt_nouns_count)
# Out:
# collections.Counter

# %%
type(final_okt_sort_dic_graph)
# Out:
# nltk.probability.FreqDist

# %%
print(re_okt_nouns_count)
# Out:
# Counter({'기술': 66, '지능': 36, '인공': 28, '분석': 28, '데이터': 26, '바스': 22, '메타': 20, '버스': 20, '음성인식': 19, '인식': 15, '음성합성': 14, '개발': 13, '러닝': 13, '솔루션': 12, '필기': 11, '통해': 11, '기반': 11, '서비스': 11, '활용': 10, '제공': 10, '기업': 10, '관련': 10, '투자': 10, '언어': 10, '사용': 10, '빅데이터': 10, '모델': 10, '대화': 9, '음성': 9, '문제': 9, '텍스트': 8, '대한': 8, '이해': 8, '영상': 8, '평가': 7, '주식': 7, '자율': 7, '주행': 7, '린지': 6, '학습': 6, '이미지': 6, '컴퓨터': 6, '경쟁력': 6, '가장': 6, '로보틱스': 6, '스케': 6, '의미': 6, '검색': 6, '정보': 6, '분야': 6, '마인': 6, '엔비디아': 6, '대회': 6, '프로그램': 5, '상한': 5, '하이': 5, '트론': 5, '회사': 5, '양자': 5, '알고리즘': 5, '주가': 5, '진행': 5, '일정': 5, '연구': 5, '합성': 5, '논문': 5, '사람': 5, '최신': 5, '이닝': 4, '캠퍼스': 4, '문장': 4, '소프트웨어': 4, '갤럭시': 4, '디지털': 4, '응용': 4, '절대': 4, '예측': 4, '관리': 4, '머신': 4, '구축': 4, '챗봇': 4, '복합': 4, '에이': 4, '비트코인': 4, '인간': 4, '마이크로소프트': 4, '과정': 4, '센터': 4, '역량': 4, '소개': 4, '한국어': 4, '대규모': 4, '이용': 4, '연설': 4, '주제': 4, '교육': 4, '차량': 4, '위해': 4, '지역': 3, '모든': 3, '시각': 3, '패스트': 3, '요약': 3, '에스': 3, '부문': 3, '표면처리': 3, '시대': 3, '능력': 3, '대학교': 3, '혜주': 3, '주목': 3, '전문가': 3, '공부': 3, '무엇': 3, '모두': 3, '역할': 3, '프로': 3, '규칙': 3, '보고': 3, '증시': 3, '단어': 3, '공식': 3, '저자': 3, '학파': 3, '수학': 3, '전략': 3, '워드': 3, '국내': 3, '최고': 3, '전망': 3, '중이': 3, '클라우드': 3, '사업': 3, '패키지': 3, '제작': 3, '젠슨': 3, '추천': 3, '현재': 3, '접목': 3, '소셜': 3, '비용': 3, '추가': 3, '그랜드': 3, '수리': 3, '강화': 2, '인사이트': 2, '기법': 2, '문서': 2, '신경망': 2, '비롯': 2, '상식': 2, '상처리': 2, '네트워크': 2, '설계': 2, '이론': 2, '우리': 2, '공개': 2, '이전': 2, '개발자': 2, '멀티': 2, '재벌': 2, '연구소': 2, '수익': 2, '대표': 2, '최적화': 2, '자바': 2, '구체': 2, '프로그래밍': 2, '파이썬': 2, '주요': 2, '애플리케이션': 2, '공장': 2, '도시': 2, '트윈': 2, '자체': 2, '융합': 2, '아이': 2, '인지': 2, '패턴': 2, '해당': 2, '구조': 2, '도메인': 2, '무하': 2, '적용': 2, '급등': 2, '상승': 2, '추출': 2, '모닝': 2, '라이브': 2, '원자폭탄': 2, '세상': 2, '과학': 2, '에너지': 2, '상태': 2, '방향': 2, '커뮤니케이션': 2, '핵심': 2, '계속': 2, '자신': 2, '경우': 2, '이상': 2, '방법': 2, '감소': 2, '상황': 2, '경북': 2, '크롤': 2, '심화': 2, '통계': 2, '코스닥': 2, '테크': 2, '절단': 2, '가공': 2, '조선': 2, '영위': 2, '부분': 2, '의존': 2, '처음': 2, '하나로': 2, '산업': 2, '해결': 2, '코스': 2, '소통': 2, '지속': 2, '플랫폼': 2, '이재명': 2, '후보': 2, '양성': 2, '미니': 2, '프로젝트': 2, '그냥': 2, '의견': 2, '자동': 2, '콘텐츠': 2, '구글': 2, '번역': 2, '반도체': 2, '텐센트': 2, '기능': 2, '예정': 2, '기계번역': 2, '매일': 2, '네이버': 2, '확보': 2, '어르신': 2, '영어': 2, '지문': 2, '아바타': 2, '인류': 2, '역사상': 2, '라이선스': 2, '독점': 2, '개요': 2, '스타트업': 2, '글로벌': 2, '정리': 2, '포스팅': 2, '이번': 2, '모주': 2, '발전': 2, '비즈니스': 2, '제품': 2, '하나': 2, '중요성': 2, '증가': 2, '주차': 2, '자료구조': 2, '코드': 2, '이용자': 2, '생각': 2, '카카오': 2, '생명': 2, '답변': 2, '캠프': 2, '크루즈': 2, '웨이': 2, '형태소': 2, '설치': 2, '정함': 2, '엔터프라이즈': 2, '스마트': 2, '기구': 2, '단계': 2, '사고': 2, '추론': 2, '완화': 2, '묘사': 2, '도형': 2, '이해관계자': 2, '행동': 2, '통운': 2, '시스템': 2, '콴다': 2, '링크': 1, '관광': 1, '해답': 1, '제시': 1, '담당자': 1, '자료': 1, '수요일': 1, '인재': 1, '직접': 1, '컴공': 1, '전산': 1, '서울': 1, '대졸': 1, '추월': 1, '법률': 1, '처리장치': 1, '해선': 1, '컴퓨터공학': 1, '건축': 1, '자재': 1, '제조': 1, '데크': 1, '플레이': 1, '선용': 1, '철판': 1, '자아': 1, '도약': 1, '일각': 1, '탄생': 1, '또한': 1, '일반': 1, '객관': 1, '전공': 1, '중앙': 1, '학부': 1, '학년': 1, '스톤': 1, '디자인': 1, '멀티코어': 1, '컴퓨팅': 1, '무선': 1, '이동통신': 1, '정보보호': 1, '생체인식': 1, '정보검색': 1, '패턴인식': 1, '도메': 1, '인별': 1, '신규': 1, '향상': 1, '세대': 1, '폼팩터': 1, '센서': 1, '퓨전': 1, '엣지': 1, '주로': 1, '성공': 1, '후기': 1, '이야기': 1, '뉴스레터': 1, '넷플릭스': 1, '게임': 1, '신약': 1, '배터리': 1, '성능': 1, '개선': 1, '날씨': 1, '선별': 1, '이동': 1, '경로': 1, '교통': 1, '보호': 1, '생활': 1, '순서': 1, '의사코드': 1, '순서도': 1, '표현': 1, '심층': 1, '편미분': 1, '방정식': 1, '추상화': 1, '조작': 1, '툴킷': 1, '황정리': 1, '수원': 1, '삼성': 1, '전기': 1, '트레이너': 1, '하이브리드': 1, '전상호': 1, '코어': 1, '상무': 1, '특징': 1, '복잡': 1, '획득': 1, '속도': 1, '저장': 1, '타입': 1, '유닛': 1, '유의': 1, '슬로건': 1, '경험': 1, '리치': 1, '달러': 1, '근접': 1, '예산': 1, '법안': 1, '호재': 1, '작용': 1, '마감': 1, '방식': 1, '실시': 1, '티비': 1, '오늘아침': 1, '어플리케이션': 1, '출판': 1, '미디어': 1, '발매': 1, '시리즈': 1, '장벽': 1, '허물': 1, '누구': 1, '조회': 1, '수가': 1, '상위': 1, '노출': 1, '유입': 1, '국어': 1, '전자': 1, '순찰': 1, '토카막' ...

# %%
print(final_okt_sort_dic_graph)
# Out:
# <FreqDist with 848 samples and 1828 outcomes>

# %%
len(final_okt_sort_dic_graph)
# Out:
# 848

# %%
plt.title('자연어 처리 주요 키워드 빈도수', fontsize=20)

final_okt_sort_dic_graph.plot(5)
plt.show()
